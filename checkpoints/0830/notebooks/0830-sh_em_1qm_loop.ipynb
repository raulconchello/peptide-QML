# %%
initial_path = 'peptide-QML/'
# initial_path = '../'

# %%
day = "0830"
name_notebook = day + "-sh_em_1qm_loop.ipynb"

#ask the user if that is correct, if he says yes kkep going, otherwise stop
import sys
answer = input("{} is the name of the notebook | Is that correct? (y/n): ".format(name_notebook))
if answer != "y":
    print("Please, change the name of the notebook")
    sys.exit()

# %%
import numpy as np

# %%
import sys
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import functions as f
from my_code import pytorch_model as ptm
from my_code import quantum_nodes as qn
from my_code import pytorch_wrappers as pw
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.0.4) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %% [markdown]
# # Data

# %%
data_file_path = initial_path + 'data/Scores/PET/generated/bb14_Strings_Energies_10_000_4_aa.txt'  # Replace with the actual path to your 'data.txt' file
string_list, number_list = f.read_data_file(data_file_path)
score_list = np.array(number_list)/1000
vector_list = np.array([f.string_to_numbers(string) for string in string_list]) # one hot encoding

# %%
X, Y, X_validation, Y_validation = f.create_validating_set(vector_list, score_list, percentage=0.1)

# %%
# Define the dataset
input_data = ptm.torch.tensor(X) 
target_data = ptm.torch.tensor(Y).view(-1, 1)

# Define the validation set
input_validation = ptm.torch.tensor(X_validation)
target_validation = ptm.torch.tensor(Y_validation).view(-1, 1)

# %%
input_data.shape, target_data.shape, input_validation.shape, target_validation.shape
# Out:
# (torch.Size([9000, 4]),
#  torch.Size([9000, 1]),
#  torch.Size([1000, 4]),
#  torch.Size([1000, 1]))

# %% [markdown]
# # Training

# %%
for iii in range(5):

    for block_n_layers in range(1, 21):
        print(iii, " # ------- block_n_layers: ", block_n_layers, " ------- #")
        print("")
        print("")

        # -- QUANTUM NODE -- #

        n_aminoacids = len(string_list[0])

        quantum_layer = qn.circuit(
            n_qubits = n_aminoacids, 
            device = "default.qubit.torch",
            device_options = {'shots': None},
            embedding = qn.parts.AngleEmbedding, 
            # embedding_ansatz = qn.parts.Ansatz_11,
            block_ansatz = qn.parts.Ansatz_11,
            final_ansatz = qn.parts.Ansatz_final_11,
            measurement = qn.parts.Measurement('Z', (n_aminoacids-1)//2),
            # embedding_n_layers = 4,
            # different_inputs_per_layer = True,
            block_n_layers = block_n_layers,
            # wrapper_qlayer = pw.QLayerEmpty,
        )

        # -- HYBRID MODEL -- #
        input_dim = input_data.size(1)

        n_pre_classical_layers = 4
        layers_dim = np.linspace(n_aminoacids, input_dim, 4).astype(int)

        import torch.nn as nn
        import torch
            
        class Reshape(nn.Module):
            def __init__(self):
                super(Reshape, self).__init__()

            def forward(self, x):
                dims = len(x.shape)
                return torch.transpose(x, dims-2, dims-1).reshape(x.shape[-3] if dims==3 else 1, x.shape[-2]*x.shape[-1]).squeeze()

        layers =  [ptm.nn.Embedding(num_embeddings=19, embedding_dim=quantum_layer.input_shape[0]//n_aminoacids), Reshape()]
        layers += [quantum_layer(), ptm.nn.Linear(1,1)]

        # Create model and set data:
        model = ptm.pytorch_model(
            layers,    
            save_options = {'initial_path': initial_path, 'name_notebook': name_notebook},
        )
        model.set_data(
            data_X=input_data, 
            data_Y=target_data, 
            data_X_validation=input_validation,
            data_Y_validation=target_validation
        )
        model.keep_track_params=False


        # -- TRAINING -- #
        import torch.optim as optim

        # train the model
        model.train(
            optimizer= optim.Adam,
            optimizer_options={'lr': 0.05},
            num_epochs = 30,                
            batch_size = 32,
            stop_training_options = {
                'lookback_epochs': 5, 
                'threshold': 0.005
            },
        )

        # save string of the model
        model.save_str(
            metadata={
                "data_file_path": data_file_path,
                "Quantum_circuit": quantum_layer.__str__(),
            }
        )

        # plot the losses of the trainig loop and save the figures
        model.plot_losses(save=True, save_txt=True)

        #save all the parameters of the model and the intermediate parameters of the model
        model.save_state_dict(intermediate=False)

        # plot the validation and save it
        model.plot_validation(save=True, fig_size=(9,9), percentatge=1)

        # print validation and save it
        model.str_validation(save=True, precision=4, percentatge=1, printing=False)
# Out:
# 0  # ------- block_n_layers:  1  ------- #
# Epoch [0/30], Loss: 3.8941, Loss validation: 4.4815
# - Epoch [1/30], i: [32/9000], Loss: 2.7432
# /usr/lib/python3/dist-packages/torch/autograd/__init__.py:147: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:115.)
#   Variable._execution_engine.run_backward(
# 	 Validation string, 	 i: 0; 	 prediction: -0.1058, 	 target: -0.0644, 	 loss: 0.6422
# 	 Validation string, 	 i: 1; 	 prediction: -0.1226, 	 target: -0.0980, 	 loss: 0.2505
# 	 Validation string, 	 i: 2; 	 prediction: -0.1085, 	 target: -0.0502, 	 loss: 1.1623
# Epoch [1/30], Loss: 0.7306, Loss validation: 0.4710, Time remaining: ~0.0h 6.0m 55s
# 	 Validation string, 	 i: 0; 	 prediction: -0.1137, 	 target: -0.0644, 	 loss: 0.7654
# 	 Validation string, 	 i: 1; 	 prediction: -0.1157, 	 target: -0.0980, 	 loss: 0.1808
# 	 Validation string, 	 i: 2; 	 prediction: -0.1057, 	 target: -0.0502, 	 loss: 1.1080
# Epoch [2/30], Loss: 0.4470, Loss validation: 0.5089, Time remaining: ~0.0h 6.0m 5s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0665, 	 target: -0.0644, 	 loss: 0.0326
# 	 Validation string, 	 i: 1; 	 prediction: -0.0534, 	 target: -0.0980, 	 loss: 0.4551
# 	 Validation string, 	 i: 2; 	 prediction: -0.0824, 	 target: -0.0502, 	 loss: 0.6421
# Epoch [3/30], Loss: 0.4382, Loss validation: 0.3223, Time remaining: ~0.0h 5.0m 35s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0645, 	 target: -0.0644, 	 loss: 0.0012
# 	 Validation string, 	 i: 1; 	 prediction: -0.0627, 	 target: -0.0980, 	 loss: 0.3608
# 	 Validation string, 	 i: 2; 	 prediction: -0.0800, 	 target: -0.0502, 	 loss: 0.5947
# Epoch [4/30], Loss: 0.4123, Loss validation: 0.3567, Time remaining: ~0.0h 5.0m 18s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0870, 	 target: -0.0644, 	 loss: 0.3509
# 	 Validation string, 	 i: 1; 	 prediction: -0.0957, 	 target: -0.0980, 	 loss: 0.0234
# 	 Validation string, 	 i: 2; 	 prediction: -0.0965, 	 target: -0.0502, 	 loss: 0.9241
# Epoch [5/30], Loss: 0.3983, Loss validation: 0.4091, Time remaining: ~0.0h 4.0m 58s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0583, 	 target: -0.0644, 	 loss: 0.0953
# 	 Validation string, 	 i: 1; 	 prediction: -0.0592, 	 target: -0.0980, 	 loss: 0.3957
# 	 Validation string, 	 i: 2; 	 prediction: -0.0773, 	 target: -0.0502, 	 loss: 0.5419
# Epoch [6/30], Loss: 0.4144, Loss validation: 0.3419, Time remaining: ~0.0h 4.0m 45s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0705, 	 target: -0.0644, 	 loss: 0.0946
# 	 Validation string, 	 i: 1; 	 prediction: -0.0820, 	 target: -0.0980, 	 loss: 0.1635
# 	 Validation string, 	 i: 2; 	 prediction: -0.1044, 	 target: -0.0502, 	 loss: 1.0808
# Epoch [7/30], Loss: 0.4123, Loss validation: 0.3751, Time remaining: ~0.0h 4.0m 32s
# 	 Validation string, 	 i: 0; 	 prediction: -0.1108, 	 target: -0.0644, 	 loss: 0.7196
# 	 Validation string, 	 i: 1; 	 prediction: -0.0984, 	 target: -0.0980, 	 loss: 0.0038
# 	 Validation string, 	 i: 2; 	 prediction: -0.0847, 	 target: -0.0502, 	 loss: 0.6881
# Epoch [8/30], Loss: 0.4100, Loss validation: 0.4168, Time remaining: ~0.0h 4.0m 19s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_41.txt
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_41.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_41.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_41.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_41.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_41.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_41.txt
# Model saved as peptide-QML/checkpoints/0830/models/0830-sh_em_1qm_loop_41.pth
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_41.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_41.txt
# 0  # ------- block_n_layers:  2  ------- #
#
#
# Epoch [0/30], Loss: 4.2203, Loss validation: 4.6998
# 	 Validation string, 	 i: 0; 	 prediction: -0.0638, 	 target: -0.0644, 	 loss: 0.0104
# 	 Validation string, 	 i: 1; 	 prediction: -0.0587, 	 target: -0.0980, 	 loss: 0.4013
# 	 Validation string, 	 i: 2; 	 prediction: -0.0319, 	 target: -0.0502, 	 loss: 0.3642
# Epoch [1/30], Loss: 0.8483, Loss validation: 0.5332, Time remaining: ~0.0h 8.0m 8s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0371, 	 target: -0.0644, 	 loss: 0.4234
# 	 Validation string, 	 i: 1; 	 prediction: -0.0050, 	 target: -0.0980, 	 loss: 0.9486
# 	 Validation string, 	 i: 2; 	 prediction: 0.0273, 	 target: -0.0502, 	 loss: 1.5440
# Epoch [2/30], Loss: 0.6276, Loss validation: 0.5769, Time remaining: ~0.0h 7.0m 16s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0955, 	 target: -0.0644, 	 loss: 0.4825
# 	 Validation string, 	 i: 1; 	 prediction: -0.0930, 	 target: -0.0980, 	 loss: 0.0515
# 	 Validation string, 	 i: 2; 	 prediction: -0.0715, 	 target: -0.0502, 	 loss: 0.4256
# Epoch [3/30], Loss: 0.4906, Loss validation: 0.3909, Time remaining: ~0.0h 6.0m 48s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0947, 	 target: -0.0644, 	 loss: 0.4701
# 	 Validation string, 	 i: 1; 	 prediction: -0.0873, 	 target: -0.0980, 	 loss: 0.1097
# 	 Validation string, 	 i: 2; 	 prediction: -0.0964, 	 target: -0.0502, 	 loss: 0.9218
# Epoch [4/30], Loss: 0.4160, Loss validation: 0.4238, Time remaining: ~0.0h 6.0m 22s
# 	 Validation string, 	 i: 0; 	 prediction: -0.1226, 	 target: -0.0644, 	 loss: 0.9028
# 	 Validation string, 	 i: 1; 	 prediction: -0.1336, 	 target: -0.0980, 	 loss: 0.3628
# 	 Validation string, 	 i: 2; 	 prediction: -0.0738, 	 target: -0.0502, 	 loss: 0.4703
# Epoch [5/30], Loss: 0.4090, Loss validation: 0.4059, Time remaining: ~0.0h 6.0m 5s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0646, 	 target: -0.0644, 	 loss: 0.0020
# 	 Validation string, 	 i: 1; 	 prediction: -0.0499, 	 target: -0.0980, 	 loss: 0.4906
# 	 Validation string, 	 i: 2; 	 prediction: -0.0481, 	 target: -0.0502, 	 loss: 0.0416
# Epoch [6/30], Loss: 0.4146, Loss validation: 0.3819, Time remaining: ~0.0h 5.0m 51s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0905, 	 target: -0.0644, 	 loss: 0.4043
# 	 Validation string, 	 i: 1; 	 prediction: -0.0890, 	 target: -0.0980, 	 loss: 0.0915
# 	 Validation string, 	 i: 2; 	 prediction: -0.0569, 	 target: -0.0502, 	 loss: 0.1351
# Epoch [7/30], Loss: 0.4146, Loss validation: 0.3576, Time remaining: ~0.0h 5.0m 32s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0993, 	 target: -0.0644, 	 loss: 0.5409
# 	 Validation string, 	 i: 1; 	 prediction: -0.0967, 	 target: -0.0980, 	 loss: 0.0132
# 	 Validation string, 	 i: 2; 	 prediction: -0.0619, 	 target: -0.0502, 	 loss: 0.2337
# Epoch [8/30], Loss: 0.4077, Loss validation: 0.3631, Time remaining: ~0.0h 5.0m 20s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_42.txt
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_42.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_42.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_42.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_42.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_42.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_42.txt
# Model saved as peptide-QML/checkpoints/0830/models/0830-sh_em_1qm_loop_42.pth
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_42.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_42.txt
# 0  # ------- block_n_layers:  3  ------- #
#
#
# Epoch [0/30], Loss: 2.8958, Loss validation: 3.3945
# 	 Validation string, 	 i: 0; 	 prediction: -0.1252, 	 target: -0.0644, 	 loss: 0.9434
# 	 Validation string, 	 i: 1; 	 prediction: -0.1044, 	 target: -0.0980, 	 loss: 0.0646
# 	 Validation string, 	 i: 2; 	 prediction: -0.0810, 	 target: -0.0502, 	 loss: 0.6150
# Epoch [1/30], Loss: 0.7146, Loss validation: 0.5921, Time remaining: ~0.0h 8.0m 21s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0256, 	 target: -0.0644, 	 loss: 0.6026
# 	 Validation string, 	 i: 1; 	 prediction: -0.0549, 	 target: -0.0980, 	 loss: 0.4398
# 	 Validation string, 	 i: 2; 	 prediction: -0.0412, 	 target: -0.0502, 	 loss: 0.1779
# Epoch [2/30], Loss: 0.5947, Loss validation: 0.5815, Time remaining: ~0.0h 7.0m 38s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0657, 	 target: -0.0644, 	 loss: 0.0201
# 	 Validation string, 	 i: 1; 	 prediction: -0.0700, 	 target: -0.0980, 	 loss: 0.2860
# 	 Validation string, 	 i: 2; 	 prediction: -0.0584, 	 target: -0.0502, 	 loss: 0.1635
# Epoch [3/30], Loss: 0.4632, Loss validation: 0.3621, Time remaining: ~0.0h 7.0m 19s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0305, 	 target: -0.0644, 	 loss: 0.5268
# 	 Validation string, 	 i: 1; 	 prediction: -0.0237, 	 target: -0.0980, 	 loss: 0.7582
# 	 Validation string, 	 i: 2; 	 prediction: -0.0551, 	 target: -0.0502, 	 loss: 0.0980
# Epoch [4/30], Loss: 0.4130, Loss validation: 0.4241, Time remaining: ~0.0h 6.0m 56s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0622, 	 target: -0.0644, 	 loss: 0.0348
# 	 Validation string, 	 i: 1; 	 prediction: -0.0632, 	 target: -0.0980, 	 loss: 0.3553
# 	 Validation string, 	 i: 2; 	 prediction: -0.0399, 	 target: -0.0502, 	 loss: 0.2037
# Epoch [5/30], Loss: 0.4146, Loss validation: 0.3826, Time remaining: ~0.0h 6.0m 34s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0719, 	 target: -0.0644, 	 loss: 0.1161
# 	 Validation string, 	 i: 1; 	 prediction: -0.0912, 	 target: -0.0980, 	 loss: 0.0693
# 	 Validation string, 	 i: 2; 	 prediction: -0.0638, 	 target: -0.0502, 	 loss: 0.2728
# Epoch [6/30], Loss: 0.4065, Loss validation: 0.3691, Time remaining: ~0.0h 6.0m 19s
# 	 Validation string, 	 i: 0; 	 prediction: -0.1153, 	 target: -0.0644, 	 loss: 0.7894
# 	 Validation string, 	 i: 1; 	 prediction: -0.1159, 	 target: -0.0980, 	 loss: 0.1825
# 	 Validation string, 	 i: 2; 	 prediction: -0.0644, 	 target: -0.0502, 	 loss: 0.2834
# Epoch [7/30], Loss: 0.3994, Loss validation: 0.4461, Time remaining: ~0.0h 6.0m 6s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0864, 	 target: -0.0644, 	 loss: 0.3403
# 	 Validation string, 	 i: 1; 	 prediction: -0.0860, 	 target: -0.0980, 	 loss: 0.1230
# 	 Validation string, 	 i: 2; 	 prediction: -0.0878, 	 target: -0.0502, 	 loss: 0.7511
# Epoch [8/30], Loss: 0.4105, Loss validation: 0.3754, Time remaining: ~0.0h 5.0m 54s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_43.txt
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_43.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_43.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_43.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_43.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_43.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_43.txt
# Model saved as peptide-QML/checkpoints/0830/models/0830-sh_em_1qm_loop_43.pth
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_43.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_43.txt
# 0  # ------- block_n_layers:  4  ------- #
#
#
# Epoch [0/30], Loss: 3.9920, Loss validation: 4.4744
# 	 Validation string, 	 i: 0; 	 prediction: -0.1167, 	 target: -0.0644, 	 loss: 0.8108
# 	 Validation string, 	 i: 1; 	 prediction: -0.0801, 	 target: -0.0980, 	 loss: 0.1831
# 	 Validation string, 	 i: 2; 	 prediction: -0.0400, 	 target: -0.0502, 	 loss: 0.2020
# Epoch [1/30], Loss: 0.8266, Loss validation: 0.5009, Time remaining: ~0.0h 9.0m 16s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0352, 	 target: -0.0644, 	 loss: 0.4534
# 	 Validation string, 	 i: 1; 	 prediction: -0.0141, 	 target: -0.0980, 	 loss: 0.8561
# 	 Validation string, 	 i: 2; 	 prediction: 0.0051, 	 target: -0.0502, 	 loss: 1.1008
# Epoch [2/30], Loss: 0.4991, Loss validation: 0.6273, Time remaining: ~0.0h 9.0m 4s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0182, 	 target: -0.0644, 	 loss: 0.7174
# 	 Validation string, 	 i: 1; 	 prediction: -0.0064, 	 target: -0.0980, 	 loss: 0.9346
# 	 Validation string, 	 i: 2; 	 prediction: -0.0008, 	 target: -0.0502, 	 loss: 0.9834
# Epoch [3/30], Loss: 0.4275, Loss validation: 0.5167, Time remaining: ~0.0h 8.0m 33s
# 	 Validation string, 	 i: 0; 	 prediction: -0.1039, 	 target: -0.0644, 	 loss: 0.6126
# 	 Validation string, 	 i: 1; 	 prediction: -0.0963, 	 target: -0.0980, 	 loss: 0.0175
# 	 Validation string, 	 i: 2; 	 prediction: -0.0670, 	 target: -0.0502, 	 loss: 0.3354
# Epoch [4/30], Loss: 0.4073, Loss validation: 0.3881, Time remaining: ~0.0h 8.0m 16s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0843, 	 target: -0.0644, 	 loss: 0.3083
# 	 Validation string, 	 i: 1; 	 prediction: -0.0764, 	 target: -0.0980, 	 loss: 0.2205
# 	 Validation string, 	 i: 2; 	 prediction: -0.0711, 	 target: -0.0502, 	 loss: 0.4174
# Epoch [5/30], Loss: 0.4135, Loss validation: 0.3285, Time remaining: ~0.0h 7.0m 55s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0526, 	 target: -0.0644, 	 loss: 0.1831
# 	 Validation string, 	 i: 1; 	 prediction: -0.0505, 	 target: -0.0980, 	 loss: 0.4846
# 	 Validation string, 	 i: 2; 	 prediction: -0.0480, 	 target: -0.0502, 	 loss: 0.0439
# Epoch [6/30], Loss: 0.4146, Loss validation: 0.3970, Time remaining: ~0.0h 7.0m 38s
# 	 Validation string, 	 i: 0; 	 prediction: -0.1135, 	 target: -0.0644, 	 loss: 0.7620
# 	 Validation string, 	 i: 1; 	 prediction: -0.1212, 	 target: -0.0980, 	 loss: 0.2369
# 	 Validation string, 	 i: 2; 	 prediction: -0.1303, 	 target: -0.0502, 	 loss: 1.5985
# Epoch [7/30], Loss: 0.4198, Loss validation: 0.4939, Time remaining: ~0.0h 7.0m 15s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_44.txt
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_44.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_44.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_44.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_44.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_44.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_44.txt
# Model saved as peptide-QML/checkpoints/0830/models/0830-sh_em_1qm_loop_44.pth
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_44.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_44.txt
# 0  # ------- block_n_layers:  5  ------- #
#
#
# Epoch [0/30], Loss: 6.1537, Loss validation: 7.2453
# 	 Validation string, 	 i: 0; 	 prediction: -0.0740, 	 target: -0.0644, 	 loss: 0.1480
# 	 Validation string, 	 i: 1; 	 prediction: 0.0050, 	 target: -0.0980, 	 loss: 1.0508
# 	 Validation string, 	 i: 2; 	 prediction: 0.0833, 	 target: -0.0502, 	 loss: 2.6610
# Epoch [1/30], Loss: 0.7999, Loss validation: 0.6089, Time remaining: ~0.0h 12.0m 4s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0568, 	 target: -0.0644, 	 loss: 0.1186
# 	 Validation string, 	 i: 1; 	 prediction: -0.0070, 	 target: -0.0980, 	 loss: 0.9287
# 	 Validation string, 	 i: 2; 	 prediction: -0.0102, 	 target: -0.0502, 	 loss: 0.7974
# Epoch [2/30], Loss: 0.6312, Loss validation: 0.5371, Time remaining: ~0.0h 10.0m 35s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0359, 	 target: -0.0644, 	 loss: 0.4424
# 	 Validation string, 	 i: 1; 	 prediction: -0.0113, 	 target: -0.0980, 	 loss: 0.8843
# 	 Validation string, 	 i: 2; 	 prediction: -0.0462, 	 target: -0.0502, 	 loss: 0.0783
# Epoch [3/30], Loss: 0.5926, Loss validation: 0.4715, Time remaining: ~0.0h 10.0m 6s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0597, 	 target: -0.0644, 	 loss: 0.0740
# 	 Validation string, 	 i: 1; 	 prediction: -0.0571, 	 target: -0.0980, 	 loss: 0.4173
# 	 Validation string, 	 i: 2; 	 prediction: -0.0708, 	 target: -0.0502, 	 loss: 0.4118
# Epoch [4/30], Loss: 0.5887, Loss validation: 0.4514, Time remaining: ~0.0h 9.0m 32s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0488, 	 target: -0.0644, 	 loss: 0.2426
# 	 Validation string, 	 i: 1; 	 prediction: -0.0316, 	 target: -0.0980, 	 loss: 0.6777
# 	 Validation string, 	 i: 2; 	 prediction: -0.0298, 	 target: -0.0502, 	 loss: 0.4056
# Epoch [5/30], Loss: 0.4774, Loss validation: 0.3960, Time remaining: ~0.0h 9.0m 3s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0263, 	 target: -0.0644, 	 loss: 0.5918
# 	 Validation string, 	 i: 1; 	 prediction: -0.0241, 	 target: -0.0980, 	 loss: 0.7541
# 	 Validation string, 	 i: 2; 	 prediction: -0.0647, 	 target: -0.0502, 	 loss: 0.2893
# Epoch [6/30], Loss: 0.4150, Loss validation: 0.5314, Time remaining: ~0.0h 8.0m 44s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0320, 	 target: -0.0644, 	 loss: 0.5031
# 	 Validation string, 	 i: 1; 	 prediction: -0.0620, 	 target: -0.0980, 	 loss: 0.3672
# 	 Validation string, 	 i: 2; 	 prediction: -0.0485, 	 target: -0.0502, 	 loss: 0.0323
# Epoch [7/30], Loss: 0.4262, Loss validation: 0.4791, Time remaining: ~0.0h 8.0m 23s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0748, 	 target: -0.0644, 	 loss: 0.1614
# 	 Validation string, 	 i: 1; 	 prediction: -0.0621, 	 target: -0.0980, 	 loss: 0.3669
# 	 Validation string, 	 i: 2; 	 prediction: -0.0568, 	 target: -0.0502, 	 loss: 0.1321
# Epoch [8/30], Loss: 0.4079, Loss validation: 0.3827, Time remaining: ~0.0h 8.0m 2s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0717, 	 target: -0.0644, 	 loss: 0.1132
# 	 Validation string, 	 i: 1; 	 prediction: -0.0676, 	 target: -0.0980, 	 loss: 0.3101
# 	 Validation string, 	 i: 2; 	 prediction: -0.0288, 	 target: -0.0502, 	 loss: 0.4257
# Epoch [9/30], Loss: 0.4094, Loss validation: 0.3566, Time remaining: ~0.0h 7.0m 39s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0661, 	 target: -0.0644, 	 loss: 0.0267
# 	 Validation string, 	 i: 1; 	 prediction: -0.0863, 	 target: -0.0980, 	 loss: 0.1192
# 	 Validation string, 	 i: 2; 	 prediction: -0.0607, 	 target: -0.0502, 	 loss: 0.2110
# Epoch [10/30], Loss: 0.4090, Loss validation: 0.4260, Time remaining: ~0.0h 7.0m 15s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_45.txt
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_45.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_45.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_45.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_45.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_45.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_45.txt
# Model saved as peptide-QML/checkpoints/0830/models/0830-sh_em_1qm_loop_45.pth
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_45.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_45.txt
# 0  # ------- block_n_layers:  6  ------- #
#
#
# Epoch [0/30], Loss: 5.4497, Loss validation: 6.3620
# 	 Validation string, 	 i: 0; 	 prediction: -0.1245, 	 target: -0.0644, 	 loss: 0.9319
# 	 Validation string, 	 i: 1; 	 prediction: -0.1268, 	 target: -0.0980, 	 loss: 0.2938
# 	 Validation string, 	 i: 2; 	 prediction: -0.0473, 	 target: -0.0502, 	 loss: 0.0571
# Epoch [1/30], Loss: 0.6832, Loss validation: 0.4962, Time remaining: ~0.0h 13.0m 2s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0783, 	 target: -0.0644, 	 loss: 0.2151
# 	 Validation string, 	 i: 1; 	 prediction: -0.0559, 	 target: -0.0980, 	 loss: 0.4297
# 	 Validation string, 	 i: 2; 	 prediction: -0.0455, 	 target: -0.0502, 	 loss: 0.0935
# Epoch [2/30], Loss: 0.4433, Loss validation: 0.3693, Time remaining: ~0.0h 11.0m 43s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0559, 	 target: -0.0644, 	 loss: 0.1318
# 	 Validation string, 	 i: 1; 	 prediction: -0.0506, 	 target: -0.0980, 	 loss: 0.4837
# 	 Validation string, 	 i: 2; 	 prediction: -0.0432, 	 target: -0.0502, 	 loss: 0.1388
# Epoch [3/30], Loss: 0.4151, Loss validation: 0.3262, Time remaining: ~0.0h 11.0m 23s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0637, 	 target: -0.0644, 	 loss: 0.0119
# 	 Validation string, 	 i: 1; 	 prediction: -0.0783, 	 target: -0.0980, 	 loss: 0.2007
# 	 Validation string, 	 i: 2; 	 prediction: -0.0581, 	 target: -0.0502, 	 loss: 0.1586
# Epoch [4/30], Loss: 0.4277, Loss validation: 0.3487, Time remaining: ~0.0h 10.0m 52s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0988, 	 target: -0.0644, 	 loss: 0.5329
# 	 Validation string, 	 i: 1; 	 prediction: -0.0836, 	 target: -0.0980, 	 loss: 0.1472
# 	 Validation string, 	 i: 2; 	 prediction: -0.0681, 	 target: -0.0502, 	 loss: 0.3575
# Epoch [5/30], Loss: 0.4164, Loss validation: 0.4107, Time remaining: ~0.0h 10.0m 28s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0832, 	 target: -0.0644, 	 loss: 0.2916
# 	 Validation string, 	 i: 1; 	 prediction: -0.0544, 	 target: -0.0980, 	 loss: 0.4446
# 	 Validation string, 	 i: 2; 	 prediction: -0.0452, 	 target: -0.0502, 	 loss: 0.0996
# Epoch [6/30], Loss: 0.4217, Loss validation: 0.3578, Time remaining: ~0.0h 10.0m 1s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_46.txt
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_46.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_46.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_46.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_46.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_46.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_46.txt
# Model saved as peptide-QML/checkpoints/0830/models/0830-sh_em_1qm_loop_46.pth
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_46.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_46.txt
# 0  # ------- block_n_layers:  7  ------- #
#
#
# Epoch [0/30], Loss: 1.3868, Loss validation: 1.3635
# 	 Validation string, 	 i: 0; 	 prediction: -0.0523, 	 target: -0.0644, 	 loss: 0.1875
# 	 Validation string, 	 i: 1; 	 prediction: -0.0379, 	 target: -0.0980, 	 loss: 0.6133
# 	 Validation string, 	 i: 2; 	 prediction: -0.0648, 	 target: -0.0502, 	 loss: 0.2918
# Epoch [1/30], Loss: 0.7874, Loss validation: 0.5029, Time remaining: ~0.0h 15.0m 39s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0320, 	 target: -0.0644, 	 loss: 0.5037
# 	 Validation string, 	 i: 1; 	 prediction: -0.0233, 	 target: -0.0980, 	 loss: 0.7622
# 	 Validation string, 	 i: 2; 	 prediction: -0.0262, 	 target: -0.0502, 	 loss: 0.4787
# Epoch [2/30], Loss: 0.4519, Loss validation: 0.5397, Time remaining: ~0.0h 14.0m 44s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0438, 	 target: -0.0644, 	 loss: 0.3206
# 	 Validation string, 	 i: 1; 	 prediction: -0.0394, 	 target: -0.0980, 	 loss: 0.5984
# 	 Validation string, 	 i: 2; 	 prediction: -0.0465, 	 target: -0.0502, 	 loss: 0.0737
# Epoch [3/30], Loss: 0.4264, Loss validation: 0.3805, Time remaining: ~0.0h 13.0m 29s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0586, 	 target: -0.0644, 	 loss: 0.0897
# 	 Validation string, 	 i: 1; 	 prediction: -0.0432, 	 target: -0.0980, 	 loss: 0.5589
# 	 Validation string, 	 i: 2; 	 prediction: -0.0582, 	 target: -0.0502, 	 loss: 0.1612
# Epoch [4/30], Loss: 0.4215, Loss validation: 0.4050, Time remaining: ~0.0h 12.0m 42s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0574, 	 target: -0.0644, 	 loss: 0.1089
# 	 Validation string, 	 i: 1; 	 prediction: -0.0619, 	 target: -0.0980, 	 loss: 0.3680
# 	 Validation string, 	 i: 2; 	 prediction: -0.0430, 	 target: -0.0502, 	 loss: 0.1427
# Epoch [5/30], Loss: 0.4167, Loss validation: 0.3752, Time remaining: ~0.0h 11.0m 59s
# 	 Validation string, 	 i: 0; 	 prediction: -0.0968, 	 target: -0.0644, 	 loss: 0.5027
# 	 Validation string, 	 i: 1; 	 prediction: -0.0870, 	 target: -0.0980, 	 loss: 0.1122
# 	 Validation string, 	 i: 2; 	 prediction: -0.0742, 	 target: -0.0502, 	 loss: 0.4793
# Epoch [6/30], Loss: 0.4147, Loss validation: 0.3661, Time remaining: ~0.0h 11.0m 20s
# - Epoch [7/30], i: [1088/9000], Loss: 0.3404
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-8c98966d68df> in <module>
#      63
#      64         # train the model
# ---> 65         model.train(
#      66             optimizer= optim.Adam,
#      67             optimizer_options={'lr': 0.05},
#
# ~/peptide-QML/my_code/pytorch_model.py in train(self, loss_function, optimizer, optimizer_options, initialization_options, num_epochs, batch_size, print_batch, validation, n_validation, n_print_validation, time, stop_training_options)
#     158
#     159                 # Forward pass
# --> 160                 outputs = self.model(inputs)
#     161
#     162                 # Compute the loss
#
# /usr/lib/python3/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/lib/python3/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# /usr/lib/python3/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.8/site-packages/pennylane/qnn/torch.py in forward(self, inputs)
#     406         else:
#     407             # calculate the forward pass as usual
# --> 408             results = self._evaluate_qnode(inputs)
#     409
#     410         # reshape to the correct number of batch dims
#
# ~/.local/lib/python3.8/site-packages/pennylane/qnn/torch.py in _evaluate_qnode(self, x)
#     427             **{arg: weight.to(x) for arg, weight in self.qnode_weights.items()},
#     428         }
# --> 429         res = self.qnode(**kwargs)
#     430
#     431         if isinstance(res, torch.Tensor):
#
# ~/.local/lib/python3.8/site-packages/pennylane/qnode.py in __call__(self, *args, **kwargs)
#     948                 self.execute_kwargs.pop("mode")
#     949             # pylint: disable=unexpected-keyword-arg
# --> 950             res = qml.execute(
#     951                 [self.tape],
#     952                 device=self.device,
#
# ~/.local/lib/python3.8/site-packages/pennylane/interfaces/execution.py in execute(tapes, device, gradient_fn, interface, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion, device_batch_transform)
#     509             pass_kwargs=new_device_interface,
#     510         )
# --> 511         results = cached_execute_fn(tapes, execution_config=config)
#     512         return batch_fn(results)
#     513
#
# ~/.local/lib/python3.8/site-packages/pennylane/interfaces/execution.py in wrapper(tapes, **kwargs)
#     229
#     230         for i, tape in enumerate(tapes):
# --> 231             h = tape.hash
#     232
#     233             if h in hashes.values():
#
# ~/.local/lib/python3.8/site-packages/pennylane/tape/qscript.py in hash(self)
#     236         """int: returns an integer hash uniquely representing the quantum script"""
#     237         fingerprint = []
# --> 238         fingerprint.extend(op.hash for op in self.operations)
#     239         fingerprint.extend(m.hash for m in self.measurements)
#     240         fingerprint.extend(self.trainable_params)
#
# ~/.local/lib/python3.8/site-packages/pennylane/tape/qscript.py in <genexpr>(.0)
#     236         """int: returns an integer hash uniquely representing the quantum script"""
#     237         fingerprint = []
# --> 238         fingerprint.extend(op.hash for op in self.operations)
#     239         fingerprint.extend(m.hash for m in self.measurements)
#     240         fingerprint.extend(self.trainable_params)
#
# ~/.local/lib/python3.8/site-packages/pennylane/operation.py in hash(self)
#     695                 tuple(self.wires.tolist()),
#     696                 str(self.hyperparameters.values()),
# --> 697                 _process_data(self),
#     698             )
#     699         )
#
# ~/.local/lib/python3.8/site-packages/pennylane/operation.py in _process_data(op)
#     380     # valued QNode (one that returns qml.state) requires complex typed inputs.
#     381     if op.name in ("RX", "RY", "RZ", "PhaseShift", "Rot"):
# --> 382         return str([qml.math.round(qml.math.real(d) % (2 * np.pi), 10) for d in op.data])
#     383
#     384     if op.name in ("CRX", "CRY", "CRZ", "CRot"):
#
# /usr/lib/python3/dist-packages/torch/_tensor.py in __repr__(self)
#     201             return handle_torch_function(Tensor.__repr__, (self,), self)
#     202         # All strings are unicode in Python 3.
# --> 203         return torch._tensor_str._str(self)
#     204
#     205     def backward(self, gradient=None, retain_graph=None, create_graph=False, inputs=None):
#
# /usr/lib/python3/dist-packages/torch/_tensor_str.py in _str(self)
#     404 def _str(self):
#     405     with torch.no_grad():
# --> 406         return _str_intern(self)
#
# /usr/lib/python3/dist-packages/torch/_tensor_str.py in _str_intern(inp)
#     379                     tensor_str = _tensor_str(self.to_dense(), indent)
#     380                 else:
# --> 381                     tensor_str = _tensor_str(self, indent)
#     382
#     383     if self.layout != torch.strided:
#
# /usr/lib/python3/dist-packages/torch/_tensor_str.py in _tensor_str(self, indent)
#     240         return _tensor_str_with_formatter(self, indent, summarize, real_formatter, imag_formatter)
#     241     else:
# --> 242         formatter = _Formatter(get_summarized_data(self) if summarize else self)
#     243         return _tensor_str_with_formatter(self, indent, summarize, formatter)
#     244
#
# /usr/lib/python3/dist-packages/torch/_tensor_str.py in __init__(self, tensor)
#      80
#      81         with torch.no_grad():
# ---> 82             tensor_view = tensor.reshape(-1)
#      83
#      84         if not self.floating_dtype:
#
# /usr/lib/python3/dist-packages/torch/autograd/grad_mode.py in __exit__(self, exc_type, exc_value, traceback)
#     126         torch.set_grad_enabled(False)
#     127
# --> 128     def __exit__(self, exc_type: Any, exc_value: Any, traceback: Any) -> None:
#     129         torch.set_grad_enabled(self.prev)
#     130
#
# KeyboardInterrupt:

# %%
# push changes to git
if initial_path != '../':
    # !cd peptide-QML && git add . && git commit -m "data trained model" && git push
# Out:
# [main 778cb793] data trained model
#  468 files changed, 212985 insertions(+)
#  create mode 100644 checkpoints/0830/models/.gitkeep
#  create mode 100644 checkpoints/0830/models/0830-mh_em_1qm_loop_2.pth
#  create mode 100644 checkpoints/0830/models/0830-mh_em_1qm_loop_3.pth
#  create mode 100644 checkpoints/0830/models/0830-mh_em_1qm_loop_4.pth
#  create mode 100644 checkpoints/0830/models/0830-mh_em_1qm_loop_5.pth
#  create mode 100644 checkpoints/0830/models/0830-mh_em_1qm_loop_6.pth
#  create mode 100644 checkpoints/0830/models/0830-mh_em_1qm_loop_7.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_1.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_10.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_11.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_12.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_13.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_14.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_15.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_16.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_17.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_18.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_19.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_2.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_20.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_21.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_22.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_23.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_24.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_25.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_26.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_27.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_28.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_29.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_3.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_30.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_31.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_32.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_33.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_34.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_35.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_36.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_37.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_38.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_39.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_4.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_40.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_5.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_6.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_7.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_8.pth
#  create mode 100644 checkpoints/0830/models/0830-sh_em_1qm_loop_9.pth
#  create mode 100644 checkpoints/0830/notebooks/.gitkeep
#  create mode 100644 checkpoints/0830/pdfs/.gitkeep
#  create mode 100644 checkpoints/0830/plots/.gitkeep
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_batches_2.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_batches_3.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_batches_4.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_batches_5.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_batches_6.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_batches_7.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_2.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_3.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_4.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_5.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_6.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_7.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_validation_2.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_validation_3.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_validation_4.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_validation_5.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_validation_6.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_validation_7.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_validation_2.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_validation_3.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_validation_4.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_validation_5.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_validation_6.png
#  create mode 100644 checkpoints/0830/plots/0830-mh_em_1qm_loop_validation_7.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_1.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_10.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_11.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_12.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_13.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_14.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_15.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_16.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_17.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_18.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_19.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_2.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_20.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_21.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_22.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_23.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_24.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_25.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_26.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_27.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_28.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_29.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_3.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_30.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_31.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_32.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_33.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_34.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_35.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_36.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_37.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_38.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_39.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_4.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_40.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_5.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_6.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_7.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_8.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_batches_9.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_1.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_10.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_11.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_12.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_13.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_14.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_15.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_16.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_17.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_18.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_19.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_2.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_20.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_21.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_22.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_23.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_24.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_25.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_26.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_27.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_28.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_29.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_3.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_30.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_31.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_32.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_33.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_34.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_35.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_36.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_37.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_38.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_39.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_4.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_40.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_5.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_6.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_7.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_8.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_9.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_1.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_10.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_11.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_12.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_13.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_14.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_15.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_16.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_17.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_18.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_19.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_2.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_20.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_21.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_22.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_23.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_24.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_25.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_26.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_27.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_28.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_29.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_3.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_30.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_31.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_32.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_33.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_34.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_35.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_36.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_37.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_38.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_39.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_4.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_40.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_5.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_6.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_7.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_8.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_losses_epochs_validation_9.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_1.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_10.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_11.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_12.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_13.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_14.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_15.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_16.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_17.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_18.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_19.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_2.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_20.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_21.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_22.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_23.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_24.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_25.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_26.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_27.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_28.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_29.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_3.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_30.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_31.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_32.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_33.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_34.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_35.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_36.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_37.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_38.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_39.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_4.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_40.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_5.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_6.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_7.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_8.png
#  create mode 100644 checkpoints/0830/plots/0830-sh_em_1qm_loop_validation_9.png
#  create mode 100644 checkpoints/0830/txts/.gitkeep
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_batches_2.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_batches_3.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_batches_4.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_batches_5.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_batches_6.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_batches_7.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_2.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_3.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_4.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_5.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_6.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_7.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_validation_2.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_validation_3.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_validation_4.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_validation_5.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_validation_6.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_validation_7.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_model_str_2.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_model_str_3.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_model_str_4.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_model_str_5.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_model_str_6.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_model_str_7.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_validation_2.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_validation_3.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_validation_4.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_validation_5.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_validation_6.txt
#  create mode 100644 checkpoints/0830/txts/0830-mh_em_1qm_loop_validation_7.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_1.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_10.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_11.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_12.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_13.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_14.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_15.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_16.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_17.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_18.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_19.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_2.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_20.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_21.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_22.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_23.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_24.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_25.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_26.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_27.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_28.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_29.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_3.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_30.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_31.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_32.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_33.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_34.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_35.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_36.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_37.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_38.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_39.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_4.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_40.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_5.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_6.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_7.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_8.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_batches_9.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_1.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_10.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_11.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_12.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_13.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_14.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_15.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_16.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_17.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_18.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_19.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_2.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_20.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_21.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_22.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_23.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_24.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_25.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_26.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_27.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_28.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_29.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_3.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_30.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_31.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_32.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_33.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_34.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_35.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_36.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_37.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_38.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_39.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_4.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_40.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_5.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_6.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_7.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_8.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_9.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_1.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_10.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_11.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_12.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_13.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_14.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_15.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_16.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_17.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_18.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_19.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_2.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_20.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_21.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_22.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_23.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_24.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_25.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_26.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_27.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_28.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_29.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_3.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_30.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_31.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_32.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_33.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_34.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_35.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_36.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_37.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_38.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_39.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_4.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_40.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_5.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_6.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_7.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_8.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_losses_epochs_validation_9.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_1.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_10.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_11.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_12.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_13.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_14.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_15.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_16.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_17.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_18.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_19.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_2.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_20.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_21.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_22.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_23.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_24.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_25.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_26.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_27.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_28.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_29.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_3.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_30.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_31.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_32.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_33.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_34.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_35.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_36.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_37.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_38.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_39.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_4.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_40.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_5.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_6.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_7.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_8.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_model_str_9.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_1.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_10.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_11.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_12.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_13.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_14.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_15.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_16.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_17.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_18.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_19.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_2.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_20.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_21.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_22.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_23.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_24.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_25.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_26.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_27.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_28.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_29.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_3.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_30.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_31.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_32.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_33.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_34.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_35.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_36.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_37.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_38.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_39.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_4.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_40.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_5.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_6.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_7.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_8.txt
#  create mode 100644 checkpoints/0830/txts/0830-sh_em_1qm_loop_validation_9.txt
#  create mode 100644 checkpoints/0830/versions/.gitkeep
#  create mode 100644 checkpoints/0830/versions/0830-mh_em_1qm_loop.version
#  create mode 100644 checkpoints/0830/versions/0830-sh_em_1qm_loop.version
# Enumerating objects: 471, done.
# Counting objects: 100% (471/471), done.
# Delta compression using up to 24 threads
# Compressing objects: 100% (468/468), done.
# Writing objects: 100% (469/469), 5.61 MiB | 13.03 MiB/s, done.
# Total 469 (delta 93), reused 0 (delta 0)
# remote: Resolving deltas: 100% (93/93), completed with 2 local objects.
# To github.com:raulconchello/peptide-QML.git
#    f08259fc..778cb793  main -> main
