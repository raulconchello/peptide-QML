# %%
initial_path = 'peptide-QML'
# initial_path = '..'

# %%
import sys
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import helper_classes as c
from my_code import pytorch_model as m
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.0.4) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
# name of the notebook
name_notebook = "sweep_12c_e"

# %%
sweep = c.Sweep(
    name_notebook, 
    initial_path=initial_path,
    description="To compare with sweep_12h_e_Am_Xqm with a classical model with the same number of parameters.",
    repetitions=list(range(1, 3)),
    n_layers_block=[1,2,5,12,20],
    embedding_dim=[1,5],
)

# %%
sweep.save()
# Out:
# Folder 'peptide-QML/saved/Sweeps/0914/' created successfully.

# %%
# sweep = c.Sweep.load(file_name=name_notebook+"-1", day='0912', initial_path=initial_path)

# %%
for sweep_point in sweep:

    # print the point of the sweep
    sweep.print_sweep_status(sweep_point['idx'])

    # -- MODEL -- #
                    
    class Model(m.Model):
        def __init__(self):
            super(Model, self).__init__()
            self.fc1 = m.nn.Embedding(num_embeddings=19, embedding_dim=sweep_point['embedding_dim'])
            self.fc2 = m.Reshape()
            block = [m.nn.Linear(12*sweep_point['embedding_dim'], 12*sweep_point['embedding_dim']), m.nn.Sigmoid()] * sweep_point['n_layers_block']
            self.fc3 = m.nn.Sequential(*block)
            self.fc4 = m.nn.Linear(12*sweep_point['embedding_dim'], 1) 

        def forward(self, x):
            for i in range(1,5):
                x = getattr(self, 'fc{}'.format(i))(x)
            return x

    model = Model()

    # set quantum layer
    quantum_layer = None
    model.set_quantum_layer(quantum_layer)

    # set the name and path of the model
    model.set_name_and_path(name_notebook, initial_path)

    #set sweep point
    model.set_sweep_point(
        sweep_uuid = sweep.uuid,
        sweep_point = sweep_point,
        day=sweep.day
    )

    # -- TRAIN -- #
    model.optimize_params(
        #save info
        save_model_info = True,
        description = 'sweep with 12 amino acids all classical -> to compare with sweep_12h_e_Am_Xqm',    
        #data
        data=c.Data.load(initial_path=initial_path, file_name='PET_SCORES_12_Numbers_int'),
        # train options
        optimizer = m.optim.Adam,
        optimizer_options = {'lr': 0.01},
        num_epochs = 2,                
        batch_size = 32,
        # early stopping options
        stop_training_options = {
            'lookback_epochs': 5, 
            'threshold_slope': 0.001,
            'threshold_std_dev': 0.2
        },
        # metadata
        metadata = {}
    )

    # -- VALIDATION and PLOTS -- #
    model.plot_losses(fig_size=(6,6))
    model.validate(
        pct=1,
        add_to_results=True,
        plot=True,
        print_items=False
    )

    # -- SAVE RESULTS -- #
    model.save_results()

    # -- ADD DATA GENERATED TO SWEEP -- #
    sweep.add_data(
        idx=sweep_point['idx'],
        model_uuid=model.uuid,
        best_loss_train=model.results.loss_epoch.best,
        best_loss_test=model.results.loss_validation_epoch.best,
        loss_validation=model.mean_loss_validation,
        time_train=model.results.time_epoch.last,
    )
    sweep.save(csv=False) #TODO: save csv=False automatically when sweep is already saved ion csv
# Out:
#  --- SWEEP POINT 1/20: (1, 1, 1) ---
#  --- parameters sweeping: ['repetitions', 'n_layers_block', 'embedding_dim']
#
# Folder 'peptide-QML/saved/Models/0914/' created successfully.
# Epoch [0/2], Loss epoch: 0.2714, Loss validation: 0.2709
# 	 Validation string, 	 i: 4176; 	 prediction: -0.3279, 	 target: -0.4093, 	 loss: 0.0066
# 	 Validation string, 	 i: 3188; 	 prediction: -0.1704, 	 target: -0.2763, 	 loss: 0.0112
# 	 Validation string, 	 i: 3833; 	 prediction: -0.2923, 	 target: -0.1486, 	 loss: 0.0206
# Epoch [1/2], Loss epoch: 0.0078, Loss validation: 0.0069, Time remaining: ~0.0h 0.0m 17s
# 	 Validation string, 	 i: 3968; 	 prediction: -0.1944, 	 target: -0.1797, 	 loss: 0.0002
# 	 Validation string, 	 i: 856; 	 prediction: -0.4914, 	 target: -0.4308, 	 loss: 0.0037
# 	 Validation string, 	 i: 409; 	 prediction: -0.2371, 	 target: -0.0873, 	 loss: 0.0224
# Epoch [2/2], Loss epoch: 0.0071, Loss validation: 0.0072, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.007095425389289296, std loss: 0.01048039424441426
# Folder 'peptide-QML/saved/Results/0914/' created successfully.
#
#
#  --- SWEEP POINT 2/20: (1, 1, 5) ---
#  --- time reamining: 00:16:14.62
#
# Epoch [0/2], Loss epoch: 0.0804, Loss validation: 0.0782
# 	 Validation string, 	 i: 815; 	 prediction: -0.2838, 	 target: -0.3657, 	 loss: 0.0067
# 	 Validation string, 	 i: 3899; 	 prediction: -0.2876, 	 target: -0.3645, 	 loss: 0.0059
# 	 Validation string, 	 i: 2162; 	 prediction: -0.1286, 	 target: -0.2245, 	 loss: 0.0092
# Epoch [1/2], Loss epoch: 0.0054, Loss validation: 0.0055, Time remaining: ~0.0h 0.0m 17s
# 	 Validation string, 	 i: 3261; 	 prediction: -0.2968, 	 target: -0.3023, 	 loss: 0.0000
# 	 Validation string, 	 i: 3565; 	 prediction: -0.1662, 	 target: -0.2075, 	 loss: 0.0017
# 	 Validation string, 	 i: 3278; 	 prediction: -0.2155, 	 target: -0.2426, 	 loss: 0.0007
# Epoch [2/2], Loss epoch: 0.0045, Loss validation: 0.0044, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.004214909870286446, std loss: 0.007356780241096705
#
#
#  --- SWEEP POINT 3/20: (1, 2, 1) ---
#  --- time reamining: 00:15:02.10
#
# Epoch [0/2], Loss epoch: 0.3296, Loss validation: 0.3301
# 	 Validation string, 	 i: 3225; 	 prediction: -0.1898, 	 target: -0.0773, 	 loss: 0.0127
# 	 Validation string, 	 i: 4055; 	 prediction: -0.1642, 	 target: -0.0313, 	 loss: 0.0177
# 	 Validation string, 	 i: 1536; 	 prediction: -0.1390, 	 target: -0.1573, 	 loss: 0.0003
# Epoch [1/2], Loss epoch: 0.0077, Loss validation: 0.0068, Time remaining: ~0.0h 0.0m 19s
# 	 Validation string, 	 i: 1345; 	 prediction: -0.2748, 	 target: -0.3416, 	 loss: 0.0045
# 	 Validation string, 	 i: 2483; 	 prediction: -0.0970, 	 target: 0.0001, 	 loss: 0.0094
# 	 Validation string, 	 i: 1028; 	 prediction: -0.1091, 	 target: -0.0868, 	 loss: 0.0005
# Epoch [2/2], Loss epoch: 0.0067, Loss validation: 0.0067, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0068528051143415805, std loss: 0.010625708706836517
#
#
#  --- SWEEP POINT 4/20: (1, 2, 5) ---
#  --- time reamining: 00:14:38.29
#
# Epoch [0/2], Loss epoch: 0.2201, Loss validation: 0.2204
# 	 Validation string, 	 i: 1111; 	 prediction: -0.1439, 	 target: -0.1858, 	 loss: 0.0018
# 	 Validation string, 	 i: 528; 	 prediction: -0.1449, 	 target: -0.1202, 	 loss: 0.0006
# 	 Validation string, 	 i: 2253; 	 prediction: -0.1356, 	 target: -0.2283, 	 loss: 0.0086
# Epoch [1/2], Loss epoch: 0.0052, Loss validation: 0.0044, Time remaining: ~0.0h 0.0m 20s
# 	 Validation string, 	 i: 1874; 	 prediction: -0.1473, 	 target: -0.2740, 	 loss: 0.0161
# 	 Validation string, 	 i: 2938; 	 prediction: -0.1351, 	 target: -0.0981, 	 loss: 0.0014
# 	 Validation string, 	 i: 353; 	 prediction: -0.3826, 	 target: -0.3750, 	 loss: 0.0001
# Epoch [2/2], Loss epoch: 0.0040, Loss validation: 0.0039, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0038382409677965626, std loss: 0.007050368103324824
#
#
#  --- SWEEP POINT 5/20: (1, 5, 1) ---
#  --- time reamining: 00:14:06.44
#
# Epoch [0/2], Loss epoch: 0.1795, Loss validation: 0.1799
# 	 Validation string, 	 i: 1354; 	 prediction: -0.1625, 	 target: -0.2097, 	 loss: 0.0022
# 	 Validation string, 	 i: 1121; 	 prediction: -0.3373, 	 target: -0.3984, 	 loss: 0.0037
# 	 Validation string, 	 i: 3595; 	 prediction: -0.1786, 	 target: -0.2779, 	 loss: 0.0099
# Epoch [1/2], Loss epoch: 0.0080, Loss validation: 0.0070, Time remaining: ~0.0h 0.0m 22s
# 	 Validation string, 	 i: 2121; 	 prediction: -0.4731, 	 target: -0.5038, 	 loss: 0.0009
# 	 Validation string, 	 i: 2405; 	 prediction: -0.3503, 	 target: -0.1812, 	 loss: 0.0286
# 	 Validation string, 	 i: 608; 	 prediction: -0.1591, 	 target: -0.1603, 	 loss: 0.0000
# Epoch [2/2], Loss epoch: 0.0071, Loss validation: 0.0068, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.006654666961810449, std loss: 0.010711384460045928
#
#
#  --- SWEEP POINT 6/20: (1, 5, 5) ---
#  --- time reamining: 00:13:40.71
#
# Epoch [0/2], Loss epoch: 0.3510, Loss validation: 0.3515
# 	 Validation string, 	 i: 584; 	 prediction: -0.3376, 	 target: -0.3277, 	 loss: 0.0001
# 	 Validation string, 	 i: 1472; 	 prediction: -0.3089, 	 target: -0.4239, 	 loss: 0.0132
# 	 Validation string, 	 i: 3303; 	 prediction: -0.1524, 	 target: -0.1156, 	 loss: 0.0014
# Epoch [1/2], Loss epoch: 0.0054, Loss validation: 0.0044, Time remaining: ~0.0h 0.0m 25s
# 	 Validation string, 	 i: 42; 	 prediction: -0.5004, 	 target: -0.4972, 	 loss: 0.0000
# 	 Validation string, 	 i: 3803; 	 prediction: -0.3725, 	 target: -0.4092, 	 loss: 0.0014
# 	 Validation string, 	 i: 850; 	 prediction: -0.1855, 	 target: -0.1898, 	 loss: 0.0000
# Epoch [2/2], Loss epoch: 0.0042, Loss validation: 0.0040, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.004010158548334977, std loss: 0.007331482994813359
#
#
#  --- SWEEP POINT 7/20: (1, 12, 1) ---
#  --- time reamining: 00:13:20.68
#
# Epoch [0/2], Loss epoch: 0.3348, Loss validation: 0.3353
# 	 Validation string, 	 i: 1213; 	 prediction: -0.1926, 	 target: -0.1728, 	 loss: 0.0004
# 	 Validation string, 	 i: 143; 	 prediction: -0.4271, 	 target: -0.4024, 	 loss: 0.0006
# 	 Validation string, 	 i: 1302; 	 prediction: -0.2794, 	 target: -0.0978, 	 loss: 0.0330
# Epoch [1/2], Loss epoch: 0.0119, Loss validation: 0.0080, Time remaining: ~0.0h 0.0m 29s
# 	 Validation string, 	 i: 2081; 	 prediction: -0.3918, 	 target: -0.3932, 	 loss: 0.0000
# 	 Validation string, 	 i: 4316; 	 prediction: -0.4045, 	 target: -0.3672, 	 loss: 0.0014
# 	 Validation string, 	 i: 503; 	 prediction: -0.2488, 	 target: -0.2268, 	 loss: 0.0005
# Epoch [2/2], Loss epoch: 0.0075, Loss validation: 0.0078, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.007592884846992966, std loss: 0.013767939458535725
#
#
#  --- SWEEP POINT 8/20: (1, 12, 5) ---
#  --- time reamining: 00:13:10.05
#
# Epoch [0/2], Loss epoch: 0.0278, Loss validation: 0.0279
# 	 Validation string, 	 i: 2098; 	 prediction: -0.1606, 	 target: -0.0870, 	 loss: 0.0054
# 	 Validation string, 	 i: 1417; 	 prediction: -0.1086, 	 target: -0.2244, 	 loss: 0.0134
# 	 Validation string, 	 i: 1532; 	 prediction: -0.2290, 	 target: -0.2888, 	 loss: 0.0036
# Epoch [1/2], Loss epoch: 0.0065, Loss validation: 0.0051, Time remaining: ~0.0h 0.0m 40s
# 	 Validation string, 	 i: 2773; 	 prediction: -0.2103, 	 target: -0.1463, 	 loss: 0.0041
# 	 Validation string, 	 i: 3061; 	 prediction: -0.2692, 	 target: -0.3068, 	 loss: 0.0014
# 	 Validation string, 	 i: 437; 	 prediction: -0.1283, 	 target: -0.0875, 	 loss: 0.0017
# Epoch [2/2], Loss epoch: 0.0045, Loss validation: 0.0044, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.004262453169256551, std loss: 0.007350230586680761
#
#
#  --- SWEEP POINT 9/20: (1, 20, 1) ---
#  --- time reamining: 00:13:12.73
#
# Epoch [0/2], Loss epoch: 0.5123, Loss validation: 0.5129
# 	 Validation string, 	 i: 4265; 	 prediction: -0.1714, 	 target: -0.0222, 	 loss: 0.0223
# 	 Validation string, 	 i: 956; 	 prediction: -0.1721, 	 target: -0.1433, 	 loss: 0.0008
# 	 Validation string, 	 i: 523; 	 prediction: -0.3854, 	 target: -0.3877, 	 loss: 0.0000
# Epoch [1/2], Loss epoch: 0.0198, Loss validation: 0.0094, Time remaining: ~0.0h 0.0m 33s
# 	 Validation string, 	 i: 3277; 	 prediction: -0.2785, 	 target: -0.3327, 	 loss: 0.0029
# 	 Validation string, 	 i: 3694; 	 prediction: -0.3980, 	 target: -0.2383, 	 loss: 0.0255
# 	 Validation string, 	 i: 3353; 	 prediction: -0.1779, 	 target: -0.1810, 	 loss: 0.0000
# Epoch [2/2], Loss epoch: 0.0082, Loss validation: 0.0077, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.007616110453337571, std loss: 0.013547693713197058
#
#
#  --- SWEEP POINT 10/20: (1, 20, 5) ---
#  --- time reamining: 00:12:40.70
#
# Epoch [0/2], Loss epoch: 0.4271, Loss validation: 0.4276
# 	 Validation string, 	 i: 4087; 	 prediction: -0.3780, 	 target: -0.3351, 	 loss: 0.0018
# 	 Validation string, 	 i: 3775; 	 prediction: -0.2088, 	 target: -0.1729, 	 loss: 0.0013
# 	 Validation string, 	 i: 2950; 	 prediction: -0.1731, 	 target: -0.1686, 	 loss: 0.0000
# Epoch [1/2], Loss epoch: 0.0075, Loss validation: 0.0046, Time remaining: ~0.0h 0.0m 54s
# 	 Validation string, 	 i: 42; 	 prediction: -0.4713, 	 target: -0.4972, 	 loss: 0.0007
# 	 Validation string, 	 i: 1322; 	 prediction: -0.2461, 	 target: -0.1888, 	 loss: 0.0033
# 	 Validation string, 	 i: 434; 	 prediction: -0.2882, 	 target: -0.2797, 	 loss: 0.0001
# Epoch [2/2], Loss epoch: 0.0047, Loss validation: 0.0046, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0044482115351719455, std loss: 0.007627291825762685
#
#
#  --- SWEEP POINT 11/20: (2, 1, 1) ---
#  --- time reamining: 00:12:38.87
#
# Epoch [0/2], Loss epoch: 0.0735, Loss validation: 0.0734
# 	 Validation string, 	 i: 1580; 	 prediction: -0.1524, 	 target: -0.2127, 	 loss: 0.0036
# 	 Validation string, 	 i: 3449; 	 prediction: -0.3376, 	 target: -0.4808, 	 loss: 0.0205
# 	 Validation string, 	 i: 2988; 	 prediction: -0.4527, 	 target: -0.4253, 	 loss: 0.0007
# Epoch [1/2], Loss epoch: 0.0077, Loss validation: 0.0071, Time remaining: ~0.0h 0.0m 16s
# 	 Validation string, 	 i: 4255; 	 prediction: -0.5490, 	 target: -0.4529, 	 loss: 0.0092
# 	 Validation string, 	 i: 1645; 	 prediction: -0.3779, 	 target: -0.4435, 	 loss: 0.0043
# 	 Validation string, 	 i: 2567; 	 prediction: -0.3951, 	 target: -0.3171, 	 loss: 0.0061
# Epoch [2/2], Loss epoch: 0.0072, Loss validation: 0.0069, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.006860151793279415, std loss: 0.011491379668586267
#
#
#  --- SWEEP POINT 12/20: (2, 1, 5) ---
#  --- time reamining: 00:11:01.97
#
# Epoch [0/2], Loss epoch: 0.0261, Loss validation: 0.0264
# 	 Validation string, 	 i: 90; 	 prediction: -0.2130, 	 target: -0.1402, 	 loss: 0.0053
# 	 Validation string, 	 i: 3827; 	 prediction: -0.2011, 	 target: -0.1980, 	 loss: 0.0000
# 	 Validation string, 	 i: 2705; 	 prediction: -0.2240, 	 target: -0.2802, 	 loss: 0.0032
# Epoch [1/2], Loss epoch: 0.0055, Loss validation: 0.0048, Time remaining: ~0.0h 0.0m 18s
# 	 Validation string, 	 i: 3931; 	 prediction: -0.2466, 	 target: -0.2981, 	 loss: 0.0026
# 	 Validation string, 	 i: 687; 	 prediction: -0.2972, 	 target: -0.3349, 	 loss: 0.0014
# 	 Validation string, 	 i: 3786; 	 prediction: -0.4341, 	 target: -0.4709, 	 loss: 0.0014
# Epoch [2/2], Loss epoch: 0.0044, Loss validation: 0.0044, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.004318211645961332, std loss: 0.007362782759835303
#
#
#  --- SWEEP POINT 13/20: (2, 2, 1) ---
#  --- time reamining: 00:09:33.64
#
# Epoch [0/2], Loss epoch: 0.0774, Loss validation: 0.0776
# 	 Validation string, 	 i: 2031; 	 prediction: -0.4954, 	 target: -0.2737, 	 loss: 0.0491
# 	 Validation string, 	 i: 3371; 	 prediction: -0.4218, 	 target: -0.3313, 	 loss: 0.0082
# 	 Validation string, 	 i: 183; 	 prediction: -0.4482, 	 target: -0.4607, 	 loss: 0.0002
# Epoch [1/2], Loss epoch: 0.0075, Loss validation: 0.0071, Time remaining: ~0.0h 0.0m 19s
# 	 Validation string, 	 i: 1781; 	 prediction: -0.3035, 	 target: -0.2716, 	 loss: 0.0010
# 	 Validation string, 	 i: 1343; 	 prediction: -0.1896, 	 target: -0.1896, 	 loss: 0.0000
# 	 Validation string, 	 i: 1161; 	 prediction: -0.2352, 	 target: -0.2547, 	 loss: 0.0004
# Epoch [2/2], Loss epoch: 0.0069, Loss validation: 0.0068, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.006727414527415669, std loss: 0.011631547336517691
#
#
#  --- SWEEP POINT 14/20: (2, 2, 5) ---
#  --- time reamining: 00:08:12.58
#
# Epoch [0/2], Loss epoch: 0.0284, Loss validation: 0.0285
# 	 Validation string, 	 i: 3064; 	 prediction: -0.2905, 	 target: -0.3344, 	 loss: 0.0019
# 	 Validation string, 	 i: 682; 	 prediction: -0.3980, 	 target: -0.4102, 	 loss: 0.0001
# 	 Validation string, 	 i: 2339; 	 prediction: -0.2053, 	 target: -0.1800, 	 loss: 0.0006
# Epoch [1/2], Loss epoch: 0.0052, Loss validation: 0.0043, Time remaining: ~0.0h 0.0m 20s
# 	 Validation string, 	 i: 4383; 	 prediction: -0.1488, 	 target: -0.1553, 	 loss: 0.0000
# 	 Validation string, 	 i: 881; 	 prediction: -0.1375, 	 target: -0.1405, 	 loss: 0.0000
# 	 Validation string, 	 i: 1402; 	 prediction: -0.1863, 	 target: -0.0699, 	 loss: 0.0135
# Epoch [2/2], Loss epoch: 0.0040, Loss validation: 0.0040, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.003908947987365111, std loss: 0.007095056533787531
#
#
#  --- SWEEP POINT 15/20: (2, 5, 1) ---
#  --- time reamining: 00:06:56.13
#
# Epoch [0/2], Loss epoch: 0.1099, Loss validation: 0.1102
# 	 Validation string, 	 i: 894; 	 prediction: -0.1382, 	 target: -0.1882, 	 loss: 0.0025
# 	 Validation string, 	 i: 2817; 	 prediction: -0.1928, 	 target: -0.3052, 	 loss: 0.0126
# 	 Validation string, 	 i: 3136; 	 prediction: -0.4423, 	 target: -0.4263, 	 loss: 0.0003
# Epoch [1/2], Loss epoch: 0.0081, Loss validation: 0.0072, Time remaining: ~0.0h 0.0m 21s
# 	 Validation string, 	 i: 1886; 	 prediction: -0.3677, 	 target: -0.1299, 	 loss: 0.0565
# 	 Validation string, 	 i: 1072; 	 prediction: -0.3407, 	 target: -0.4175, 	 loss: 0.0059
# 	 Validation string, 	 i: 1268; 	 prediction: -0.3895, 	 target: -0.4632, 	 loss: 0.0054
# Epoch [2/2], Loss epoch: 0.0072, Loss validation: 0.0070, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0069017143313920715, std loss: 0.011755257122575028
#
#
#  --- SWEEP POINT 16/20: (2, 5, 5) ---
#  --- time reamining: 00:05:44.10
#
# Epoch [0/2], Loss epoch: 0.1371, Loss validation: 0.1369
# 	 Validation string, 	 i: 1380; 	 prediction: -0.1479, 	 target: -0.1793, 	 loss: 0.0010
# 	 Validation string, 	 i: 3082; 	 prediction: -0.4752, 	 target: -0.4932, 	 loss: 0.0003
# 	 Validation string, 	 i: 1446; 	 prediction: -0.2003, 	 target: -0.2428, 	 loss: 0.0018
# Epoch [1/2], Loss epoch: 0.0053, Loss validation: 0.0043, Time remaining: ~0.0h 0.0m 27s
# 	 Validation string, 	 i: 3747; 	 prediction: -0.1251, 	 target: -0.3149, 	 loss: 0.0360
# 	 Validation string, 	 i: 3649; 	 prediction: -0.1304, 	 target: -0.0472, 	 loss: 0.0069
# 	 Validation string, 	 i: 3837; 	 prediction: -0.1551, 	 target: -0.1907, 	 loss: 0.0013
# Epoch [2/2], Loss epoch: 0.0041, Loss validation: 0.0044, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0043109336023627156, std loss: 0.007143905602844423
#
#
#  --- SWEEP POINT 17/20: (2, 12, 1) ---
#  --- time reamining: 00:04:36.13
#
# Epoch [0/2], Loss epoch: 0.2516, Loss validation: 0.2520
# 	 Validation string, 	 i: 4203; 	 prediction: -0.2567, 	 target: -0.1243, 	 loss: 0.0175
# 	 Validation string, 	 i: 2588; 	 prediction: -0.1457, 	 target: -0.1911, 	 loss: 0.0021
# 	 Validation string, 	 i: 2516; 	 prediction: -0.1458, 	 target: -0.1315, 	 loss: 0.0002
# Epoch [1/2], Loss epoch: 0.0109, Loss validation: 0.0078, Time remaining: ~0.0h 0.0m 29s
# 	 Validation string, 	 i: 1733; 	 prediction: -0.3949, 	 target: -0.4654, 	 loss: 0.0050
# 	 Validation string, 	 i: 691; 	 prediction: -0.2201, 	 target: -0.2497, 	 loss: 0.0009
# 	 Validation string, 	 i: 948; 	 prediction: -0.3377, 	 target: -0.3813, 	 loss: 0.0019
# Epoch [2/2], Loss epoch: 0.0077, Loss validation: 0.0077, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.007427935266862265, std loss: 0.012373841092889564
#
#
#  --- SWEEP POINT 18/20: (2, 12, 5) ---
#  --- time reamining: 00:03:29.58
#
# Epoch [0/2], Loss epoch: 0.0349, Loss validation: 0.0351
# 	 Validation string, 	 i: 1487; 	 prediction: -0.3575, 	 target: -0.2552, 	 loss: 0.0105
# 	 Validation string, 	 i: 3089; 	 prediction: -0.4281, 	 target: -0.4437, 	 loss: 0.0002
# 	 Validation string, 	 i: 2476; 	 prediction: -0.2911, 	 target: -0.3608, 	 loss: 0.0049
# Epoch [1/2], Loss epoch: 0.0062, Loss validation: 0.0045, Time remaining: ~0.0h 0.0m 39s
# 	 Validation string, 	 i: 3810; 	 prediction: -0.1143, 	 target: -0.0822, 	 loss: 0.0010
# 	 Validation string, 	 i: 1440; 	 prediction: -0.1371, 	 target: -0.1295, 	 loss: 0.0001
# 	 Validation string, 	 i: 1289; 	 prediction: -0.3124, 	 target: -0.3653, 	 loss: 0.0028
# Epoch [2/2], Loss epoch: 0.0044, Loss validation: 0.0045, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.004495923417785032, std loss: 0.007453503277296642
#
#
#  --- SWEEP POINT 19/20: (2, 20, 1) ---
#  --- time reamining: 00:02:23.87
#
# Epoch [0/2], Loss epoch: 0.0833, Loss validation: 0.0831
# 	 Validation string, 	 i: 256; 	 prediction: -0.3797, 	 target: -0.2804, 	 loss: 0.0099
# 	 Validation string, 	 i: 609; 	 prediction: -0.1957, 	 target: -0.0825, 	 loss: 0.0128
# 	 Validation string, 	 i: 4036; 	 prediction: -0.4133, 	 target: -0.3914, 	 loss: 0.0005
# Epoch [1/2], Loss epoch: 0.0122, Loss validation: 0.0075, Time remaining: ~0.0h 0.0m 34s
# 	 Validation string, 	 i: 3225; 	 prediction: -0.1559, 	 target: -0.0773, 	 loss: 0.0062
# 	 Validation string, 	 i: 4132; 	 prediction: -0.2958, 	 target: -0.3977, 	 loss: 0.0104
# 	 Validation string, 	 i: 1437; 	 prediction: -0.2729, 	 target: -0.2814, 	 loss: 0.0001
# Epoch [2/2], Loss epoch: 0.0075, Loss validation: 0.0073, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.007214566508779421, std loss: 0.012300805506970583
#
#
#  --- SWEEP POINT 20/20: (2, 20, 5) ---
#  --- time reamining: 00:01:13.00
#
# Epoch [0/2], Loss epoch: 1.5158, Loss validation: 1.5169
# 	 Validation string, 	 i: 3468; 	 prediction: -0.1425, 	 target: -0.1570, 	 loss: 0.0002
# 	 Validation string, 	 i: 4031; 	 prediction: -0.4727, 	 target: -0.5003, 	 loss: 0.0008
# 	 Validation string, 	 i: 3763; 	 prediction: -0.1848, 	 target: -0.2488, 	 loss: 0.0041
# Epoch [1/2], Loss epoch: 0.0081, Loss validation: 0.0049, Time remaining: ~0.0h 0.0m 56s
# 	 Validation string, 	 i: 1398; 	 prediction: -0.3051, 	 target: -0.2293, 	 loss: 0.0057
# 	 Validation string, 	 i: 3963; 	 prediction: -0.4846, 	 target: -0.4961, 	 loss: 0.0001
# 	 Validation string, 	 i: 986; 	 prediction: -0.4317, 	 target: -0.4584, 	 loss: 0.0007
# Epoch [2/2], Loss epoch: 0.0046, Loss validation: 0.0051, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.004966866411113692, std loss: 0.008625118770304498
