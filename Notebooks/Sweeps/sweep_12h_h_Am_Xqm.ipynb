# %%
initial_path = 'peptide-QML'
# initial_path = '..'

# %%
import sys
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import helper_classes as c
from my_code import pytorch_model as m
from my_code import quantum_nodes as q
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.0.4) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
# name of the notebook
name_notebook = "sweep_12h_h_Am_Xqm"

# %%
# sweep = c.Sweep(
#     name_notebook, 
#     initial_path=initial_path,
#     description="Try to find the best measurement and number of layers for the quantum block using Amplitude Encoding.",
#     repetitions=list(range(1, 3)),
#     n_layers_quantum_block=[0,1,2,5,12,20],
#     qubits_measurement=[1, 'all'],
# )

# %%
# sweep.save()

# %%
sweep = c.Sweep.load(file_name=name_notebook+"-1", day='0912', initial_path=initial_path)

# %%
for sweep_point in sweep.points_left:

    # print the point of the sweep
    sweep.print_sweep_status(sweep_point['idx'])

    n_qubits = 4
    if sweep_point['n_layers_quantum_block'] > 0:
        # -- QUANTUM BLOCK -- #
        quantum_layer = q.circuit(
            n_qubits = n_qubits, 
            device = "default.qubit.torch",
            device_options = {'shots': None},
            embedding = q.parts.AmplitudeEmbedding, 
            # embedding_ansatz = q.parts.Ansatz_11,
            block_ansatz = q.parts.Ansatz_11,
            final_ansatz = q.parts.Ansatz_11,
            measurement = q.parts.Measurement('Z', sweep_point['qubits_measurement']),
            # embedding_n_layers = 4,
            # different_inputs_per_layer = True,
            block_n_layers = sweep_point['n_layers_quantum_block'],
            # wrapper_qlayer = pw.QLayerEmpty,
        )
    else:
        quantum_layer = None

    # -- MODEL -- #
    class Model(m.Model):
        def __init__(self):
            super(Model, self).__init__()
            n_qubits_measured = n_qubits if sweep_point['qubits_measurement'] == 'all' else sweep_point['qubits_measurement']
            n_qubits_measured = 2**n_qubits if quantum_layer is None else n_qubits_measured
            self.fc1 = m.nn.Linear(228, 228//2)
            self.fc2 = m.nn.Linear(228//2, 2**n_qubits)
            self.fc3 = quantum_layer() if quantum_layer is not None else None
            self.fc4 = m.nn.Linear(n_qubits_measured, n_qubits_measured) 
            self.fc5 = m.nn.Linear(n_qubits_measured, 1)

        def forward(self, x):
            x = m.torch.sigmoid(self.fc1(x))
            x = m.torch.sigmoid(self.fc2(x))
            if self.fc3 is not None:
                x = self.fc3(x)
            x = m.torch.sigmoid(self.fc4(x))
            x = self.fc5(x)
            return x

    model = Model()

    # set quantum layer
    model.set_quantum_layer(quantum_layer)

    # set the name and path of the model
    model.set_name_and_path(name_notebook, initial_path)

    #set sweep point
    model.set_sweep_point(
        sweep_uuid = sweep.uuid,
        sweep_point = sweep_point,
        day=sweep.day
    )

    # -- TRAIN -- #
    model.optimize_params(
        #save info
        save_model_info = True,
        description = 'sweep with 12 amino acids and 4 qubits using Amplitude Encoding',    
        #data
        data=c.Data.load(initial_path=initial_path, file_name='PET_SCORES_12'),
        # train options
        optimizer = m.optim.Adam,
        optimizer_options = {'lr': 0.01},
        num_epochs = 2,                
        batch_size = 32,
        # early stopping options
        stop_training_options = {
            'lookback_epochs': 5, 
            'threshold_slope': 0.001,
            'threshold_std_dev': 0.2
        },
        # metadata
        metadata = {}
    )

    # -- VALIDATION and PLOTS -- #
    model.plot_losses(fig_size=(6,6))
    model.validate(
        pct=1,
        add_to_results=True,
        plot=True,
        print_items=False
    )

    # -- SAVE RESULTS -- #
    model.save_results()

    # -- ADD DATA GENERATED TO SWEEP -- #
    sweep.add_data(
        idx=sweep_point['idx'],
        model_uuid=model.uuid,
        best_loss_train=model.results.loss_epoch.best,
        best_loss_test=model.results.loss_validation_epoch.best,
        loss_validation=model.mean_loss_validation,
        time_train=model.results.time_epoch.last,
    )
    sweep.save(csv=False) #TODO: save csv=False automatically when sweep is already saved ion csv
# Out:
#  --- SWEEP POINT 21/24: (2, 12, 1) ---
#  --- time reamining: 03:59:24.36
#
# Epoch [0/2], Loss epoch: 0.4713, Loss validation: 0.4719
# /usr/lib/python3/dist-packages/torch/autograd/__init__.py:147: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:240.)
#   Variable._execution_engine.run_backward(
# 	 Validation string, 	 i: 90; 	 prediction: -0.2196, 	 target: -0.1402, 	 loss: 0.0063
# 	 Validation string, 	 i: 3739; 	 prediction: -0.1151, 	 target: -0.1388, 	 loss: 0.0006
# 	 Validation string, 	 i: 1112; 	 prediction: -0.4336, 	 target: -0.4354, 	 loss: 0.0000
# Epoch [1/2], Loss epoch: 0.0045, Loss validation: 0.0027, Time remaining: ~0.0h 36.0m 38s
# 	 Validation string, 	 i: 4080; 	 prediction: -0.4493, 	 target: -0.4377, 	 loss: 0.0001
# 	 Validation string, 	 i: 2178; 	 prediction: -0.2474, 	 target: -0.3072, 	 loss: 0.0036
# 	 Validation string, 	 i: 1229; 	 prediction: -0.0927, 	 target: -0.0864, 	 loss: 0.0000
# Epoch [2/2], Loss epoch: 0.0024, Loss validation: 0.0024, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0023686918218778917, std loss: 0.004468135978900778
#
#
#  --- SWEEP POINT 22/24: (2, 12, 'all') ---
#  --- time reamining: 03:07:08.53
#
# Epoch [0/2], Loss epoch: 0.0220, Loss validation: 0.0221
# 	 Validation string, 	 i: 2344; 	 prediction: -0.3828, 	 target: -0.2628, 	 loss: 0.0144
# 	 Validation string, 	 i: 2097; 	 prediction: -0.4899, 	 target: -0.4939, 	 loss: 0.0000
# 	 Validation string, 	 i: 3691; 	 prediction: -0.3034, 	 target: -0.3032, 	 loss: 0.0000
# Epoch [1/2], Loss epoch: 0.0041, Loss validation: 0.0028, Time remaining: ~0.0h 34.0m 54s
# 	 Validation string, 	 i: 4014; 	 prediction: -0.4133, 	 target: -0.4052, 	 loss: 0.0001
# 	 Validation string, 	 i: 3301; 	 prediction: -0.4993, 	 target: -0.5218, 	 loss: 0.0005
# 	 Validation string, 	 i: 4125; 	 prediction: -0.1543, 	 target: -0.1031, 	 loss: 0.0026
# Epoch [2/2], Loss epoch: 0.0025, Loss validation: 0.0026, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0024781669296770736, std loss: 0.004996633997444028
#
#
#  --- SWEEP POINT 23/24: (2, 20, 1) ---
#  --- time reamining: 02:08:58.38
#
# Epoch [0/2], Loss epoch: 0.3074, Loss validation: 0.3070
# 	 Validation string, 	 i: 856; 	 prediction: -0.4350, 	 target: -0.4308, 	 loss: 0.0000
# 	 Validation string, 	 i: 415; 	 prediction: -0.1126, 	 target: -0.0580, 	 loss: 0.0030
# 	 Validation string, 	 i: 3610; 	 prediction: -0.1038, 	 target: -0.1950, 	 loss: 0.0083
# Epoch [1/2], Loss epoch: 0.0045, Loss validation: 0.0028, Time remaining: ~0.0h 48.0m 15s
# 	 Validation string, 	 i: 2451; 	 prediction: -0.3814, 	 target: -0.3804, 	 loss: 0.0000
# 	 Validation string, 	 i: 3980; 	 prediction: -0.3155, 	 target: -0.3050, 	 loss: 0.0001
# 	 Validation string, 	 i: 3642; 	 prediction: -0.4860, 	 target: -0.5059, 	 loss: 0.0004
# Epoch [2/2], Loss epoch: 0.0025, Loss validation: 0.0024, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.002394130666750873, std loss: 0.00452984698555877
#
#
#  --- SWEEP POINT 24/24: (2, 20, 'all') ---
#  --- time reamining: 01:08:32.63
#
# Epoch [0/2], Loss epoch: 0.1113, Loss validation: 0.1111
# 	 Validation string, 	 i: 2132; 	 prediction: -0.1892, 	 target: -0.1792, 	 loss: 0.0001
# 	 Validation string, 	 i: 1141; 	 prediction: -0.4768, 	 target: -0.5202, 	 loss: 0.0019
# 	 Validation string, 	 i: 4287; 	 prediction: -0.4453, 	 target: -0.4888, 	 loss: 0.0019
# Epoch [1/2], Loss epoch: 0.0039, Loss validation: 0.0029, Time remaining: ~0.0h 44.0m 54s
# 	 Validation string, 	 i: 118; 	 prediction: -0.1473, 	 target: -0.1994, 	 loss: 0.0027
# 	 Validation string, 	 i: 50; 	 prediction: -0.0891, 	 target: -0.0207, 	 loss: 0.0047
# 	 Validation string, 	 i: 992; 	 prediction: -0.1231, 	 target: -0.2255, 	 loss: 0.0105
# Epoch [2/2], Loss epoch: 0.0025, Loss validation: 0.0024, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0024102167373680674, std loss: 0.004622817422098739
