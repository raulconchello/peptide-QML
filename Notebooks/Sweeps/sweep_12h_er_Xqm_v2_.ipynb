# %%
initial_path = 'peptide-QML'
# initial_path = '..'

# %%
import sys
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import helper_classes as c
from my_code import pytorch_model as m
from my_code import quantum_nodes as q

# %%
# name of the notebook
name_notebook = "sweep_12h_er_Xqm_v2"

# %%
# sweep = c.Sweep(
#     name_notebook, 
#     initial_path=initial_path,
#     description="Try to find the best measurement and number of layers for the quantum block using IQPEmbedding-Default (repeating embedding) and embedding.",
#     repetitions=list(range(1, 3)),
#     embedding_dim=[1,5],
#     embedding_n_repetitions=[1,2,3],
# )

# %%
# sweep.save()
# Out:
# Folder 'peptide-QML/saved/Sweeps/0919/' created successfully.

# %%
sweep = c.Sweep.load(file_name=name_notebook+"-2", day='0919', initial_path=initial_path)

# %%
for sweep_point in sweep:

    # print the point of the sweep
    sweep.print_sweep_status(sweep_point['idx'])

    # -- QUANTUM BLOCK -- #
    n_qubits = 6
    quantum_layer = q.circuit(
        n_qubits = n_qubits, 
        device = "default.qubit.torch",
        device_options = {'shots': None},
        embedding = q.parts.IQPEmbedding({
            'n_repeats': sweep_point['embedding_n_repetitions'],
        }),
        # embedding_ansatz = q.parts.Ansatz_11,
        block_ansatz = q.parts.Ansatz_11,
        final_ansatz = q.parts.Ansatz_11, # TODO CHECK IF THIS IS THE BEST OPTION
        measurement = q.parts.Measurement('Z', 'all'),
        # embedding_n_layers = sweep_point['embedding_n_layers'],
        # different_inputs_per_layer = False,
        block_n_layers = 10,
        # wrapper_qlayer = pw.QLayerEmpty,
    )

    # -- MODEL -- #                    
    class Model(m.Model):
        def __init__(self):
            super(Model, self).__init__()
            self.fc1 = m.nn.Embedding(num_embeddings=19, embedding_dim=sweep_point['embedding_dim'])
            self.fc2 = m.Reshape()
            self.fc3 = m.nn.Sequential(*[m.nn.Linear(12*sweep_point['embedding_dim'], 6), m.nn.Sigmoid(), m.nn.Linear(6, 6)])
            self.fc4 = quantum_layer()            
            self.fc5 = m.nn.Sequential(*[m.nn.Linear(6, 6), m.nn.Sigmoid(), m.nn.Linear(6, 1)])

        def forward(self, x):
            for i in range(1,6):
                x = getattr(self, 'fc{}'.format(i))(x)
            return x

    model = Model()

    # set quantum layer
    model.set_quantum_layer(quantum_layer)

    # set the name and path of the model
    model.set_name_and_path(name_notebook, initial_path)

    #set sweep point
    model.set_sweep_point(
        sweep_uuid = sweep.uuid,
        sweep_point = sweep_point,
        day=sweep.day
    )

    # -- TRAIN -- #
    model.optimize_params(
        #save info
        save_model_info = True,
        description = 'sweep with 12 amino acids and {} qubits using IQPEmbedding (repeating embedding) and classical Embedding'.format(n_qubits),    
        #data
        data=c.Data.load(initial_path=initial_path, file_name='PET_SCORES_12_Numbers_int'),
        # train options
        optimizer = m.optim.Adam,
        optimizer_options = {'lr': 0.01},
        num_epochs = 2,                
        batch_size = 32,
        # early stopping options
        stop_training_options = {
            'lookback_epochs': 5, 
            'threshold_slope': 0.001,
            'threshold_std_dev': 0.2
        },
        # metadata
        metadata = {}
    )

    # -- VALIDATION and PLOTS -- #
    model.plot_losses(fig_size=(6,6))
    model.validate(
        pct=1,
        add_to_results=True,
        plot=True,
        print_items=False
    )

    # -- SAVE RESULTS -- #
    model.save_results()

    # -- ADD DATA GENERATED TO SWEEP -- #
    sweep.add_data(
        idx=sweep_point['idx'],
        model_uuid=model.uuid,
        best_loss_train=model.results.loss_epoch.best,
        best_loss_test=model.results.loss_validation_epoch.best,
        loss_validation=model.mean_loss_validation,
        n_parameters=model.n_parameters,
        time_train=model.results.time_epoch.last,
    )
    sweep.save(csv=False) #TODO: save csv=False automatically when sweep is already saved ion csv
# Out:
#  --- SWEEP POINT 1/12: (1, 1, 1) ---
#  --- parameters sweeping: ['repetitions', 'embedding_dim', 'embedding_n_repetitions']
#
# Folder 'peptide-QML/saved/Models/0919/' created successfully.
# Epoch [0/2], Loss epoch: 0.2506, Loss validation: 0.2510
# 	 Validation string, 	 i: 3747; 	 prediction: -0.1144, 	 target: -0.3149, 	 loss: 0.0402
# 	 Validation string, 	 i: 1493; 	 prediction: -0.3878, 	 target: -0.3232, 	 loss: 0.0042
# 	 Validation string, 	 i: 3832; 	 prediction: -0.3128, 	 target: -0.3857, 	 loss: 0.0053
# Epoch [1/2], Loss epoch: 0.0076, Loss validation: 0.0069, Time remaining: ~0.0h 31.0m 26s
# 	 Validation string, 	 i: 2095; 	 prediction: -0.1094, 	 target: -0.0938, 	 loss: 0.0002
# 	 Validation string, 	 i: 1090; 	 prediction: -0.3876, 	 target: -0.4238, 	 loss: 0.0013
# 	 Validation string, 	 i: 3994; 	 prediction: -0.1866, 	 target: -0.2510, 	 loss: 0.0041
# Epoch [2/2], Loss epoch: 0.0071, Loss validation: 0.0072, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.007097990747185721, std loss: 0.011518792166009402
# Folder 'peptide-QML/saved/Results/0919/' created successfully.
#
#
#  --- SWEEP POINT 2/12: (1, 1, 2) ---
#  --- time reamining: 22:03:39.55
#
# Epoch [0/2], Loss epoch: 0.0209, Loss validation: 0.0210
# 	 Validation string, 	 i: 191; 	 prediction: -0.1997, 	 target: -0.2014, 	 loss: 0.0000
# 	 Validation string, 	 i: 159; 	 prediction: -0.4127, 	 target: -0.3028, 	 loss: 0.0121
# 	 Validation string, 	 i: 1829; 	 prediction: -0.2628, 	 target: -0.2386, 	 loss: 0.0006
# Epoch [1/2], Loss epoch: 0.0077, Loss validation: 0.0071, Time remaining: ~0.0h 31.0m 58s
# 	 Validation string, 	 i: 1492; 	 prediction: -0.1362, 	 target: -0.0742, 	 loss: 0.0038
# 	 Validation string, 	 i: 2918; 	 prediction: -0.4706, 	 target: -0.4854, 	 loss: 0.0002
# 	 Validation string, 	 i: 118; 	 prediction: -0.2890, 	 target: -0.1994, 	 loss: 0.0080
# Epoch [2/2], Loss epoch: 0.0073, Loss validation: 0.0071, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.007062559684302061, std loss: 0.011473553415843562
#
#
#  --- SWEEP POINT 3/12: (1, 1, 3) ---
#  --- time reamining: 19:54:24.56
#
# Epoch [0/2], Loss epoch: 0.0578, Loss validation: 0.0580
# 	 Validation string, 	 i: 1649; 	 prediction: -0.2062, 	 target: -0.1386, 	 loss: 0.0046
# 	 Validation string, 	 i: 2549; 	 prediction: -0.4676, 	 target: -0.4644, 	 loss: 0.0000
# 	 Validation string, 	 i: 2034; 	 prediction: -0.3552, 	 target: -0.3982, 	 loss: 0.0019
# Epoch [1/2], Loss epoch: 0.0076, Loss validation: 0.0079, Time remaining: ~0.0h 31.0m 19s
# 	 Validation string, 	 i: 3726; 	 prediction: -0.3802, 	 target: -0.4864, 	 loss: 0.0113
# 	 Validation string, 	 i: 3840; 	 prediction: -0.1948, 	 target: -0.1479, 	 loss: 0.0022
# 	 Validation string, 	 i: 2912; 	 prediction: -0.1034, 	 target: -0.1627, 	 loss: 0.0035
# Epoch [2/2], Loss epoch: 0.0071, Loss validation: 0.0072, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.007072094667334007, std loss: 0.011396228208938571
#
#
#  --- SWEEP POINT 4/12: (1, 5, 1) ---
#  --- time reamining: 17:48:10.61
#
# Epoch [0/2], Loss epoch: 0.3351, Loss validation: 0.3357
# 	 Validation string, 	 i: 616; 	 prediction: -0.2170, 	 target: -0.1503, 	 loss: 0.0044
# 	 Validation string, 	 i: 771; 	 prediction: -0.3742, 	 target: -0.4224, 	 loss: 0.0023
# 	 Validation string, 	 i: 1463; 	 prediction: -0.1496, 	 target: -0.2050, 	 loss: 0.0031
# Epoch [1/2], Loss epoch: 0.0066, Loss validation: 0.0058, Time remaining: ~0.0h 29.0m 27s
# 	 Validation string, 	 i: 1164; 	 prediction: -0.4458, 	 target: -0.4163, 	 loss: 0.0009
# 	 Validation string, 	 i: 4394; 	 prediction: -0.4041, 	 target: -0.2718, 	 loss: 0.0175
# 	 Validation string, 	 i: 1513; 	 prediction: -0.3559, 	 target: -0.4214, 	 loss: 0.0043
# Epoch [2/2], Loss epoch: 0.0060, Loss validation: 0.0060, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.005908451796371214, std loss: 0.010618878421467968
#
#
#  --- SWEEP POINT 5/12: (1, 5, 2) ---
#  --- time reamining: 15:36:50.03
#
# Epoch [0/2], Loss epoch: 0.1630, Loss validation: 0.1634
# 	 Validation string, 	 i: 4154; 	 prediction: -0.0882, 	 target: -0.0508, 	 loss: 0.0014
# 	 Validation string, 	 i: 2142; 	 prediction: -0.1946, 	 target: -0.0326, 	 loss: 0.0262
# 	 Validation string, 	 i: 2407; 	 prediction: -0.4479, 	 target: -0.2223, 	 loss: 0.0509
# Epoch [1/2], Loss epoch: 0.0067, Loss validation: 0.0058, Time remaining: ~0.0h 29.0m 51s
# 	 Validation string, 	 i: 2646; 	 prediction: -0.1958, 	 target: -0.2742, 	 loss: 0.0062
# 	 Validation string, 	 i: 4122; 	 prediction: -0.4646, 	 target: -0.4964, 	 loss: 0.0010
# 	 Validation string, 	 i: 3938; 	 prediction: -0.2534, 	 target: -0.2305, 	 loss: 0.0005
# Epoch [2/2], Loss epoch: 0.0060, Loss validation: 0.0060, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0059519587203289825, std loss: 0.009352642550362205
#
#
#  --- SWEEP POINT 6/12: (1, 5, 3) ---
#  --- time reamining: 13:36:05.67
#
# Epoch [0/2], Loss epoch: 0.0238, Loss validation: 0.0238
# 	 Validation string, 	 i: 3048; 	 prediction: -0.4572, 	 target: -0.4185, 	 loss: 0.0015
# 	 Validation string, 	 i: 1631; 	 prediction: -0.1956, 	 target: -0.2163, 	 loss: 0.0004
# 	 Validation string, 	 i: 539; 	 prediction: -0.1332, 	 target: -0.2094, 	 loss: 0.0058
# Epoch [1/2], Loss epoch: 0.0064, Loss validation: 0.0064, Time remaining: ~0.0h 30.0m 34s
# 	 Validation string, 	 i: 1854; 	 prediction: -0.1702, 	 target: -0.0790, 	 loss: 0.0083
# 	 Validation string, 	 i: 3183; 	 prediction: -0.2841, 	 target: -0.2499, 	 loss: 0.0012
# 	 Validation string, 	 i: 3450; 	 prediction: -0.3055, 	 target: -0.3330, 	 loss: 0.0008
# Epoch [2/2], Loss epoch: 0.0059, Loss validation: 0.0057, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.005694317545083935, std loss: 0.009638467910982072
#
#
#  --- SWEEP POINT 7/12: (2, 1, 1) ---
#  --- time reamining: 11:39:20.69
#
# Epoch [0/2], Loss epoch: 0.2019, Loss validation: 0.2023
# 	 Validation string, 	 i: 1946; 	 prediction: -0.1681, 	 target: -0.1575, 	 loss: 0.0001
# 	 Validation string, 	 i: 4102; 	 prediction: -0.3258, 	 target: -0.2771, 	 loss: 0.0024
# 	 Validation string, 	 i: 4254; 	 prediction: -0.1780, 	 target: 0.0101, 	 loss: 0.0354
# Epoch [1/2], Loss epoch: 0.0078, Loss validation: 0.0076, Time remaining: ~0.0h 29.0m 6s
# 	 Validation string, 	 i: 4155; 	 prediction: -0.3296, 	 target: -0.2261, 	 loss: 0.0107
# 	 Validation string, 	 i: 3938; 	 prediction: -0.2320, 	 target: -0.2305, 	 loss: 0.0000
# 	 Validation string, 	 i: 3749; 	 prediction: -0.3945, 	 target: -0.2942, 	 loss: 0.0101
# Epoch [2/2], Loss epoch: 0.0072, Loss validation: 0.0070, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.006878385308490133, std loss: 0.011333556871827636
#
#
#  --- SWEEP POINT 8/12: (2, 1, 2) ---
#  --- time reamining: 09:39:11.48
#
# Epoch [0/2], Loss epoch: 0.3886, Loss validation: 0.3892
# 	 Validation string, 	 i: 2017; 	 prediction: -0.4229, 	 target: -0.4881, 	 loss: 0.0043
# 	 Validation string, 	 i: 637; 	 prediction: -0.2727, 	 target: -0.3743, 	 loss: 0.0103
# 	 Validation string, 	 i: 2002; 	 prediction: -0.4273, 	 target: -0.4424, 	 loss: 0.0002
# Epoch [1/2], Loss epoch: 0.0079, Loss validation: 0.0071, Time remaining: ~0.0h 30.0m 33s
# 	 Validation string, 	 i: 3531; 	 prediction: -0.1289, 	 target: -0.0891, 	 loss: 0.0016
# 	 Validation string, 	 i: 4311; 	 prediction: -0.4120, 	 target: -0.4295, 	 loss: 0.0003
# 	 Validation string, 	 i: 4207; 	 prediction: -0.1041, 	 target: -0.1777, 	 loss: 0.0054
# Epoch [2/2], Loss epoch: 0.0072, Loss validation: 0.0070, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0069098343747672816, std loss: 0.011492029905028341
#
#
#  --- SWEEP POINT 9/12: (2, 1, 3) ---
#  --- time reamining: 07:42:24.10
#
# Epoch [0/2], Loss epoch: 0.1015, Loss validation: 0.1018
# 	 Validation string, 	 i: 3201; 	 prediction: -0.3673, 	 target: -0.4163, 	 loss: 0.0024
# 	 Validation string, 	 i: 391; 	 prediction: -0.1791, 	 target: -0.4078, 	 loss: 0.0523
# 	 Validation string, 	 i: 1753; 	 prediction: -0.1569, 	 target: -0.1709, 	 loss: 0.0002
# Epoch [1/2], Loss epoch: 0.0077, Loss validation: 0.0072, Time remaining: ~0.0h 31.0m 25s
# 	 Validation string, 	 i: 2330; 	 prediction: -0.3706, 	 target: -0.5100, 	 loss: 0.0194
# 	 Validation string, 	 i: 4412; 	 prediction: -0.2255, 	 target: -0.2641, 	 loss: 0.0015
# 	 Validation string, 	 i: 3327; 	 prediction: -0.3995, 	 target: -0.4199, 	 loss: 0.0004
# Epoch [2/2], Loss epoch: 0.0071, Loss validation: 0.0069, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.006771794668103723, std loss: 0.011041122439824838
#
#
#  --- SWEEP POINT 10/12: (2, 5, 1) ---
#  --- time reamining: 05:47:08.97
#
# Epoch [0/2], Loss epoch: 0.0206, Loss validation: 0.0207
# 	 Validation string, 	 i: 2266; 	 prediction: -0.4366, 	 target: -0.4660, 	 loss: 0.0009
# 	 Validation string, 	 i: 569; 	 prediction: -0.2288, 	 target: -0.3306, 	 loss: 0.0104
# 	 Validation string, 	 i: 1203; 	 prediction: -0.1656, 	 target: -0.1059, 	 loss: 0.0036
# Epoch [1/2], Loss epoch: 0.0064, Loss validation: 0.0061, Time remaining: ~0.0h 29.0m 56s
# 	 Validation string, 	 i: 3156; 	 prediction: -0.1343, 	 target: -0.0430, 	 loss: 0.0083
# 	 Validation string, 	 i: 85; 	 prediction: -0.1601, 	 target: -0.1763, 	 loss: 0.0003
# 	 Validation string, 	 i: 1753; 	 prediction: -0.1669, 	 target: -0.1709, 	 loss: 0.0000
# Epoch [2/2], Loss epoch: 0.0060, Loss validation: 0.0058, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0058601159824260484, std loss: 0.010257537340343353
#
#
#  --- SWEEP POINT 11/12: (2, 5, 2) ---
#  --- time reamining: 03:50:50.14
#
# Epoch [0/2], Loss epoch: 0.1795, Loss validation: 0.1791
# 	 Validation string, 	 i: 3693; 	 prediction: -0.2124, 	 target: -0.1582, 	 loss: 0.0029
# 	 Validation string, 	 i: 1823; 	 prediction: -0.1373, 	 target: -0.1751, 	 loss: 0.0014
# 	 Validation string, 	 i: 4391; 	 prediction: -0.1459, 	 target: -0.0790, 	 loss: 0.0045
# Epoch [1/2], Loss epoch: 0.0065, Loss validation: 0.0058, Time remaining: ~0.0h 29.0m 53s
# 	 Validation string, 	 i: 1314; 	 prediction: -0.3476, 	 target: -0.4163, 	 loss: 0.0047
# 	 Validation string, 	 i: 3122; 	 prediction: -0.4845, 	 target: -0.5675, 	 loss: 0.0069
# 	 Validation string, 	 i: 2707; 	 prediction: -0.2407, 	 target: -0.3205, 	 loss: 0.0064
# Epoch [2/2], Loss epoch: 0.0059, Loss validation: 0.0057, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.005663261245790628, std loss: 0.009257532279628727
#
#
#  --- SWEEP POINT 12/12: (2, 5, 3) ---
#  --- time reamining: 01:55:20.35
#
# Epoch [0/2], Loss epoch: 0.0535, Loss validation: 0.0534
# 	 Validation string, 	 i: 1476; 	 prediction: -0.4420, 	 target: -0.3907, 	 loss: 0.0026
# 	 Validation string, 	 i: 2586; 	 prediction: -0.4322, 	 target: -0.4829, 	 loss: 0.0026
# 	 Validation string, 	 i: 3711; 	 prediction: -0.1647, 	 target: -0.1997, 	 loss: 0.0012
# Epoch [1/2], Loss epoch: 0.0064, Loss validation: 0.0057, Time remaining: ~0.0h 31.0m 17s
# 	 Validation string, 	 i: 2649; 	 prediction: -0.1699, 	 target: -0.1174, 	 loss: 0.0028
# 	 Validation string, 	 i: 3218; 	 prediction: -0.2609, 	 target: -0.2276, 	 loss: 0.0011
# 	 Validation string, 	 i: 2348; 	 prediction: -0.2795, 	 target: -0.3320, 	 loss: 0.0028
# Epoch [2/2], Loss epoch: 0.0060, Loss validation: 0.0059, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.005928669910464256, std loss: 0.009183096321038574
