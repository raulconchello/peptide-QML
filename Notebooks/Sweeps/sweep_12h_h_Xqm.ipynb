# %%
initial_path = 'peptide-QML'
# initial_path = '..'

# %%
import sys
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import helper_classes as c
from my_code import pytorch_model as m
from my_code import quantum_nodes as q
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.0.4) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
# name of the notebook
name_notebook = "sweep_12h_h_Xqm"

# %%
sweep = c.Sweep(
    name_notebook, 
    initial_path=initial_path,
    description="4 qubits. Try to find the best measurement and number of layers for the quantum block.",
    repetitions=list(range(1, 3)),
    n_layers_quantum_block=[0,1,2,5,12,20],
    qubits_measurement=[1, 'all'],
)

# %%
sweep.save()

# %%
for sweep_point in sweep:

    # print the point of the sweep
    sweep.print_sweep_status(sweep_point['idx'])

    
    n_qubits = 4
    if sweep_point['n_layers_quantum_block'] > 0:
        # -- QUANTUM BLOCK -- #
        quantum_layer = q.circuit(
            n_qubits = n_qubits, 
            device = "default.qubit.torch",
            device_options = {'shots': None},
            embedding = q.parts.AngleEmbedding, 
            # embedding_ansatz = q.parts.Ansatz_11,
            block_ansatz = q.parts.Ansatz_11,
            final_ansatz = q.parts.Ansatz_11,
            measurement = q.parts.Measurement('Z', sweep_point['qubits_measurement']),
            # embedding_n_layers = 4,
            # different_inputs_per_layer = True,
            block_n_layers = sweep_point['n_layers_quantum_block'],
            # wrapper_qlayer = pw.QLayerEmpty,
        )
    else:
        quantum_layer = None

    # -- MODEL -- #
    class Model(m.Model):
        def __init__(self):
            super(Model, self).__init__()
            n_qubits_measured = n_qubits if sweep_point['qubits_measurement'] == 'all' else sweep_point['qubits_measurement']
            n_qubits_measured = n_qubits if quantum_layer is None else n_qubits_measured
            self.fc1 = m.nn.Linear(228, 228//2)
            self.fc2 = m.nn.Linear(228//2, n_qubits)
            self.fc3 = quantum_layer() if quantum_layer is not None else None
            self.fc4 = m.nn.Linear(n_qubits_measured, n_qubits_measured) 
            self.fc5 = m.nn.Linear(n_qubits_measured, 1)

        def forward(self, x):
            x = m.torch.sigmoid(self.fc1(x))
            x = m.torch.sigmoid(self.fc2(x))
            if self.fc3 is not None:
                x = self.fc3(x)
            x = m.torch.sigmoid(self.fc4(x))
            x = self.fc5(x)
            return x

    model = Model()

    # set quantum layer
    model.set_quantum_layer(quantum_layer)

    # set the name and path of the model
    model.set_name_and_path(name_notebook, initial_path)

    #set sweep point
    model.set_sweep_point(
        sweep_uuid = sweep.uuid,
        sweep_point = sweep_point,
        day=sweep.day
    )

    # -- TRAIN -- #
    model.optimize_params(
        #save info
        save_model_info = True,
        description = 'sweep test with 12 amino acids and clasical QML',    
        #data
        data=c.Data.load(initial_path=initial_path, file_name='PET_SCORES_12'),
        # train options
        optimizer = m.optim.Adam,
        optimizer_options = {'lr': 0.01},
        num_epochs = 2,                
        batch_size = 32,
        # early stopping options
        stop_training_options = {
            'lookback_epochs': 5, 
            'threshold_slope': 0.001,
            'threshold_std_dev': 0.2
        },
        # metadata
        metadata = {}
    )

    # -- VALIDATION and PLOTS -- #
    model.plot_losses(fig_size=(6,6))
    model.validate(
        pct=1,
        add_to_results=True,
        plot=True,
        print_items=False
    )

    # -- SAVE RESULTS -- #
    model.save_results()

    # -- ADD DATA GENERATED TO SWEEP -- #
    sweep.add_data(
        idx=sweep_point['idx'],
        model_uuid=model.uuid,
        best_loss_train=model.results.loss_epoch.best,
        best_loss_test=model.results.loss_validation_epoch.best,
        loss_validation=model.mean_loss_validation,
        time_train=model.results.time_epoch.last,
    )
    sweep.save(csv=False) #TODO: save csv=False automatically when sweep is already saved ion csv
# Out:
#  --- SWEEP POINT 1/24: (1, 0, 1) ---
#  --- parameters sweeping: ['repetitions', 'n_layers_quantum_block', 'qubits_measurement']
#
# Epoch [0/2], Loss epoch: 0.2360, Loss validation: 0.2356
# 	 Validation string, 	 i: 201; 	 prediction: -0.4676, 	 target: -0.4415, 	 loss: 0.0007
# 	 Validation string, 	 i: 2261; 	 prediction: -0.3482, 	 target: -0.3387, 	 loss: 0.0001
# 	 Validation string, 	 i: 234; 	 prediction: -0.4873, 	 target: -0.3955, 	 loss: 0.0084
# Epoch [1/2], Loss epoch: 0.0047, Loss validation: 0.0028, Time remaining: ~0.0h 5.0m 59s
# 	 Validation string, 	 i: 334; 	 prediction: -0.2955, 	 target: -0.2680, 	 loss: 0.0008
# 	 Validation string, 	 i: 3373; 	 prediction: -0.4432, 	 target: -0.4312, 	 loss: 0.0001
# 	 Validation string, 	 i: 57; 	 prediction: -0.2488, 	 target: -0.2086, 	 loss: 0.0016
# Epoch [2/2], Loss epoch: 0.0025, Loss validation: 0.0024, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.002404176736733443, std loss: 0.004794096811726124
#
#
#  --- SWEEP POINT 2/24: (1, 0, 'all') ---
#  --- time reamining: 04:50:07.22
#
# Epoch [0/2], Loss epoch: 0.1118, Loss validation: 0.1116
# 	 Validation string, 	 i: 1609; 	 prediction: -0.2300, 	 target: -0.1907, 	 loss: 0.0015
# 	 Validation string, 	 i: 1509; 	 prediction: -0.1845, 	 target: -0.1587, 	 loss: 0.0007
# 	 Validation string, 	 i: 3251; 	 prediction: -0.1218, 	 target: -0.1595, 	 loss: 0.0014
# Epoch [1/2], Loss epoch: 0.0043, Loss validation: 0.0028, Time remaining: ~0.0h 5.0m 25s
# 	 Validation string, 	 i: 1583; 	 prediction: -0.3116, 	 target: -0.3572, 	 loss: 0.0021
# 	 Validation string, 	 i: 4095; 	 prediction: -0.3382, 	 target: -0.3409, 	 loss: 0.0000
# 	 Validation string, 	 i: 1117; 	 prediction: -0.4162, 	 target: -0.4239, 	 loss: 0.0001
# Epoch [2/2], Loss epoch: 0.0024, Loss validation: 0.0024, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.002331647753790892, std loss: 0.004620927479814087
#
#
#  --- SWEEP POINT 3/24: (1, 1, 1) ---
#  --- time reamining: 04:10:15.52
#
# Epoch [0/2], Loss epoch: 0.2207, Loss validation: 0.2211
# 	 Validation string, 	 i: 362; 	 prediction: -0.1730, 	 target: -0.1484, 	 loss: 0.0006
# 	 Validation string, 	 i: 1383; 	 prediction: -0.3466, 	 target: -0.3819, 	 loss: 0.0012
# 	 Validation string, 	 i: 2739; 	 prediction: -0.1663, 	 target: -0.0705, 	 loss: 0.0092
# Epoch [1/2], Loss epoch: 0.0161, Loss validation: 0.0035, Time remaining: ~0.0h 34.0m 60s
# 	 Validation string, 	 i: 2945; 	 prediction: -0.1983, 	 target: -0.1786, 	 loss: 0.0004
# 	 Validation string, 	 i: 2674; 	 prediction: -0.2786, 	 target: -0.3169, 	 loss: 0.0015
# 	 Validation string, 	 i: 1957; 	 prediction: -0.5073, 	 target: -0.4840, 	 loss: 0.0005
# Epoch [2/2], Loss epoch: 0.0029, Loss validation: 0.0027, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.002635911586967187, std loss: 0.005259582162558157
#
#
#  --- SWEEP POINT 4/24: (1, 1, 'all') ---
#  --- time reamining: 10:39:32.98
#
# Epoch [0/2], Loss epoch: 0.0765, Loss validation: 0.0768
# 	 Validation string, 	 i: 3528; 	 prediction: -0.3828, 	 target: -0.3756, 	 loss: 0.0001
# 	 Validation string, 	 i: 1699; 	 prediction: -0.2228, 	 target: -0.0822, 	 loss: 0.0198
# 	 Validation string, 	 i: 1985; 	 prediction: -0.4633, 	 target: -0.4245, 	 loss: 0.0015
# Epoch [1/2], Loss epoch: 0.0041, Loss validation: 0.0026, Time remaining: ~0.0h 16.0m 14s
# 	 Validation string, 	 i: 4377; 	 prediction: -0.4329, 	 target: -0.4684, 	 loss: 0.0013
# 	 Validation string, 	 i: 981; 	 prediction: -0.4559, 	 target: -0.4723, 	 loss: 0.0003
# 	 Validation string, 	 i: 198; 	 prediction: -0.3871, 	 target: -0.4296, 	 loss: 0.0018
# Epoch [2/2], Loss epoch: 0.0025, Loss validation: 0.0024, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.002361750060297876, std loss: 0.004720200008208439
#
#
#  --- SWEEP POINT 5/24: (1, 2, 1) ---
#  --- time reamining: 12:51:26.58
#
# Epoch [0/2], Loss epoch: 1.8286, Loss validation: 1.8298
# 	 Validation string, 	 i: 15; 	 prediction: -0.2399, 	 target: -0.2871, 	 loss: 0.0022
# 	 Validation string, 	 i: 945; 	 prediction: -0.2382, 	 target: -0.2505, 	 loss: 0.0002
# 	 Validation string, 	 i: 3574; 	 prediction: -0.4434, 	 target: -0.4170, 	 loss: 0.0007
# Epoch [1/2], Loss epoch: 0.0113, Loss validation: 0.0027, Time remaining: ~0.0h 35.0m 25s
# 	 Validation string, 	 i: 2805; 	 prediction: -0.0730, 	 target: -0.0321, 	 loss: 0.0017
# 	 Validation string, 	 i: 1163; 	 prediction: -0.1707, 	 target: -0.1568, 	 loss: 0.0002
# 	 Validation string, 	 i: 3373; 	 prediction: -0.4463, 	 target: -0.4312, 	 loss: 0.0002
# Epoch [2/2], Loss epoch: 0.0025, Loss validation: 0.0025, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0024382032041478487, std loss: 0.004797008466491354
#
#
#  --- SWEEP POINT 6/24: (1, 2, 'all') ---
#  --- time reamining: 13:56:14.98
#
# Epoch [0/2], Loss epoch: 0.1492, Loss validation: 0.1495
# 	 Validation string, 	 i: 2285; 	 prediction: -0.2628, 	 target: -0.2967, 	 loss: 0.0011
# 	 Validation string, 	 i: 2634; 	 prediction: -0.4330, 	 target: -0.4265, 	 loss: 0.0000
# 	 Validation string, 	 i: 2724; 	 prediction: -0.3536, 	 target: -0.2569, 	 loss: 0.0093
# Epoch [1/2], Loss epoch: 0.0044, Loss validation: 0.0026, Time remaining: ~0.0h 33.0m 58s
# 	 Validation string, 	 i: 3542; 	 prediction: -0.5770, 	 target: -0.5776, 	 loss: 0.0000
# 	 Validation string, 	 i: 2385; 	 prediction: -0.1891, 	 target: -0.1924, 	 loss: 0.0000
# 	 Validation string, 	 i: 3698; 	 prediction: -0.3878, 	 target: -0.4513, 	 loss: 0.0040
# Epoch [2/2], Loss epoch: 0.0024, Loss validation: 0.0024, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0023488993993105688, std loss: 0.004845213710676421
#
#
#  --- SWEEP POINT 7/24: (1, 5, 1) ---
#  --- time reamining: 13:59:14.81
#
# Epoch [0/2], Loss epoch: 0.3668, Loss validation: 0.3673
# 	 Validation string, 	 i: 2711; 	 prediction: -0.2992, 	 target: -0.3377, 	 loss: 0.0015
# 	 Validation string, 	 i: 819; 	 prediction: -0.3408, 	 target: -0.3725, 	 loss: 0.0010
# 	 Validation string, 	 i: 1628; 	 prediction: -0.3872, 	 target: -0.3942, 	 loss: 0.0000
# Epoch [1/2], Loss epoch: 0.0067, Loss validation: 0.0028, Time remaining: ~0.0h 40.0m 19s
# 	 Validation string, 	 i: 3836; 	 prediction: -0.3814, 	 target: -0.4172, 	 loss: 0.0013
# 	 Validation string, 	 i: 2742; 	 prediction: -0.1137, 	 target: -0.1369, 	 loss: 0.0005
# 	 Validation string, 	 i: 4051; 	 prediction: -0.2439, 	 target: -0.1593, 	 loss: 0.0072
# Epoch [2/2], Loss epoch: 0.0025, Loss validation: 0.0025, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.002414238459076014, std loss: 0.0045273995975862675
#
#
#  --- SWEEP POINT 8/24: (1, 5, 'all') ---
#  --- time reamining: 14:40:15.66
#
# Epoch [0/2], Loss epoch: 0.5641, Loss validation: 0.5648
# 	 Validation string, 	 i: 4234; 	 prediction: -0.3385, 	 target: -0.3859, 	 loss: 0.0022
# 	 Validation string, 	 i: 2958; 	 prediction: -0.2714, 	 target: -0.2903, 	 loss: 0.0004
# 	 Validation string, 	 i: 2225; 	 prediction: -0.4281, 	 target: -0.4728, 	 loss: 0.0020
# Epoch [1/2], Loss epoch: 0.0195, Loss validation: 0.0052, Time remaining: ~0.0h 33.0m 42s
# 	 Validation string, 	 i: 1614; 	 prediction: -0.4171, 	 target: -0.4142, 	 loss: 0.0000
# 	 Validation string, 	 i: 468; 	 prediction: -0.1383, 	 target: -0.1526, 	 loss: 0.0002
# 	 Validation string, 	 i: 3485; 	 prediction: -0.2991, 	 target: -0.3219, 	 loss: 0.0005
# Epoch [2/2], Loss epoch: 0.0035, Loss validation: 0.0029, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.002823730786361926, std loss: 0.005423493934467691
#
#
#  --- SWEEP POINT 9/24: (1, 12, 1) ---
#  --- time reamining: 14:44:49.30
#
# Epoch [0/2], Loss epoch: 0.2087, Loss validation: 0.2091
# 	 Validation string, 	 i: 1608; 	 prediction: -0.4574, 	 target: -0.4523, 	 loss: 0.0000
# 	 Validation string, 	 i: 3460; 	 prediction: -0.2372, 	 target: -0.1923, 	 loss: 0.0020
# 	 Validation string, 	 i: 2679; 	 prediction: -0.2844, 	 target: -0.2609, 	 loss: 0.0006
# Epoch [1/2], Loss epoch: 0.0043, Loss validation: 0.0034, Time remaining: ~0.0h 36.0m 34s
# 	 Validation string, 	 i: 4179; 	 prediction: -0.5514, 	 target: -0.6307, 	 loss: 0.0063
# 	 Validation string, 	 i: 1686; 	 prediction: -0.1427, 	 target: -0.1554, 	 loss: 0.0002
# 	 Validation string, 	 i: 881; 	 prediction: -0.1104, 	 target: -0.1405, 	 loss: 0.0009
# Epoch [2/2], Loss epoch: 0.0025, Loss validation: 0.0025, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0024625644730811003, std loss: 0.004525922921440085
#
#
#  --- SWEEP POINT 10/24: (1, 12, 'all') ---
#  --- time reamining: 15:28:22.07
#
# Folder 'peptide-QML/saved/Models/0913/' created successfully.
# Epoch [0/2], Loss epoch: 0.1304, Loss validation: 0.1307
# 	 Validation string, 	 i: 2833; 	 prediction: -0.3841, 	 target: -0.4985, 	 loss: 0.0131
# 	 Validation string, 	 i: 2072; 	 prediction: -0.1058, 	 target: -0.1098, 	 loss: 0.0000
# 	 Validation string, 	 i: 2749; 	 prediction: -0.1656, 	 target: -0.2632, 	 loss: 0.0095
# Epoch [1/2], Loss epoch: 0.0045, Loss validation: 0.0029, Time remaining: ~0.0h 38.0m 49s
# 	 Validation string, 	 i: 1076; 	 prediction: -0.2177, 	 target: -0.1113, 	 loss: 0.0113
# 	 Validation string, 	 i: 299; 	 prediction: -0.2391, 	 target: -0.2981, 	 loss: 0.0035
# 	 Validation string, 	 i: 1764; 	 prediction: -0.1070, 	 target: -0.0892, 	 loss: 0.0003
# Epoch [2/2], Loss epoch: 0.0026, Loss validation: 0.0025, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0024928934148348712, std loss: 0.004502126916984301
# Folder 'peptide-QML/saved/Results/0913/' created successfully.
#
#
#  --- SWEEP POINT 11/24: (1, 20, 1) ---
#  --- time reamining: 15:43:15.46
#
# Epoch [0/2], Loss epoch: 1.4809, Loss validation: 1.4820
# 	 Validation string, 	 i: 2633; 	 prediction: -0.1107, 	 target: -0.0747, 	 loss: 0.0013
# 	 Validation string, 	 i: 1591; 	 prediction: -0.2187, 	 target: -0.2437, 	 loss: 0.0006
# 	 Validation string, 	 i: 2696; 	 prediction: -0.1025, 	 target: -0.0294, 	 loss: 0.0053
# Epoch [1/2], Loss epoch: 0.0072, Loss validation: 0.0028, Time remaining: ~0.0h 39.0m 54s
# 	 Validation string, 	 i: 3521; 	 prediction: -0.4267, 	 target: -0.3534, 	 loss: 0.0054
# 	 Validation string, 	 i: 1409; 	 prediction: -0.2470, 	 target: -0.3528, 	 loss: 0.0112
# 	 Validation string, 	 i: 3295; 	 prediction: -0.3674, 	 target: -0.3416, 	 loss: 0.0007
# Epoch [2/2], Loss epoch: 0.0026, Loss validation: 0.0024, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.00240044985753895, std loss: 0.00478850041119579
#
#
#  --- SWEEP POINT 12/24: (1, 20, 'all') ---
#  --- time reamining: 16:12:51.68
#
# Epoch [0/2], Loss epoch: 0.0491, Loss validation: 0.0492
# 	 Validation string, 	 i: 202; 	 prediction: -0.1051, 	 target: 0.0091, 	 loss: 0.0130
# 	 Validation string, 	 i: 4050; 	 prediction: -0.2152, 	 target: -0.3352, 	 loss: 0.0144
# 	 Validation string, 	 i: 195; 	 prediction: -0.1612, 	 target: -0.1476, 	 loss: 0.0002
# Epoch [1/2], Loss epoch: 0.0044, Loss validation: 0.0030, Time remaining: ~0.0h 40.0m 5s
# 	 Validation string, 	 i: 3888; 	 prediction: -0.1989, 	 target: -0.2248, 	 loss: 0.0007
# 	 Validation string, 	 i: 3989; 	 prediction: -0.0823, 	 target: -0.0839, 	 loss: 0.0000
# 	 Validation string, 	 i: 3320; 	 prediction: -0.1811, 	 target: -0.1402, 	 loss: 0.0017
# Epoch [2/2], Loss epoch: 0.0026, Loss validation: 0.0025, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0025235838490516296, std loss: 0.004630627915477449
#
#
#  --- SWEEP POINT 13/24: (2, 0, 1) ---
#  --- time reamining: 16:41:28.71
#
# Epoch [0/2], Loss epoch: 0.4416, Loss validation: 0.4422
# 	 Validation string, 	 i: 3702; 	 prediction: -0.4924, 	 target: -0.5021, 	 loss: 0.0001
# 	 Validation string, 	 i: 1468; 	 prediction: -0.5259, 	 target: -0.5352, 	 loss: 0.0001
# 	 Validation string, 	 i: 3137; 	 prediction: -0.3648, 	 target: -0.3485, 	 loss: 0.0003
# Epoch [1/2], Loss epoch: 0.0050, Loss validation: 0.0027, Time remaining: ~0.0h 5.0m 43s
# 	 Validation string, 	 i: 3566; 	 prediction: -0.1967, 	 target: -0.1147, 	 loss: 0.0067
# 	 Validation string, 	 i: 3625; 	 prediction: -0.1127, 	 target: -0.0410, 	 loss: 0.0051
# 	 Validation string, 	 i: 3563; 	 prediction: -0.3156, 	 target: -0.2662, 	 loss: 0.0024
# Epoch [2/2], Loss epoch: 0.0024, Loss validation: 0.0024, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0023513119670470557, std loss: 0.004634995572156617
#
#
#  --- SWEEP POINT 14/24: (2, 0, 'all') ---
#  --- time reamining: 14:17:19.40
#
# Epoch [0/2], Loss epoch: 0.2724, Loss validation: 0.2729
# 	 Validation string, 	 i: 2945; 	 prediction: -0.1857, 	 target: -0.1786, 	 loss: 0.0000
# 	 Validation string, 	 i: 3397; 	 prediction: -0.1213, 	 target: -0.0872, 	 loss: 0.0012
# 	 Validation string, 	 i: 1995; 	 prediction: -0.2567, 	 target: -0.2800, 	 loss: 0.0005
# Epoch [1/2], Loss epoch: 0.0052, Loss validation: 0.0026, Time remaining: ~0.0h 5.0m 49s
# 	 Validation string, 	 i: 866; 	 prediction: -0.3805, 	 target: -0.3953, 	 loss: 0.0002
# 	 Validation string, 	 i: 3496; 	 prediction: -0.1211, 	 target: -0.1817, 	 loss: 0.0037
# 	 Validation string, 	 i: 2388; 	 prediction: -0.4203, 	 target: -0.4708, 	 loss: 0.0026
# Epoch [2/2], Loss epoch: 0.0023, Loss validation: 0.0024, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.002351709135364122, std loss: 0.004239848669921753
#
#
#  --- SWEEP POINT 15/24: (2, 1, 1) ---
#  --- time reamining: 12:12:11.66
#
# Epoch [0/2], Loss epoch: 0.0877, Loss validation: 0.0880
# 	 Validation string, 	 i: 1552; 	 prediction: -0.3712, 	 target: -0.2996, 	 loss: 0.0051
# 	 Validation string, 	 i: 2350; 	 prediction: -0.3953, 	 target: -0.4219, 	 loss: 0.0007
# 	 Validation string, 	 i: 3063; 	 prediction: -0.4153, 	 target: -0.4264, 	 loss: 0.0001
# Epoch [1/2], Loss epoch: 0.0041, Loss validation: 0.0028, Time remaining: ~0.0h 20.0m 12s
# 	 Validation string, 	 i: 1318; 	 prediction: -0.2363, 	 target: -0.3843, 	 loss: 0.0219
# 	 Validation string, 	 i: 1806; 	 prediction: -0.4001, 	 target: -0.3801, 	 loss: 0.0004
# 	 Validation string, 	 i: 3058; 	 prediction: -0.4798, 	 target: -0.4954, 	 loss: 0.0002
# Epoch [2/2], Loss epoch: 0.0024, Loss validation: 0.0023, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0023098002877970807, std loss: 0.004404039907279182
#
#
#  --- SWEEP POINT 16/24: (2, 1, 'all') ---
#  --- time reamining: 10:47:25.67
#
# Epoch [0/2], Loss epoch: 0.1267, Loss validation: 0.1265
# 	 Validation string, 	 i: 4334; 	 prediction: -0.2044, 	 target: -0.2080, 	 loss: 0.0000
# 	 Validation string, 	 i: 1990; 	 prediction: -0.2554, 	 target: -0.3307, 	 loss: 0.0057
# 	 Validation string, 	 i: 4055; 	 prediction: -0.1222, 	 target: -0.0313, 	 loss: 0.0083
# Epoch [1/2], Loss epoch: 0.0045, Loss validation: 0.0026, Time remaining: ~0.0h 24.0m 6s
# 	 Validation string, 	 i: 1736; 	 prediction: -0.1588, 	 target: -0.2171, 	 loss: 0.0034
# 	 Validation string, 	 i: 1241; 	 prediction: -0.3023, 	 target: -0.2433, 	 loss: 0.0035
# 	 Validation string, 	 i: 2385; 	 prediction: -0.1941, 	 target: -0.1924, 	 loss: 0.0000
# Epoch [2/2], Loss epoch: 0.0025, Loss validation: 0.0025, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0024261321959443295, std loss: 0.004891499823062332
#
#
#  --- SWEEP POINT 17/24: (2, 2, 1) ---
#  --- time reamining: 09:21:58.55
#
# Epoch [0/2], Loss epoch: 0.1259, Loss validation: 0.1256
# 	 Validation string, 	 i: 3524; 	 prediction: -0.4285, 	 target: -0.4326, 	 loss: 0.0000
# 	 Validation string, 	 i: 4125; 	 prediction: -0.1496, 	 target: -0.1031, 	 loss: 0.0022
# 	 Validation string, 	 i: 1498; 	 prediction: -0.2002, 	 target: -0.2862, 	 loss: 0.0074
# Epoch [1/2], Loss epoch: 0.0042, Loss validation: 0.0028, Time remaining: ~0.0h 33.0m 13s
# 	 Validation string, 	 i: 3478; 	 prediction: -0.1761, 	 target: -0.2497, 	 loss: 0.0054
# 	 Validation string, 	 i: 1407; 	 prediction: -0.4580, 	 target: -0.4712, 	 loss: 0.0002
# 	 Validation string, 	 i: 2973; 	 prediction: -0.4176, 	 target: -0.4006, 	 loss: 0.0003
# Epoch [2/2], Loss epoch: 0.0025, Loss validation: 0.0025, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0024924591394104617, std loss: 0.004781467121218209
#
#
#  --- SWEEP POINT 18/24: (2, 2, 'all') ---
#  --- time reamining: 08:09:32.12
#
# Epoch [0/2], Loss epoch: 0.0332, Loss validation: 0.0332
# 	 Validation string, 	 i: 2355; 	 prediction: -0.1665, 	 target: -0.0899, 	 loss: 0.0059
# 	 Validation string, 	 i: 2662; 	 prediction: -0.1928, 	 target: -0.1860, 	 loss: 0.0000
# 	 Validation string, 	 i: 95; 	 prediction: -0.2627, 	 target: -0.3351, 	 loss: 0.0052
# Epoch [1/2], Loss epoch: 0.0039, Loss validation: 0.0028, Time remaining: ~0.0h 22.0m 56s
# 	 Validation string, 	 i: 3940; 	 prediction: -0.3387, 	 target: -0.3312, 	 loss: 0.0001
# 	 Validation string, 	 i: 931; 	 prediction: -0.2452, 	 target: -0.3196, 	 loss: 0.0055
# 	 Validation string, 	 i: 2921; 	 prediction: -0.4363, 	 target: -0.4150, 	 loss: 0.0005
# Epoch [2/2], Loss epoch: 0.0024, Loss validation: 0.0025, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.00239140271698266, std loss: 0.004989646650804846
#
#
#  --- SWEEP POINT 19/24: (2, 5, 1) ---
#  --- time reamining: 06:58:33.64
#
# Epoch [0/2], Loss epoch: 0.5407, Loss validation: 0.5401
# 	 Validation string, 	 i: 2417; 	 prediction: -0.2364, 	 target: -0.2734, 	 loss: 0.0014
# 	 Validation string, 	 i: 3724; 	 prediction: -0.3199, 	 target: -0.3458, 	 loss: 0.0007
# 	 Validation string, 	 i: 4058; 	 prediction: -0.4886, 	 target: -0.5261, 	 loss: 0.0014
# Epoch [1/2], Loss epoch: 0.0047, Loss validation: 0.0027, Time remaining: ~0.0h 21.0m 53s
# 	 Validation string, 	 i: 196; 	 prediction: -0.0767, 	 target: -0.0490, 	 loss: 0.0008
# 	 Validation string, 	 i: 2892; 	 prediction: -0.3352, 	 target: -0.3709, 	 loss: 0.0013
# 	 Validation string, 	 i: 3732; 	 prediction: -0.4660, 	 target: -0.4636, 	 loss: 0.0000
# Epoch [2/2], Loss epoch: 0.0025, Loss validation: 0.0024, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0023538241140467217, std loss: 0.00468878369379786
#
#
#  --- SWEEP POINT 20/24: (2, 5, 'all') ---
#  --- time reamining: 05:46:03.01
#
# Epoch [0/2], Loss epoch: 0.1115, Loss validation: 0.1113
# 	 Validation string, 	 i: 2658; 	 prediction: -0.4908, 	 target: -0.4021, 	 loss: 0.0079
# 	 Validation string, 	 i: 3636; 	 prediction: -0.4359, 	 target: -0.4304, 	 loss: 0.0000
# 	 Validation string, 	 i: 1668; 	 prediction: -0.4304, 	 target: -0.4360, 	 loss: 0.0000
# Epoch [1/2], Loss epoch: 0.0041, Loss validation: 0.0026, Time remaining: ~0.0h 34.0m 4s
# 	 Validation string, 	 i: 3198; 	 prediction: -0.2987, 	 target: -0.3052, 	 loss: 0.0000
# 	 Validation string, 	 i: 1170; 	 prediction: -0.4460, 	 target: -0.4877, 	 loss: 0.0017
# 	 Validation string, 	 i: 3151; 	 prediction: -0.4327, 	 target: -0.4005, 	 loss: 0.0010
# Epoch [2/2], Loss epoch: 0.0025, Loss validation: 0.0025, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.002512158184886019, std loss: 0.004721437956169498
#
#
#  --- SWEEP POINT 21/24: (2, 12, 1) ---
#  --- time reamining: 04:39:40.29
#
# Epoch [0/2], Loss epoch: 1.5490, Loss validation: 1.5501
# 	 Validation string, 	 i: 1477; 	 prediction: -0.3132, 	 target: -0.3189, 	 loss: 0.0000
# 	 Validation string, 	 i: 19; 	 prediction: -0.1536, 	 target: -0.1632, 	 loss: 0.0001
# 	 Validation string, 	 i: 699; 	 prediction: -0.4155, 	 target: -0.4296, 	 loss: 0.0002
# Epoch [1/2], Loss epoch: 0.0088, Loss validation: 0.0027, Time remaining: ~0.0h 35.0m 52s
# 	 Validation string, 	 i: 3878; 	 prediction: -0.3363, 	 target: -0.3908, 	 loss: 0.0030
# 	 Validation string, 	 i: 1279; 	 prediction: -0.4702, 	 target: -0.4397, 	 loss: 0.0009
# 	 Validation string, 	 i: 209; 	 prediction: -0.1323, 	 target: -0.1154, 	 loss: 0.0003
# Epoch [2/2], Loss epoch: 0.0025, Loss validation: 0.0025, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0024087250614644746, std loss: 0.004492557559136415
#
#
#  --- SWEEP POINT 22/24: (2, 12, 'all') ---
#  --- time reamining: 03:36:22.43
#
# Epoch [0/2], Loss epoch: 0.3991, Loss validation: 0.3997
# 	 Validation string, 	 i: 1640; 	 prediction: -0.3967, 	 target: -0.3674, 	 loss: 0.0009
# 	 Validation string, 	 i: 628; 	 prediction: -0.2104, 	 target: -0.1501, 	 loss: 0.0036
# 	 Validation string, 	 i: 1449; 	 prediction: -0.2729, 	 target: -0.1944, 	 loss: 0.0062
# Epoch [1/2], Loss epoch: 0.0042, Loss validation: 0.0027, Time remaining: ~0.0h 32.0m 12s
# 	 Validation string, 	 i: 2852; 	 prediction: -0.4417, 	 target: -0.4750, 	 loss: 0.0011
# 	 Validation string, 	 i: 173; 	 prediction: -0.4079, 	 target: -0.4293, 	 loss: 0.0005
# 	 Validation string, 	 i: 1369; 	 prediction: -0.2665, 	 target: -0.2904, 	 loss: 0.0006
# Epoch [2/2], Loss epoch: 0.0025, Loss validation: 0.0025, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0024681306327031974, std loss: 0.004410297488487588
#
#
#  --- SWEEP POINT 23/24: (2, 20, 1) ---
#  --- time reamining: 02:27:25.98
#
# Epoch [0/2], Loss epoch: 0.0511, Loss validation: 0.0510
# 	 Validation string, 	 i: 2180; 	 prediction: -0.4277, 	 target: -0.4134, 	 loss: 0.0002
# 	 Validation string, 	 i: 2653; 	 prediction: -0.1390, 	 target: -0.0347, 	 loss: 0.0109
# 	 Validation string, 	 i: 4308; 	 prediction: -0.4524, 	 target: -0.4229, 	 loss: 0.0009
# Epoch [1/2], Loss epoch: 0.0041, Loss validation: 0.0034, Time remaining: ~0.0h 48.0m 17s
# 	 Validation string, 	 i: 1469; 	 prediction: -0.2646, 	 target: -0.3059, 	 loss: 0.0017
# 	 Validation string, 	 i: 4301; 	 prediction: -0.3438, 	 target: -0.3482, 	 loss: 0.0000
# 	 Validation string, 	 i: 405; 	 prediction: -0.2428, 	 target: -0.2542, 	 loss: 0.0001
# Epoch [2/2], Loss epoch: 0.0025, Loss validation: 0.0025, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.002448850789596295, std loss: 0.00461658550239955
#
#
#  --- SWEEP POINT 24/24: (2, 20, 'all') ---
#  --- time reamining: 01:16:48.56
#
# Epoch [0/2], Loss epoch: 0.0217, Loss validation: 0.0217
# 	 Validation string, 	 i: 1514; 	 prediction: -0.1997, 	 target: -0.3533, 	 loss: 0.0236
# 	 Validation string, 	 i: 2127; 	 prediction: -0.1762, 	 target: -0.1785, 	 loss: 0.0000
# 	 Validation string, 	 i: 321; 	 prediction: -0.2665, 	 target: -0.3456, 	 loss: 0.0063
# Epoch [1/2], Loss epoch: 0.0041, Loss validation: 0.0029, Time remaining: ~0.0h 40.0m 42s
# 	 Validation string, 	 i: 4057; 	 prediction: -0.1556, 	 target: -0.1068, 	 loss: 0.0024
# 	 Validation string, 	 i: 1909; 	 prediction: -0.2741, 	 target: -0.2346, 	 loss: 0.0016
# 	 Validation string, 	 i: 885; 	 prediction: -0.3022, 	 target: -0.2580, 	 loss: 0.0020
# Epoch [2/2], Loss epoch: 0.0026, Loss validation: 0.0025, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0025060983616465257, std loss: 0.004830417491483526
