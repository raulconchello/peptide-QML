# %%
initial_path = 'peptide-QML'
initial_path = '..'

# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import helper_classes as c

# %% [markdown]
# # 0927-sweep_6c_linear-1

# %%
sweep = c.Sweep.load(
    initial_path=initial_path,
    day='0927',
    file_name='sweep_6c_linear-1',
)
sweep.lists.keys()
# Out:
# dict_keys(['idx', 'repetitions', 'model_uuid', 'best_loss_train', 'best_loss_test', 'loss_validation', 'n_parameters', 'time_train'])

# %%
sweep.plot(
    x_key='n_parameters',
    y_key='loss_validation',
    legend_keys=[],
    fit_degree=2,
    replace=[],
    fix = [],
)
# Out:
# d:\Raul\Programs\envs\PennyLane\lib\site-packages\autograd\tracer.py:48: RankWarning: Polyfit may be poorly conditioned
#   return f_raw(*args, **kwargs)
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # 0926-sweep_6h_er_Aqm-2 & 0927-sweep_6h_er_Aqm-4

# %%
sweep = c.SweepUnion(
    sweeps=[
        c.Sweep.load(
            initial_path=initial_path,
            day='0926',
            file_name='sweep_6h_er_Aqm-2',
        ),
        c.Sweep.load(
            initial_path=initial_path,
            day='0927',
            file_name='sweep_6h_er_Aqm-4',
        ),
    ]
)
sweep.lists.keys()
# Out:
# dict_keys(['idx', 'repetitions', 'block_n_layers', 'embedding_n_layers', 'ansatz', 'model_uuid', 'best_loss_train', 'best_loss_test', 'loss_validation', 'n_parameters', 'time_train', 'sweep_uuid'])

# %%
# list(zip(sweep.lists['embedding_dim'], sweep.lists['quantum_n_layers'], sweep.lists['quantum_measurement'], sweep.lists['n_parameters']))

# %%
sweep.plot(
    x_key='n_parameters',
    y_key='loss_validation',
    legend_keys=['ansatz'],
    fit_degree=2,
    replace=[("<class 'my_code.quantum_nodes.parts.Ansatz_full_conn'>", 'full_conn'), ("<class 'my_code.quantum_nodes.parts.Ansatz_11'>", '11')],
    fix = [],
    to_string = ['ansatz'],
)

# %%
sweep.plot(
    x_key='n_parameters',
    y_key='loss_validation',
    legend_keys=['embedding_n_layers'],
    fit_degree=2,
    replace=[("<class 'my_code.quantum_nodes.parts.Ansatz_full_conn'>", 'full_conn'), ("<class 'my_code.quantum_nodes.parts.Ansatz_11'>", '11')],
    fix = [('ansatz', "<class 'my_code.quantum_nodes.parts.Ansatz_11'>")],
    to_string = ['ansatz',],
)

# %%
sweep.plot(
    x_key='block_n_layers',
    y_key='loss_validation',
    legend_keys=['ansatz'],
    fit_degree=2,
    replace=[("<class 'my_code.quantum_nodes.parts.Ansatz_full_conn'>", 'full_conn'), ("<class 'my_code.quantum_nodes.parts.Ansatz_11'>", '11')],
    fix = [],
    to_string = ['ansatz'],
)

# %%
sweep.plot(
    x_key='embedding_n_layers',
    y_key='loss_validation',
    legend_keys=['ansatz'],
    fit_degree=2,
    replace=[("<class 'my_code.quantum_nodes.parts.Ansatz_full_conn'>", 'full_conn'), ("<class 'my_code.quantum_nodes.parts.Ansatz_11'>", '11')],
    fix = [],
    to_string = ['ansatz'],
)

# %% [markdown]
# # 0927-sweep_6h_e_Xqm-1

# %%
sweep = c.Sweep.load(
    initial_path=initial_path,
    day='0927',
    file_name='sweep_6h_e_Xqm-1',
)
sweep.lists.keys()
# Out:
# dict_keys(['idx', 'repetitions', 'block_n_layers', 'measurement', 'ansatz', 'model_uuid', 'best_loss_train', 'best_loss_test', 'loss_validation', 'n_parameters', 'time_train'])

# %%
sweep.plot(
    x_key='block_n_layers',
    y_key='loss_validation',
    legend_keys=['measurement'],
    fit_degree=2,
    replace=[("<class 'my_code.quantum_nodes.parts.Ansatz_full_conn'>", 'full_conn'), ("<class 'my_code.quantum_nodes.parts.Ansatz_2'>", '2'), ("<class 'my_code.quantum_nodes.parts.Ansatz_11'>", '11')],
    fix = [],
    to_string = ['ansatz'],
)

sweep.plot(
    x_key='block_n_layers',
    y_key='loss_validation',
    legend_keys=['ansatz'],
    fit_degree=2,
    replace=[("<class 'my_code.quantum_nodes.parts.Ansatz_full_conn'>", 'full_conn'), ("<class 'my_code.quantum_nodes.parts.Ansatz_2'>", '2'), ("<class 'my_code.quantum_nodes.parts.Ansatz_11'>", '11')],
    fix = [('measurement','all')],
    to_string = ['ansatz'],
)

sweep.plot(
    x_key='block_n_layers',
    y_key='loss_validation',
    legend_keys=['ansatz'],
    fit_degree=2,
    replace=[("<class 'my_code.quantum_nodes.parts.Ansatz_full_conn'>", 'full_conn'), ("<class 'my_code.quantum_nodes.parts.Ansatz_2'>", '2'), ("<class 'my_code.quantum_nodes.parts.Ansatz_11'>", '11')],
    fix = [('measurement','1')],
    to_string = ['ansatz'],
)
