# %%
initial_path = 'peptide-QML'
# initial_path = '..'

# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import helper_classes as c
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # sweep_4h_er_Xqm-2

# %%
sweep = c.Sweep.load(
    initial_path=initial_path,
    day='0921',
    file_name='sweep_4h_er_Xqm-2',
)
sweep.lists.keys()
# Out:
# dict_keys(['idx', 'repetitions', 'quantum_n_layers', 'quantum_measurement', 'embedding_dim', 'model_uuid', 'best_loss_train', 'best_loss_test', 'loss_validation', 'n_parameters', 'time_train'])

# %%
list(zip(sweep.lists['embedding_dim'], sweep.lists['quantum_n_layers'], sweep.lists['quantum_measurement'], sweep.lists['n_parameters']))
# Out:
# [(1, 1, 0, 45),
#  (2, 1, 0, 76),
#  (3, 1, 0, 107),
#  (4, 1, 0, 138),
#  (5, 1, 0, 169),
#  (6, 1, 0, 200),
#  (1, 1, 1, 45),
#  (2, 1, 1, 76),
#  (3, 1, 1, 107),
#  (4, 1, 1, 138),
#  (5, 1, 1, 169),
#  (6, 1, 1, 200),
#  (1, 1, 'all', 48),
#  (2, 1, 'all', 79),
#  (3, 1, 'all', 110),
#  (4, 1, 'all', 141),
#  (5, 1, 'all', 172),
#  (6, 1, 'all', 203),
#  (1, 3, 0, 69),
#  (2, 3, 0, 100),
#  (3, 3, 0, 131),
#  (4, 3, 0, 162),
#  (5, 3, 0, 193),
#  (6, 3, 0, 224),
#  (1, 3, 1, 69),
#  (2, 3, 1, 100),
#  (3, 3, 1, 131),
#  (4, 3, 1, 162),
#  (5, 3, 1, 193),
#  (6, 3, 1, 224),
#  (1, 3, 'all', 72),
#  (2, 3, 'all', 103),
#  (3, 3, 'all', 134),
#  (4, 3, 'all', 165),
#  (5, 3, 'all', 196),
#  (6, 3, 'all', 227),
#  (1, 5, 0, 93),
#  (2, 5, 0, 124),
#  (3, 5, 0, 155),
#  (4, 5, 0, 186),
#  (5, 5, 0, 217),
#  (6, 5, 0, 248),
#  (1, 5, 1, 93),
#  (2, 5, 1, 124),
#  (3, 5, 1, 155),
#  (4, 5, 1, 186),
#  (5, 5, 1, 217),
#  (6, 5, 1, 248),
#  (1, 5, 'all', 96),
#  (2, 5, 'all', 127),
# ...

# %%
sweep.plot(
    x_key='quantum_n_layers',
    y_key='loss_validation',
    legend_keys=['embedding_dim'],
    fit_degree=2,
    replace=[('embedding_dim', 'dim embedding'), ('loss_validation', 'loss validation')],
    fix = [],
)

# %%
sweep.plot(
    x_key='n_parameters',
    y_key='loss_validation',
    legend_keys=[],
    fit_degree=2,
    replace=[('embedding_dim', 'dim embedding'), ('loss_validation', 'loss validation')],
    fix = [],
)
# Out:
# No handles with labels found to put in legend.

# %%
sweep.plot(
    x_key='embedding_dim',
    y_key='loss_validation',
    legend_keys=['quantum_n_layers'],
    fit_degree=2,
    replace=[('embedding_dim', 'dim embedding'), ('loss_validation', 'loss validation')],
    fix = [('quantum_measurement', '0')],
)

# %%
sweep.plot(
    x_key='embedding_dim',
    y_key='loss_validation',
    legend_keys=['quantum_n_layers'],
    fit_degree=2,
    replace=[('embedding_dim', 'dim embedding'), ('loss_validation', 'loss validation')],
    fix = [('quantum_measurement', '1')],
)

# %%
sweep.plot(
    x_key='embedding_dim',
    y_key='loss_validation',
    legend_keys=['quantum_n_layers'],
    fit_degree=2,
    replace=[('embedding_dim', 'dim embedding'), ('loss_validation', 'loss validation')],
    fix = [('quantum_measurement', 'all')],
)

# %% [markdown]
# # 0921-sweep_4h_er_Xqm_v2-1

# %%
sweep = c.Sweep.load(
    initial_path=initial_path,
    day='0921',
    file_name='sweep_4h_er_Xqm_v2-1',
)
sweep.lists.keys()
# Out:
# dict_keys(['idx', 'repetitions', 'quantum_n_layers', 'quantum_measurement', 'embedding_n_layers', 'model_uuid', 'best_loss_train', 'best_loss_test', 'loss_validation', 'n_parameters', 'time_train'])

# %%
sweep.plot(
    x_key='embedding_n_layers',
    y_key='loss_validation',
    legend_keys=['quantum_n_layers'],
    fit_degree=2,
    replace=[],
    fix = [],
)

# %%
sweep.plot(
    x_key='n_parameters',
    y_key='loss_validation',
    legend_keys=['quantum_n_layers'],
    fit_degree=2,
    replace=[],
    fix = [],
)
for qm in ['1', 'all']:
    sweep.plot(
        x_key='n_parameters',
        y_key='loss_validation',
        legend_keys=['quantum_n_layers'],
        fit_degree=2,
        replace=[],
        fix = [('quantum_measurement', qm)],
    )

# %%
sweep.plot(
    x_key='quantum_n_layers',
    y_key='loss_validation',
    legend_keys=['quantum_measurement'],
    fit_degree=2,
    replace=[],
    fix = [],
)

for enl in [0, 1, 2, 4, 6]:
    sweep.plot(
        x_key='quantum_n_layers',
        y_key='loss_validation',
        legend_keys=['quantum_measurement'],
        fit_degree=2,
        replace=[],
        fix = [('embedding_n_layers', enl)],
    )

# %% [markdown]
# # 0921-sweep_4h_er_Xqm_v2-2

# %%
sweep = c.Sweep.load(
    initial_path=initial_path,
    day='0921',
    file_name='sweep_4h_er_Xqm_v2-2',
)
sweep.lists.keys()
# Out:
# dict_keys(['idx', 'repetitions', 'quantum_n_layers', 'quantum_measurement', 'embedding_n_layers', 'model_uuid', 'best_loss_train', 'best_loss_test', 'loss_validation', 'n_parameters', 'time_train'])

# %%
sweep.plot(
    x_key='embedding_n_layers',
    y_key='loss_validation',
    legend_keys=['quantum_n_layers'],
    fit_degree=2,
    replace=[],
    fix = [],
)

# %%
sweep.plot(
    x_key='n_parameters',
    y_key='loss_validation',
    legend_keys=['quantum_n_layers'],
    fit_degree=2,
    replace=[],
    fix = [],
)
for qm in ['1', 'all']:
    sweep.plot(
        x_key='n_parameters',
        y_key='loss_validation',
        legend_keys=['quantum_n_layers'],
        fit_degree=2,
        replace=[],
        fix = [('quantum_measurement', qm)],
    )

# %%
sweep.plot(
    x_key='quantum_n_layers',
    y_key='loss_validation',
    legend_keys=['quantum_measurement'],
    fit_degree=2,
    replace=[],
    fix = [],
)

for enl in [0, 1, 2, 4, 6]:
    sweep.plot(
        x_key='quantum_n_layers',
        y_key='loss_validation',
        legend_keys=['quantum_measurement'],
        fit_degree=2,
        replace=[],
        fix = [('embedding_n_layers', enl)],
    )

# %% [markdown]
# # 0921-sweep_4h_er_Xqm_v2-3

# %%
sweep = c.Sweep.load(
    initial_path=initial_path,
    day='0921',
    file_name='sweep_4h_er_Xqm_v3-2',
)
sweep.lists.keys()
# Out:
# dict_keys(['idx', 'repetitions', 'quantum_n_layers', 'quantum_measurement', 'embedding_dim', 'model_uuid', 'best_loss_train', 'best_loss_test', 'loss_validation', 'n_parameters', 'time_train'])

# %%
sweep.plot(
    x_key='quantum_n_layers',
    y_key='loss_validation',
    legend_keys=['embedding_dim'],
    fit_degree=1,
    replace=[],
    fix = [],
)

# %%
sweep.plot(
    x_key='embedding_dim',
    y_key='loss_validation',
    legend_keys=['quantum_n_layers'],
    fit_degree=0,
    replace=[],
    fix = [],
)
