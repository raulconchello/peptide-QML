# %%
initial_path = 'peptide-QML'
# initial_path = '..'

# %%
import sys
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import helper_classes as c
from my_code import pytorch_model as m
from my_code import quantum_nodes as q
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.0.4) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
# name of the notebook
name_notebook = "sweep_12h_e_Am_Xqm_v2"

# %%
sweep = c.Sweep(
    name_notebook, 
    initial_path=initial_path,
    description="Try to find the best measurement and number of layers for the quantum block using Amplitude Encoding (repeating embedding) and embedding.",
    repetitions=list(range(1, 3)),
    n_layers_quantum_block=[2,12,20,25],
    embedding_n_layers=[1,2,3,4],
)

# %%
sweep.save()

# %%
# sweep = c.Sweep.load(file_name=name_notebook+"-1", day='0912', initial_path=initial_path)

# %%
for sweep_point in sweep:

    # print the point of the sweep
    sweep.print_sweep_status(sweep_point['idx'])

    # -- QUANTUM BLOCK -- #
    n_qubits = 6
    quantum_layer = q.circuit(
        n_qubits = n_qubits, 
        device = "default.qubit.torch",
        device_options = {'shots': None},
        embedding = q.parts.AmplitudeEmbedding, 
        embedding_ansatz = q.parts.Ansatz_11,
        block_ansatz = q.parts.Ansatz_11,
        final_ansatz = q.parts.Ansatz_11, # TODO CHECK IF THIS IS THE BEST OPTION
        measurement = q.parts.Measurement('Z', 1),
        embedding_n_layers = sweep_point['embedding_n_layers'],
        # different_inputs_per_layer = True,
        block_n_layers = sweep_point['n_layers_quantum_block'],
        # wrapper_qlayer = pw.QLayerEmpty,
    )

    # -- MODEL -- #                    
    class Model(m.Model):
        def __init__(self):
            super(Model, self).__init__()
            embedding_dim = 2**n_qubits//12
            self.fc1 = m.nn.Embedding(num_embeddings=19, embedding_dim=embedding_dim)
            self.fc2 = m.Reshape()
            self.fc3 = quantum_layer() 
            self.fc4 = m.nn.Linear(1, 1) 
            self.fc5 = m.nn.Linear(1, 1)

        def forward(self, x):
            x = self.fc1(x)
            x = self.fc2(x)
            x = self.fc3(x)
            x = m.torch.sigmoid(self.fc4(x))
            x = self.fc5(x)
            return x

    model = Model()

    # set quantum layer
    model.set_quantum_layer(quantum_layer)

    # set the name and path of the model
    model.set_name_and_path(name_notebook, initial_path)

    #set sweep point
    model.set_sweep_point(
        sweep_uuid = sweep.uuid,
        sweep_point = sweep_point,
        day=sweep.day
    )

    # -- TRAIN -- #
    model.optimize_params(
        #save info
        save_model_info = True,
        description = 'sweep with 12 amino acids and {} qubits using Amplitude Encoding (repeating embedding) and classical Embedding'.format(n_qubits),    
        #data
        data=c.Data.load(initial_path=initial_path, file_name='PET_SCORES_12_Numbers_int'),
        # train options
        optimizer = m.optim.Adam,
        optimizer_options = {'lr': 0.01},
        num_epochs = 2,                
        batch_size = 32,
        # early stopping options
        stop_training_options = {
            'lookback_epochs': 5, 
            'threshold_slope': 0.001,
            'threshold_std_dev': 0.2
        },
        # metadata
        metadata = {}
    )

    # -- VALIDATION and PLOTS -- #
    model.plot_losses(fig_size=(6,6))
    model.validate(
        pct=1,
        add_to_results=True,
        plot=True,
        print_items=False
    )

    # -- SAVE RESULTS -- #
    model.save_results()

    # -- ADD DATA GENERATED TO SWEEP -- #
    sweep.add_data(
        idx=sweep_point['idx'],
        model_uuid=model.uuid,
        best_loss_train=model.results.loss_epoch.best,
        best_loss_test=model.results.loss_validation_epoch.best,
        loss_validation=model.mean_loss_validation,
        time_train=model.results.time_epoch.last,
    )
    sweep.save(csv=False) #TODO: save csv=False automatically when sweep is already saved ion csv
# Out:
#  --- SWEEP POINT 1/40: (1, 1, 4, 1) ---
#  --- parameters sweeping: ['repetitions', 'n_layers_quantum_block', 'n_qubits', 'qubits_measurement']
#
# Epoch [0/2], Loss epoch: 0.3548, Loss validation: 0.3554
#  - Epoch [1/2], i: [128/397780], Loss: 0.2368
# /usr/lib/python3/dist-packages/torch/autograd/__init__.py:147: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at  ../aten/src/ATen/native/Copy.cpp:240.)
#   Variable._execution_engine.run_backward(
# 	 Validation string, 	 i: 3173; 	 prediction: -0.1521, 	 target: -0.2330, 	 loss: 0.0065
# 	 Validation string, 	 i: 1610; 	 prediction: -0.4016, 	 target: -0.4729, 	 loss: 0.0051
# 	 Validation string, 	 i: 3676; 	 prediction: -0.2794, 	 target: -0.1398, 	 loss: 0.0195
# Epoch [1/2], Loss epoch: 0.0138, Loss validation: 0.0129, Time remaining: ~0.0h 5.0m 45s
# 	 Validation string, 	 i: 4289; 	 prediction: -0.1651, 	 target: -0.0004, 	 loss: 0.0271
# 	 Validation string, 	 i: 1469; 	 prediction: -0.2385, 	 target: -0.3059, 	 loss: 0.0045
# 	 Validation string, 	 i: 3386; 	 prediction: -0.1566, 	 target: -0.1191, 	 loss: 0.0014
# Epoch [2/2], Loss epoch: 0.0123, Loss validation: 0.0120, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.012111820192489164, std loss: 0.0181903553212625
#
#
#  --- SWEEP POINT 2/40: (1, 1, 4, 'all') ---
#  --- time reamining: 1870:50:47.46
#
# Epoch [0/2], Loss epoch: 0.0341, Loss validation: 0.0343
# 	 Validation string, 	 i: 528; 	 prediction: -0.2231, 	 target: -0.1202, 	 loss: 0.0106
# 	 Validation string, 	 i: 172; 	 prediction: -0.1360, 	 target: -0.1783, 	 loss: 0.0018
# 	 Validation string, 	 i: 1388; 	 prediction: -0.2454, 	 target: -0.1302, 	 loss: 0.0133
# Epoch [1/2], Loss epoch: 0.0102, Loss validation: 0.0095, Time remaining: ~0.0h 6.0m 4s
# 	 Validation string, 	 i: 3434; 	 prediction: -0.3644, 	 target: -0.1666, 	 loss: 0.0391
# 	 Validation string, 	 i: 3184; 	 prediction: -0.0973, 	 target: -0.1532, 	 loss: 0.0031
# 	 Validation string, 	 i: 281; 	 prediction: -0.3510, 	 target: -0.3493, 	 loss: 0.0000
# Epoch [2/2], Loss epoch: 0.0096, Loss validation: 0.0097, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.009791241849089999, std loss: 0.01512020941342155
#
#
#  --- SWEEP POINT 3/40: (1, 1, 6, 1) ---
#  --- time reamining: 916:59:24.41
#
# Epoch [0/2], Loss epoch: 0.0914, Loss validation: 0.0917
# 	 Validation string, 	 i: 51; 	 prediction: -0.2862, 	 target: -0.4201, 	 loss: 0.0179
# 	 Validation string, 	 i: 1495; 	 prediction: -0.3512, 	 target: -0.3965, 	 loss: 0.0020
# 	 Validation string, 	 i: 2284; 	 prediction: -0.1112, 	 target: -0.1144, 	 loss: 0.0000
# Epoch [1/2], Loss epoch: 0.0086, Loss validation: 0.0084, Time remaining: ~0.0h 7.0m 51s
# 	 Validation string, 	 i: 2462; 	 prediction: -0.1725, 	 target: -0.1222, 	 loss: 0.0025
# 	 Validation string, 	 i: 2586; 	 prediction: -0.3862, 	 target: -0.4829, 	 loss: 0.0093
# 	 Validation string, 	 i: 3834; 	 prediction: -0.1700, 	 target: -0.0734, 	 loss: 0.0093
# Epoch [2/2], Loss epoch: 0.0083, Loss validation: 0.0087, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.00859063456212918, std loss: 0.013840275658983197
#
#
#  --- SWEEP POINT 4/40: (1, 1, 6, 'all') ---
#  --- time reamining: 600:30:46.06
#
# Epoch [0/2], Loss epoch: 0.2606, Loss validation: 0.2605
# 	 Validation string, 	 i: 354; 	 prediction: -0.3607, 	 target: -0.2255, 	 loss: 0.0183
# 	 Validation string, 	 i: 215; 	 prediction: -0.3710, 	 target: -0.5001, 	 loss: 0.0167
# 	 Validation string, 	 i: 274; 	 prediction: -0.2121, 	 target: -0.2360, 	 loss: 0.0006
# Epoch [1/2], Loss epoch: 0.0081, Loss validation: 0.0078, Time remaining: ~0.0h 8.0m 41s
# 	 Validation string, 	 i: 1557; 	 prediction: -0.3851, 	 target: -0.3875, 	 loss: 0.0000
# 	 Validation string, 	 i: 2584; 	 prediction: -0.1273, 	 target: -0.0908, 	 loss: 0.0013
# 	 Validation string, 	 i: 1199; 	 prediction: -0.1379, 	 target: -0.2984, 	 loss: 0.0258
# Epoch [2/2], Loss epoch: 0.0072, Loss validation: 0.0071, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.006937313825913404, std loss: 0.010794989251030528
#
#
#  --- SWEEP POINT 5/40: (1, 2, 4, 1) ---
#  --- time reamining: 442:16:51.55
#
# Epoch [0/2], Loss epoch: 1.1473, Loss validation: 1.1482
# 	 Validation string, 	 i: 2995; 	 prediction: -0.4351, 	 target: -0.4829, 	 loss: 0.0023
# 	 Validation string, 	 i: 3553; 	 prediction: -0.1552, 	 target: -0.0974, 	 loss: 0.0033
# 	 Validation string, 	 i: 2885; 	 prediction: -0.3779, 	 target: -0.2154, 	 loss: 0.0264
# Epoch [1/2], Loss epoch: 0.0127, Loss validation: 0.0088, Time remaining: ~0.0h 6.0m 55s
# 	 Validation string, 	 i: 503; 	 prediction: -0.2984, 	 target: -0.2268, 	 loss: 0.0051
# 	 Validation string, 	 i: 3693; 	 prediction: -0.2562, 	 target: -0.1582, 	 loss: 0.0096
# 	 Validation string, 	 i: 458; 	 prediction: -0.1695, 	 target: -0.1676, 	 loss: 0.0000
# Epoch [2/2], Loss epoch: 0.0089, Loss validation: 0.0088, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.008814872466093191, std loss: 0.014970971370057713
#
#
#  --- SWEEP POINT 6/40: (1, 2, 4, 'all') ---
#  --- time reamining: 346:29:12.00
#
# Epoch [0/2], Loss epoch: 0.3610, Loss validation: 0.3618
# 	 Validation string, 	 i: 3739; 	 prediction: -0.1611, 	 target: -0.1388, 	 loss: 0.0005
# 	 Validation string, 	 i: 3849; 	 prediction: -0.1318, 	 target: -0.1824, 	 loss: 0.0026
# 	 Validation string, 	 i: 3918; 	 prediction: -0.1432, 	 target: -0.0080, 	 loss: 0.0183
# Epoch [1/2], Loss epoch: 0.0090, Loss validation: 0.0082, Time remaining: ~0.0h 7.0m 8s
# 	 Validation string, 	 i: 2487; 	 prediction: -0.2367, 	 target: -0.2405, 	 loss: 0.0000
# 	 Validation string, 	 i: 4226; 	 prediction: -0.1716, 	 target: -0.1624, 	 loss: 0.0001
# 	 Validation string, 	 i: 3718; 	 prediction: -0.1704, 	 target: -0.2007, 	 loss: 0.0009
# Epoch [2/2], Loss epoch: 0.0080, Loss validation: 0.0081, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.007878206364114692, std loss: 0.012910635071397565
#
#
#  --- SWEEP POINT 7/40: (1, 2, 6, 1) ---
#  --- time reamining: 282:33:41.86
#
# Epoch [0/2], Loss epoch: 0.0508, Loss validation: 0.0510
# 	 Validation string, 	 i: 1254; 	 prediction: -0.4302, 	 target: -0.4796, 	 loss: 0.0024
# 	 Validation string, 	 i: 1006; 	 prediction: -0.4285, 	 target: -0.4813, 	 loss: 0.0028
# 	 Validation string, 	 i: 2336; 	 prediction: -0.1967, 	 target: -0.2926, 	 loss: 0.0092
# Epoch [1/2], Loss epoch: 0.0085, Loss validation: 0.0088, Time remaining: ~0.0h 9.0m 52s
# 	 Validation string, 	 i: 1979; 	 prediction: -0.2393, 	 target: -0.0840, 	 loss: 0.0241
# 	 Validation string, 	 i: 1183; 	 prediction: -0.3995, 	 target: -0.4646, 	 loss: 0.0042
# 	 Validation string, 	 i: 3004; 	 prediction: -0.3735, 	 target: -0.2849, 	 loss: 0.0079
# Epoch [2/2], Loss epoch: 0.0080, Loss validation: 0.0079, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.007795130818807488, std loss: 0.014052230085829145
#
#
#  --- SWEEP POINT 8/40: (1, 2, 6, 'all') ---
#  --- time reamining: 237:40:29.63
#
# Epoch [0/2], Loss epoch: 0.1269, Loss validation: 0.1266
# 	 Validation string, 	 i: 4152; 	 prediction: -0.3671, 	 target: -0.3045, 	 loss: 0.0039
# 	 Validation string, 	 i: 1733; 	 prediction: -0.3543, 	 target: -0.4654, 	 loss: 0.0123
# 	 Validation string, 	 i: 4141; 	 prediction: -0.4576, 	 target: -0.4606, 	 loss: 0.0000
# Epoch [1/2], Loss epoch: 0.0076, Loss validation: 0.0068, Time remaining: ~0.0h 10.0m 13s
# 	 Validation string, 	 i: 2922; 	 prediction: -0.2159, 	 target: -0.2406, 	 loss: 0.0006
# 	 Validation string, 	 i: 1203; 	 prediction: -0.1549, 	 target: -0.1059, 	 loss: 0.0024
# 	 Validation string, 	 i: 1595; 	 prediction: -0.2586, 	 target: -0.1700, 	 loss: 0.0078
# Epoch [2/2], Loss epoch: 0.0066, Loss validation: 0.0065, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.006397620115238179, std loss: 0.009703863143139604
#
#
#  --- SWEEP POINT 9/40: (1, 5, 4, 1) ---
#  --- time reamining: 203:57:01.91
#
# Epoch [0/2], Loss epoch: 0.6007, Loss validation: 0.6012
# 	 Validation string, 	 i: 3854; 	 prediction: -0.3513, 	 target: -0.3204, 	 loss: 0.0010
# 	 Validation string, 	 i: 3820; 	 prediction: -0.2538, 	 target: -0.2002, 	 loss: 0.0029
# 	 Validation string, 	 i: 3940; 	 prediction: -0.2840, 	 target: -0.3312, 	 loss: 0.0022
# Epoch [1/2], Loss epoch: 0.0104, Loss validation: 0.0091, Time remaining: ~0.0h 10.0m 33s
# 	 Validation string, 	 i: 1024; 	 prediction: -0.4124, 	 target: -0.3539, 	 loss: 0.0034
# 	 Validation string, 	 i: 4186; 	 prediction: -0.1234, 	 target: -0.0524, 	 loss: 0.0050
# 	 Validation string, 	 i: 1778; 	 prediction: -0.3476, 	 target: -0.5130, 	 loss: 0.0274
# Epoch [2/2], Loss epoch: 0.0088, Loss validation: 0.0096, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.00959592678594117, std loss: 0.014112118547206412
#
#
#  --- SWEEP POINT 10/40: (1, 5, 4, 'all') ---
#  --- time reamining: 177:41:15.04
#
# Epoch [0/2], Loss epoch: 0.2634, Loss validation: 0.2632
# 	 Validation string, 	 i: 3150; 	 prediction: -0.1768, 	 target: -0.1502, 	 loss: 0.0007
# 	 Validation string, 	 i: 3503; 	 prediction: -0.4118, 	 target: -0.5090, 	 loss: 0.0095
# 	 Validation string, 	 i: 1026; 	 prediction: -0.1456, 	 target: -0.2528, 	 loss: 0.0115
# Epoch [1/2], Loss epoch: 0.0090, Loss validation: 0.0083, Time remaining: ~0.0h 10.0m 46s
# 	 Validation string, 	 i: 3801; 	 prediction: -0.2187, 	 target: -0.4029, 	 loss: 0.0339
# 	 Validation string, 	 i: 3344; 	 prediction: -0.1945, 	 target: -0.2920, 	 loss: 0.0095
# 	 Validation string, 	 i: 503; 	 prediction: -0.2352, 	 target: -0.2268, 	 loss: 0.0001
# Epoch [2/2], Loss epoch: 0.0083, Loss validation: 0.0083, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.008266223333067651, std loss: 0.013087627697833608
#
#
#  --- SWEEP POINT 11/40: (1, 5, 6, 1) ---
#  --- time reamining: 156:35:58.86
#
# Epoch [0/2], Loss epoch: 0.0642, Loss validation: 0.0641
# 	 Validation string, 	 i: 1438; 	 prediction: -0.4594, 	 target: -0.5656, 	 loss: 0.0113
# 	 Validation string, 	 i: 2490; 	 prediction: -0.4065, 	 target: -0.6110, 	 loss: 0.0418
# 	 Validation string, 	 i: 693; 	 prediction: -0.3752, 	 target: -0.2460, 	 loss: 0.0167
# Epoch [1/2], Loss epoch: 0.0078, Loss validation: 0.0075, Time remaining: ~0.0h 16.0m 54s
# 	 Validation string, 	 i: 3544; 	 prediction: -0.1252, 	 target: -0.2348, 	 loss: 0.0120
# 	 Validation string, 	 i: 3142; 	 prediction: -0.2320, 	 target: -0.3256, 	 loss: 0.0088
# 	 Validation string, 	 i: 2320; 	 prediction: -0.2770, 	 target: -0.2168, 	 loss: 0.0036
# Epoch [2/2], Loss epoch: 0.0071, Loss validation: 0.0073, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.006953774345874481, std loss: 0.011440859760483701
#
#
#  --- SWEEP POINT 12/40: (1, 5, 6, 'all') ---
#  --- time reamining: 140:15:56.77
#
# Epoch [0/2], Loss epoch: 0.0222, Loss validation: 0.0223
# 	 Validation string, 	 i: 1631; 	 prediction: -0.1653, 	 target: -0.2163, 	 loss: 0.0026
# 	 Validation string, 	 i: 3428; 	 prediction: -0.2159, 	 target: -0.2072, 	 loss: 0.0001
# 	 Validation string, 	 i: 1453; 	 prediction: -0.2098, 	 target: -0.2499, 	 loss: 0.0016
# Epoch [1/2], Loss epoch: 0.0072, Loss validation: 0.0069, Time remaining: ~0.0h 17.0m 28s
# 	 Validation string, 	 i: 4078; 	 prediction: -0.3182, 	 target: -0.2593, 	 loss: 0.0035
# 	 Validation string, 	 i: 621; 	 prediction: -0.1887, 	 target: -0.2508, 	 loss: 0.0039
# 	 Validation string, 	 i: 235; 	 prediction: -0.1872, 	 target: -0.0730, 	 loss: 0.0131
# Epoch [2/2], Loss epoch: 0.0065, Loss validation: 0.0066, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.0063107813498011955, std loss: 0.009579850789892885
#
#
#  --- SWEEP POINT 13/40: (1, 12, 4, 1) ---
#  --- time reamining: 126:33:46.35
#
# Epoch [0/2], Loss epoch: 0.0619, Loss validation: 0.0617
# 	 Validation string, 	 i: 1328; 	 prediction: -0.3293, 	 target: -0.1845, 	 loss: 0.0210
# 	 Validation string, 	 i: 3803; 	 prediction: -0.3000, 	 target: -0.4092, 	 loss: 0.0119
# 	 Validation string, 	 i: 364; 	 prediction: -0.2875, 	 target: -0.1628, 	 loss: 0.0155
# Epoch [1/2], Loss epoch: 0.0097, Loss validation: 0.0092, Time remaining: ~0.0h 19.0m 25s
# 	 Validation string, 	 i: 15; 	 prediction: -0.2740, 	 target: -0.2871, 	 loss: 0.0002
# 	 Validation string, 	 i: 2322; 	 prediction: -0.3745, 	 target: -0.4623, 	 loss: 0.0077
# 	 Validation string, 	 i: 3851; 	 prediction: -0.3010, 	 target: -0.3723, 	 loss: 0.0051
# Epoch [2/2], Loss epoch: 0.0093, Loss validation: 0.0089, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.00890047088980071, std loss: 0.014109026004169769
#
#
#  --- SWEEP POINT 14/40: (1, 12, 4, 'all') ---
#  --- time reamining: 115:07:17.30
#
# Epoch [0/2], Loss epoch: 0.0209, Loss validation: 0.0210
# 	 Validation string, 	 i: 322; 	 prediction: -0.3309, 	 target: -0.2394, 	 loss: 0.0084
# 	 Validation string, 	 i: 1302; 	 prediction: -0.1622, 	 target: -0.0978, 	 loss: 0.0042
# 	 Validation string, 	 i: 353; 	 prediction: -0.4193, 	 target: -0.3750, 	 loss: 0.0020
# Epoch [1/2], Loss epoch: 0.0106, Loss validation: 0.0097, Time remaining: ~0.0h 19.0m 42s
# 	 Validation string, 	 i: 4010; 	 prediction: -0.4251, 	 target: -0.5071, 	 loss: 0.0067
# 	 Validation string, 	 i: 3262; 	 prediction: -0.3089, 	 target: -0.3164, 	 loss: 0.0001
# 	 Validation string, 	 i: 2297; 	 prediction: -0.2766, 	 target: -0.5153, 	 loss: 0.0570
# Epoch [2/2], Loss epoch: 0.0098, Loss validation: 0.0105, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.010463049508147946, std loss: 0.014803451107091452
#
#
#  --- SWEEP POINT 15/40: (1, 12, 6, 1) ---
#  --- time reamining: 105:10:04.98
#
# Epoch [0/2], Loss epoch: 0.0714, Loss validation: 0.0717
# 	 Validation string, 	 i: 2941; 	 prediction: -0.3586, 	 target: -0.3074, 	 loss: 0.0026
# 	 Validation string, 	 i: 426; 	 prediction: -0.1201, 	 target: -0.1068, 	 loss: 0.0002
# 	 Validation string, 	 i: 797; 	 prediction: -0.4025, 	 target: -0.4140, 	 loss: 0.0001
# Epoch [1/2], Loss epoch: 0.0069, Loss validation: 0.0065, Time remaining: ~0.0h 34.0m 44s
# 	 Validation string, 	 i: 1022; 	 prediction: -0.2899, 	 target: -0.2265, 	 loss: 0.0040
# 	 Validation string, 	 i: 2143; 	 prediction: -0.2942, 	 target: -0.2735, 	 loss: 0.0004
# 	 Validation string, 	 i: 2146; 	 prediction: -0.4472, 	 target: -0.4881, 	 loss: 0.0017
# Epoch [2/2], Loss epoch: 0.0064, Loss validation: 0.0068, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.006509229112251426, std loss: 0.010335234034153842
#
#
#  --- SWEEP POINT 16/40: (1, 12, 6, 'all') ---
#  --- time reamining: 97:56:38.13
#
# Epoch [0/2], Loss epoch: 0.0985, Loss validation: 0.0988
# 	 Validation string, 	 i: 3058; 	 prediction: -0.4636, 	 target: -0.4954, 	 loss: 0.0010
# 	 Validation string, 	 i: 4162; 	 prediction: -0.3862, 	 target: -0.4153, 	 loss: 0.0008
# 	 Validation string, 	 i: 4359; 	 prediction: -0.3398, 	 target: -0.4299, 	 loss: 0.0081
# Epoch [1/2], Loss epoch: 0.0067, Loss validation: 0.0077, Time remaining: ~0.0h 35.0m 7s
# 	 Validation string, 	 i: 279; 	 prediction: -0.4174, 	 target: -0.4430, 	 loss: 0.0007
# 	 Validation string, 	 i: 4009; 	 prediction: -0.2743, 	 target: -0.1069, 	 loss: 0.0280
# 	 Validation string, 	 i: 111; 	 prediction: -0.1894, 	 target: -0.2745, 	 loss: 0.0072
# Epoch [2/2], Loss epoch: 0.0062, Loss validation: 0.0062, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.006023700704850509, std loss: 0.00993136236378599
#
#
#  --- SWEEP POINT 17/40: (1, 20, 4, 1) ---
#  --- time reamining: 91:23:15.40
#
# Epoch [0/2], Loss epoch: 0.1201, Loss validation: 0.1198
# 	 Validation string, 	 i: 2004; 	 prediction: -0.1428, 	 target: -0.1979, 	 loss: 0.0030
# 	 Validation string, 	 i: 2780; 	 prediction: -0.3176, 	 target: -0.3282, 	 loss: 0.0001
# 	 Validation string, 	 i: 4180; 	 prediction: -0.4094, 	 target: -0.2947, 	 loss: 0.0132
# Epoch [1/2], Loss epoch: 0.0105, Loss validation: 0.0102, Time remaining: ~0.0h 30.0m 20s
# 	 Validation string, 	 i: 568; 	 prediction: -0.4272, 	 target: -0.4431, 	 loss: 0.0003
# 	 Validation string, 	 i: 570; 	 prediction: -0.2148, 	 target: -0.1977, 	 loss: 0.0003
# 	 Validation string, 	 i: 2729; 	 prediction: -0.4463, 	 target: -0.4331, 	 loss: 0.0002
# Epoch [2/2], Loss epoch: 0.0099, Loss validation: 0.0101, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.009688561439214087, std loss: 0.015135215085665437
#
#
#  --- SWEEP POINT 18/40: (1, 20, 4, 'all') ---
#  --- time reamining: 84:59:43.66
#
# Epoch [0/2], Loss epoch: 0.1388, Loss validation: 0.1388
# 	 Validation string, 	 i: 3625; 	 prediction: -0.0999, 	 target: -0.0410, 	 loss: 0.0035
# 	 Validation string, 	 i: 614; 	 prediction: -0.4026, 	 target: -0.4537, 	 loss: 0.0026
# 	 Validation string, 	 i: 1777; 	 prediction: -0.1722, 	 target: -0.1130, 	 loss: 0.0035
# Epoch [1/2], Loss epoch: 0.0087, Loss validation: 0.0083, Time remaining: ~0.0h 30.0m 36s
# 	 Validation string, 	 i: 2060; 	 prediction: -0.2982, 	 target: -0.2385, 	 loss: 0.0036
# 	 Validation string, 	 i: 3475; 	 prediction: -0.4421, 	 target: -0.4360, 	 loss: 0.0000
# 	 Validation string, 	 i: 4176; 	 prediction: -0.2590, 	 target: -0.4093, 	 loss: 0.0226
# Epoch [2/2], Loss epoch: 0.0081, Loss validation: 0.0081, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.00801572614310559, std loss: 0.013634869564320836
#
#
#  --- SWEEP POINT 19/40: (1, 20, 6, 1) ---
#  --- time reamining: 79:07:30.93
#
# Epoch [0/2], Loss epoch: 0.2701, Loss validation: 0.2705
# 	 Validation string, 	 i: 3989; 	 prediction: -0.3211, 	 target: -0.0839, 	 loss: 0.0562
# 	 Validation string, 	 i: 3276; 	 prediction: -0.2164, 	 target: -0.2221, 	 loss: 0.0000
# 	 Validation string, 	 i: 167; 	 prediction: -0.3731, 	 target: -0.4751, 	 loss: 0.0104
# Epoch [1/2], Loss epoch: 0.0072, Loss validation: 0.0063, Time remaining: ~0.0h 55.0m 13s
# 	 Validation string, 	 i: 3617; 	 prediction: -0.3245, 	 target: -0.2993, 	 loss: 0.0006
# 	 Validation string, 	 i: 1752; 	 prediction: -0.3354, 	 target: -0.2046, 	 loss: 0.0171
# 	 Validation string, 	 i: 3982; 	 prediction: -0.3828, 	 target: -0.2605, 	 loss: 0.0150
# Epoch [2/2], Loss epoch: 0.0064, Loss validation: 0.0061, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.005932989922702616, std loss: 0.009419318223578783
#
#
#  --- SWEEP POINT 20/40: (1, 20, 6, 'all') ---
#  --- time reamining: 75:22:24.27
#
# Epoch [0/2], Loss epoch: 0.1329, Loss validation: 0.1333
# 	 Validation string, 	 i: 716; 	 prediction: -0.2525, 	 target: -0.2660, 	 loss: 0.0002
# 	 Validation string, 	 i: 3989; 	 prediction: -0.3085, 	 target: -0.0839, 	 loss: 0.0504
# 	 Validation string, 	 i: 852; 	 prediction: -0.0962, 	 target: -0.1661, 	 loss: 0.0049
# Epoch [1/2], Loss epoch: 0.0068, Loss validation: 0.0060, Time remaining: ~0.0h 55.0m 44s
# 	 Validation string, 	 i: 2025; 	 prediction: -0.4179, 	 target: -0.5081, 	 loss: 0.0081
# 	 Validation string, 	 i: 1284; 	 prediction: -0.1624, 	 target: -0.0767, 	 loss: 0.0073
# 	 Validation string, 	 i: 2555; 	 prediction: -0.2182, 	 target: -0.1738, 	 loss: 0.0020
# Epoch [2/2], Loss epoch: 0.0062, Loss validation: 0.0062, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.006128295736225731, std loss: 0.00960369812398332
#
#
#  --- SWEEP POINT 21/40: (2, 1, 4, 1) ---
#  --- time reamining: 71:40:52.62
#
# Epoch [0/2], Loss epoch: 2.3656, Loss validation: 2.3681
# 	 Validation string, 	 i: 2093; 	 prediction: -0.1958, 	 target: -0.2404, 	 loss: 0.0020
# 	 Validation string, 	 i: 775; 	 prediction: -0.2702, 	 target: -0.2070, 	 loss: 0.0040
# 	 Validation string, 	 i: 2935; 	 prediction: -0.4420, 	 target: -0.4917, 	 loss: 0.0025
# Epoch [1/2], Loss epoch: 0.0185, Loss validation: 0.0097, Time remaining: ~0.0h 6.0m 5s
# 	 Validation string, 	 i: 998; 	 prediction: -0.2679, 	 target: -0.2994, 	 loss: 0.0010
# 	 Validation string, 	 i: 1971; 	 prediction: -0.4207, 	 target: -0.3615, 	 loss: 0.0035
# 	 Validation string, 	 i: 1091; 	 prediction: -0.1565, 	 target: -0.2223, 	 loss: 0.0043
# Epoch [2/2], Loss epoch: 0.0096, Loss validation: 0.0097, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.009497872030648837, std loss: 0.0156278598583329
#
#
#  --- SWEEP POINT 22/40: (2, 1, 4, 'all') ---
#  --- time reamining: 65:07:23.50
#
# Epoch [0/2], Loss epoch: 0.7663, Loss validation: 0.7656
# 	 Validation string, 	 i: 134; 	 prediction: -0.3314, 	 target: -0.4675, 	 loss: 0.0185
# 	 Validation string, 	 i: 772; 	 prediction: -0.2178, 	 target: -0.3010, 	 loss: 0.0069
# 	 Validation string, 	 i: 4339; 	 prediction: -0.1650, 	 target: -0.0901, 	 loss: 0.0056
# Epoch [1/2], Loss epoch: 0.0112, Loss validation: 0.0104, Time remaining: ~0.0h 6.0m 15s
# 	 Validation string, 	 i: 2448; 	 prediction: -0.2229, 	 target: -0.2683, 	 loss: 0.0021
# 	 Validation string, 	 i: 3107; 	 prediction: -0.2547, 	 target: -0.2728, 	 loss: 0.0003
# 	 Validation string, 	 i: 1801; 	 prediction: -0.3656, 	 target: -0.4494, 	 loss: 0.0070
# Epoch [2/2], Loss epoch: 0.0096, Loss validation: 0.0101, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.009689318792766115, std loss: 0.015053369527292552
#
#
#  --- SWEEP POINT 23/40: (2, 1, 6, 1) ---
#  --- time reamining: 59:08:38.98
#
# Epoch [0/2], Loss epoch: 0.4614, Loss validation: 0.4620
# 	 Validation string, 	 i: 564; 	 prediction: -0.2041, 	 target: -0.1767, 	 loss: 0.0008
# 	 Validation string, 	 i: 3832; 	 prediction: -0.3139, 	 target: -0.3857, 	 loss: 0.0051
# 	 Validation string, 	 i: 2690; 	 prediction: -0.1390, 	 target: -0.1278, 	 loss: 0.0001
# Epoch [1/2], Loss epoch: 0.0092, Loss validation: 0.0086, Time remaining: ~0.0h 8.0m 1s
# 	 Validation string, 	 i: 1811; 	 prediction: -0.3021, 	 target: -0.2151, 	 loss: 0.0076
# 	 Validation string, 	 i: 3106; 	 prediction: -0.4803, 	 target: -0.5061, 	 loss: 0.0007
# 	 Validation string, 	 i: 1102; 	 prediction: -0.2170, 	 target: -0.2129, 	 loss: 0.0000
# Epoch [2/2], Loss epoch: 0.0082, Loss validation: 0.0083, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.008121455605214354, std loss: 0.014212432478856904
#
#
#  --- SWEEP POINT 24/40: (2, 1, 6, 'all') ---
#  --- time reamining: 53:44:40.74
#
# Epoch [0/2], Loss epoch: 0.0273, Loss validation: 0.0274
# 	 Validation string, 	 i: 367; 	 prediction: -0.5123, 	 target: -0.4939, 	 loss: 0.0003
# 	 Validation string, 	 i: 3648; 	 prediction: -0.1573, 	 target: -0.1371, 	 loss: 0.0004
# 	 Validation string, 	 i: 238; 	 prediction: -0.3837, 	 target: -0.4285, 	 loss: 0.0020
# Epoch [1/2], Loss epoch: 0.0082, Loss validation: 0.0077, Time remaining: ~0.0h 8.0m 19s
# 	 Validation string, 	 i: 195; 	 prediction: -0.2526, 	 target: -0.1476, 	 loss: 0.0110
# 	 Validation string, 	 i: 3124; 	 prediction: -0.2238, 	 target: -0.0318, 	 loss: 0.0368
# 	 Validation string, 	 i: 2187; 	 prediction: -0.3871, 	 target: -0.4962, 	 loss: 0.0119
# Epoch [2/2], Loss epoch: 0.0076, Loss validation: 0.0072, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.007142980066136867, std loss: 0.011319371220882926
#
#
#  --- SWEEP POINT 25/40: (2, 2, 4, 1) ---
#  --- time reamining: 48:46:15.69
#
# Epoch [0/2], Loss epoch: 0.9696, Loss validation: 0.9707
# 	 Validation string, 	 i: 1730; 	 prediction: -0.4691, 	 target: -0.4138, 	 loss: 0.0031
# 	 Validation string, 	 i: 3225; 	 prediction: -0.2523, 	 target: -0.0773, 	 loss: 0.0306
# 	 Validation string, 	 i: 1869; 	 prediction: -0.5131, 	 target: -0.3398, 	 loss: 0.0300
# Epoch [1/2], Loss epoch: 0.0117, Loss validation: 0.0100, Time remaining: ~0.0h 7.0m 16s
# 	 Validation string, 	 i: 3221; 	 prediction: -0.1676, 	 target: -0.4945, 	 loss: 0.1068
# 	 Validation string, 	 i: 369; 	 prediction: -0.3827, 	 target: -0.5073, 	 loss: 0.0155
# 	 Validation string, 	 i: 3437; 	 prediction: -0.1303, 	 target: -0.1162, 	 loss: 0.0002
# Epoch [2/2], Loss epoch: 0.0095, Loss validation: 0.0095, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.009371156726700476, std loss: 0.014231184581558426
#
#
#  --- SWEEP POINT 26/40: (2, 2, 4, 'all') ---
#  --- time reamining: 44:07:15.43
#
# Epoch [0/2], Loss epoch: 0.0225, Loss validation: 0.0227
# 	 Validation string, 	 i: 970; 	 prediction: -0.3278, 	 target: -0.1665, 	 loss: 0.0260
# 	 Validation string, 	 i: 2120; 	 prediction: -0.2084, 	 target: -0.1496, 	 loss: 0.0035
# 	 Validation string, 	 i: 3178; 	 prediction: -0.2927, 	 target: -0.1975, 	 loss: 0.0091
# Epoch [1/2], Loss epoch: 0.0094, Loss validation: 0.0087, Time remaining: ~0.0h 7.0m 24s
# 	 Validation string, 	 i: 2777; 	 prediction: -0.2619, 	 target: -0.4099, 	 loss: 0.0219
# 	 Validation string, 	 i: 548; 	 prediction: -0.1907, 	 target: -0.1913, 	 loss: 0.0000
# 	 Validation string, 	 i: 2756; 	 prediction: -0.1404, 	 target: -0.2054, 	 loss: 0.0042
# Epoch [2/2], Loss epoch: 0.0087, Loss validation: 0.0087, Time remaining: ~0.0h 0.0m 0s
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 0.008496119793947732, std loss: 0.013779764231874962
#
#
#  --- SWEEP POINT 27/40: (2, 2, 6, 1) ---
#  --- time reamining: 39:48:13.56
#
# Epoch [0/2], Loss epoch: 0.2313, Loss validation: 0.2316
#  - Epoch [1/2], i: [131680/397780], Loss: 0.0183
