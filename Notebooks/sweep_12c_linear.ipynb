# %%
initial_path = 'peptide-QML'
# initial_path = '..'

# %%
import sys
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import helper_classes as c
from my_code import pytorch_model as m
from my_code import quantum_nodes as q
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# name of the notebook
name_notebook = "sweep_6c_linear"

# %%
# sweep = c.Sweep(
#     name_notebook, 
#     initial_path=initial_path,
#     description="Linear classical network to compare with 0926-sweep_6h_er_Aqm",
#     repetitions=list(range(1, 6)),
# )

# %%
# sweep.save()

# %%
sweep = c.Sweep.load(file_name=name_notebook+"-1", day='0927', initial_path=initial_path)

# %%
for sweep_point in sweep.points_left:

    # print the point of the sweep
    sweep.print_sweep_status(sweep_point['idx'])

    n_qubits = 6

    # -- MODEL -- #                    
    class Model(m.Model):
        def __init__(self):
            super(Model, self).__init__()
            self.fc1 = m.nn.Embedding(num_embeddings=19, embedding_dim=1)
            self.fc2 = m.Reshape()            
            self.fc4 = m.nn.Linear(n_qubits, 1)

        def forward(self, x):
            for i in [1,2,4]:
                x = getattr(self, 'fc{}'.format(i))(x)
            return x

    model = Model()

    # set the name and path of the model
    model.set_name_and_path(name_notebook, initial_path)

    #set sweep point
    model.set_sweep_point(
        sweep_uuid = sweep.uuid,
        sweep_point = sweep_point,
        day=sweep.day
    )

    # -- TRAIN -- #
    model.optimize_params(
        #save info
        save_model_info = True,
        description = 'repetition sweep: Linear classical network to compare with 0926-sweep_6h_er_Aqm',    
        #data
        data=c.Data.load(initial_path=initial_path, file_name='PE_SCORES_6_Numbers'),
        # train options
        optimizer = m.optim.Adam,
        optimizer_options = {'lr': 0.01},
        num_epochs = 20,                
        batch_size = 32,
        # early stopping options
        stop_training_options = {
            'lookback_epochs': 5, 
            'threshold_slope': 0.001,
            'threshold_std_dev': 0.2
        },
        # metadata
        metadata = {}
    )

    # -- VALIDATION and PLOTS -- #
    model.plot_losses(fig_size=(6,6))
    model.validate(
        pct=1,
        add_to_results=True,
        plot=True,
        print_items=False
    )

    # -- SAVE RESULTS -- #
    model.save_results()

    # -- ADD DATA GENERATED TO SWEEP -- #
    sweep.add_data(
        idx=sweep_point['idx'],
        model_uuid=model.uuid,
        best_loss_train=model.results.loss_epoch.best,
        best_loss_test=model.results.loss_validation_epoch.best,
        loss_validation=model.mean_loss_validation,
        n_parameters=model.n_parameters,
        time_train=model.results.time_epoch.last,
    )
    sweep.save(csv=False) #TODO: save csv=False automatically when sweep is already saved ion csv
# Out:
#  --- SWEEP POINT 1/5: (1,) ---
#  --- parameters sweeping: ['repetitions']
#
# Epoch [0/20], Loss epoch: 131.7734, Loss validation: 132.3589
#  - Epoch [1/20], i: [7008/11284], Loss: 38.37976
# 	 Validation string, 	 i: 83; 	 prediction: -8.4861, 	 target: -7.2100, 	 loss: 1.6283
# 	 Validation string, 	 i: 73; 	 prediction: -4.0263, 	 target: -6.4000, 	 loss: 5.6346
# 	 Validation string, 	 i: 31; 	 prediction: -10.8742, 	 target: -4.1100, 	 loss: 45.7540
# Epoch [1/20], Loss epoch: 51.3761, Loss validation: 19.1236, Time remaining: ~0.0h 0.0m 6s
# 	 Validation string, 	 i: 70; 	 prediction: -11.7132, 	 target: -15.6800, 	 loss: 15.7356
# 	 Validation string, 	 i: 40; 	 prediction: -9.9799, 	 target: -8.1100, 	 loss: 3.4965
# 	 Validation string, 	 i: 36; 	 prediction: -2.7200, 	 target: -7.5700, 	 loss: 23.5221
# Epoch [2/20], Loss epoch: 21.1962, Loss validation: 15.8194, Time remaining: ~0.0h 0.0m 6s
# 	 Validation string, 	 i: 15; 	 prediction: -17.7564, 	 target: -13.4300, 	 loss: 18.7173
# 	 Validation string, 	 i: 24; 	 prediction: -8.6988, 	 target: -2.0200, 	 loss: 44.6060
# 	 Validation string, 	 i: 62; 	 prediction: -16.8028, 	 target: -23.7000, 	 loss: 47.5714
# Epoch [3/20], Loss epoch: 19.7112, Loss validation: 15.6838, Time remaining: ~0.0h 0.0m 6s
# 	 Validation string, 	 i: 1; 	 prediction: -8.9494, 	 target: -12.2800, 	 loss: 11.0926
# 	 Validation string, 	 i: 48; 	 prediction: -16.6401, 	 target: -17.4400, 	 loss: 0.6398
# 	 Validation string, 	 i: 14; 	 prediction: -14.8175, 	 target: -15.1200, 	 loss: 0.0915
# Epoch [4/20], Loss epoch: 19.5588, Loss validation: 16.1772, Time remaining: ~0.0h 0.0m 6s
# 	 Validation string, 	 i: 29; 	 prediction: -12.8218, 	 target: -13.7700, 	 loss: 0.8990
# 	 Validation string, 	 i: 21; 	 prediction: -7.6378, 	 target: -9.6300, 	 loss: 3.9690
# 	 Validation string, 	 i: 17; 	 prediction: -7.9341, 	 target: -11.0100, 	 loss: 9.4613
# Epoch [5/20], Loss epoch: 19.5028, Loss validation: 16.0669, Time remaining: ~0.0h 0.0m 5s
# 	 Validation string, 	 i: 109; 	 prediction: -10.5867, 	 target: -13.7200, 	 loss: 9.8177
# 	 Validation string, 	 i: 92; 	 prediction: -10.2528, 	 target: -8.6600, 	 loss: 2.5369
# 	 Validation string, 	 i: 44; 	 prediction: -13.9060, 	 target: -17.0700, 	 loss: 10.0107
# Epoch [6/20], Loss epoch: 19.4976, Loss validation: 16.3448, Time remaining: ~0.0h 0.0m 5s
# 	 Validation string, 	 i: 42; 	 prediction: -10.3119, 	 target: -13.2800, 	 loss: 8.8098
# 	 Validation string, 	 i: 22; 	 prediction: -10.2349, 	 target: -0.9300, 	 loss: 86.5809
# 	 Validation string, 	 i: 105; 	 prediction: -10.1719, 	 target: -16.3900, 	 loss: 38.6648
# Epoch [7/20], Loss epoch: 19.4724, Loss validation: 15.9073, Time remaining: ~0.0h 0.0m 4s
# 	 Validation string, 	 i: 97; 	 prediction: -15.1478, 	 target: -18.7300, 	 loss: 12.8321
# 	 Validation string, 	 i: 2; 	 prediction: -12.3238, 	 target: -10.2300, 	 loss: 4.3840
# 	 Validation string, 	 i: 85; 	 prediction: -10.8963, 	 target: -10.3800, 	 loss: 0.2665
# Epoch [8/20], Loss epoch: 19.4755, Loss validation: 16.0234, Time remaining: ~0.0h 0.0m 4s
# 	 Validation string, 	 i: 58; 	 prediction: -12.8308, 	 target: -12.8600, 	 loss: 0.0009
# 	 Validation string, 	 i: 107; 	 prediction: -6.4699, 	 target: -8.3800, 	 loss: 3.6486
# 	 Validation string, 	 i: 22; 	 prediction: -10.2262, 	 target: -0.9300, 	 loss: 86.4193
# Epoch [9/20], Loss epoch: 19.4693, Loss validation: 15.4438, Time remaining: ~0.0h 0.0m 4s
# 	 Validation string, 	 i: 123; 	 prediction: -12.5615, 	 target: -15.2800, 	 loss: 7.3904
# 	 Validation string, 	 i: 64; 	 prediction: -9.8777, 	 target: -14.8300, 	 loss: 24.5255
# 	 Validation string, 	 i: 51; 	 prediction: -10.1887, 	 target: -17.7400, 	 loss: 57.0226
# Epoch [10/20], Loss epoch: 19.4583, Loss validation: 16.2257, Time remaining: ~0.0h 0.0m 3s
# 	 Validation string, 	 i: 49; 	 prediction: -12.7007, 	 target: -18.0400, 	 loss: 28.5078
# 	 Validation string, 	 i: 113; 	 prediction: -14.4370, 	 target: -17.7300, 	 loss: 10.8441
# 	 Validation string, 	 i: 51; 	 prediction: -10.3692, 	 target: -17.7400, 	 loss: 54.3287
# Epoch [11/20], Loss epoch: 19.4633, Loss validation: 15.8724, Time remaining: ~0.0h 0.0m 3s
# 	 Validation string, 	 i: 36; 	 prediction: -2.8754, 	 target: -7.5700, 	 loss: 22.0388
# 	 Validation string, 	 i: 124; 	 prediction: -4.7788, 	 target: -7.4900, 	 loss: 7.3508
# 	 Validation string, 	 i: 82; 	 prediction: -4.4212, 	 target: -6.8800, 	 loss: 6.0458
# Epoch [12/20], Loss epoch: 19.5063, Loss validation: 15.8716, Time remaining: ~0.0h 0.0m 3s
# The loss is not changing anymore, so we stop training.
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 18.7211923885174, std loss: 28.087675327268588
#
#
#  --- SWEEP POINT 2/5: (2,) ---
#  --- time reamining: 01:03:02.56
#
# Epoch [0/20], Loss epoch: 133.8536, Loss validation: 134.7457
# 	 Validation string, 	 i: 38; 	 prediction: -14.2462, 	 target: -14.4300, 	 loss: 0.0338
# 	 Validation string, 	 i: 11; 	 prediction: -8.6505, 	 target: 4.0300, 	 loss: 160.7961
# 	 Validation string, 	 i: 1; 	 prediction: -11.4045, 	 target: -12.2800, 	 loss: 0.7665
# Epoch [1/20], Loss epoch: 47.3018, Loss validation: 18.5042, Time remaining: ~0.0h 0.0m 6s
# 	 Validation string, 	 i: 14; 	 prediction: -14.8076, 	 target: -15.1200, 	 loss: 0.0976
# 	 Validation string, 	 i: 103; 	 prediction: -10.3307, 	 target: -14.4800, 	 loss: 17.2167
# 	 Validation string, 	 i: 3; 	 prediction: -5.0743, 	 target: -5.5500, 	 loss: 0.2263
# Epoch [2/20], Loss epoch: 21.1355, Loss validation: 15.7411, Time remaining: ~0.0h 0.0m 6s
# 	 Validation string, 	 i: 58; 	 prediction: -12.6289, 	 target: -12.8600, 	 loss: 0.0534
# 	 Validation string, 	 i: 78; 	 prediction: -10.2861, 	 target: -8.7800, 	 loss: 2.2683
# 	 Validation string, 	 i: 86; 	 prediction: -8.0355, 	 target: -8.3800, 	 loss: 0.1187
# Epoch [3/20], Loss epoch: 19.7937, Loss validation: 15.9204, Time remaining: ~0.0h 0.0m 5s
# 	 Validation string, 	 i: 2; 	 prediction: -12.4540, 	 target: -10.2300, 	 loss: 4.9460
# 	 Validation string, 	 i: 82; 	 prediction: -4.2647, 	 target: -6.8800, 	 loss: 6.8399
# 	 Validation string, 	 i: 82; 	 prediction: -4.2647, 	 target: -6.8800, 	 loss: 6.8399
# Epoch [4/20], Loss epoch: 19.6049, Loss validation: 15.9699, Time remaining: ~0.0h 0.0m 5s
# 	 Validation string, 	 i: 67; 	 prediction: -7.9520, 	 target: -7.5600, 	 loss: 0.1537
# 	 Validation string, 	 i: 28; 	 prediction: -13.4835, 	 target: -20.0700, 	 loss: 43.3822
# 	 Validation string, 	 i: 5; 	 prediction: -6.4277, 	 target: -14.3900, 	 loss: 63.3990
# Epoch [5/20], Loss epoch: 19.5164, Loss validation: 15.6124, Time remaining: ~0.0h 0.0m 5s
# 	 Validation string, 	 i: 94; 	 prediction: -6.1606, 	 target: -5.8800, 	 loss: 0.0787
# 	 Validation string, 	 i: 89; 	 prediction: -13.2902, 	 target: -8.3100, 	 loss: 24.8029
# 	 Validation string, 	 i: 17; 	 prediction: -8.3337, 	 target: -11.0100, 	 loss: 7.1626
# Epoch [6/20], Loss epoch: 19.4830, Loss validation: 15.8970, Time remaining: ~0.0h 0.0m 4s
# 	 Validation string, 	 i: 52; 	 prediction: -7.8883, 	 target: -6.7800, 	 loss: 1.2284
# 	 Validation string, 	 i: 48; 	 prediction: -16.4499, 	 target: -17.4400, 	 loss: 0.9803
# 	 Validation string, 	 i: 80; 	 prediction: -17.0531, 	 target: -13.3100, 	 loss: 14.0106
# Epoch [7/20], Loss epoch: 19.4558, Loss validation: 15.6912, Time remaining: ~0.0h 0.0m 4s
# 	 Validation string, 	 i: 92; 	 prediction: -10.7445, 	 target: -8.6600, 	 loss: 4.3453
# 	 Validation string, 	 i: 38; 	 prediction: -12.3881, 	 target: -14.4300, 	 loss: 4.1693
# 	 Validation string, 	 i: 4; 	 prediction: -8.0071, 	 target: -5.8800, 	 loss: 4.5244
# Epoch [8/20], Loss epoch: 19.4630, Loss validation: 15.5453, Time remaining: ~0.0h 0.0m 4s
# 	 Validation string, 	 i: 48; 	 prediction: -16.2837, 	 target: -17.4400, 	 loss: 1.3371
# 	 Validation string, 	 i: 1; 	 prediction: -8.6378, 	 target: -12.2800, 	 loss: 13.2655
# 	 Validation string, 	 i: 2; 	 prediction: -11.9850, 	 target: -10.2300, 	 loss: 3.0799
# Epoch [9/20], Loss epoch: 19.4561, Loss validation: 16.5131, Time remaining: ~0.0h 0.0m 3s
# 	 Validation string, 	 i: 74; 	 prediction: -6.5405, 	 target: -8.8000, 	 loss: 5.1055
# 	 Validation string, 	 i: 51; 	 prediction: -9.9361, 	 target: -17.7400, 	 loss: 60.9001
# 	 Validation string, 	 i: 29; 	 prediction: -12.8299, 	 target: -13.7700, 	 loss: 0.8838
# Epoch [10/20], Loss epoch: 19.4937, Loss validation: 16.6448, Time remaining: ~0.0h 0.0m 3s
# The loss is not changing anymore, so we stop training.
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 18.965929772237512, std loss: 27.649772446320462
#
#
#  --- SWEEP POINT 3/5: (3,) ---
#  --- time reamining: 00:23:44.15
#
# Epoch [0/20], Loss epoch: 147.3084, Loss validation: 148.0805
# 	 Validation string, 	 i: 82; 	 prediction: -5.6210, 	 target: -6.8800, 	 loss: 1.5850
# 	 Validation string, 	 i: 37; 	 prediction: -5.4668, 	 target: -6.6100, 	 loss: 1.3070
# 	 Validation string, 	 i: 30; 	 prediction: -8.4359, 	 target: -9.0000, 	 loss: 0.3182
# Epoch [1/20], Loss epoch: 54.9643, Loss validation: 15.8525, Time remaining: ~0.0h 0.0m 6s
# 	 Validation string, 	 i: 110; 	 prediction: -6.5130, 	 target: -11.1600, 	 loss: 21.5945
# 	 Validation string, 	 i: 86; 	 prediction: -7.7909, 	 target: -8.3800, 	 loss: 0.3471
# 	 Validation string, 	 i: 90; 	 prediction: -6.3166, 	 target: 2.2600, 	 loss: 73.5576
# Epoch [2/20], Loss epoch: 20.3214, Loss validation: 16.2684, Time remaining: ~0.0h 0.0m 5s
# 	 Validation string, 	 i: 49; 	 prediction: -13.0280, 	 target: -18.0400, 	 loss: 25.1198
# 	 Validation string, 	 i: 26; 	 prediction: -3.9963, 	 target: -8.8100, 	 loss: 23.1713
# 	 Validation string, 	 i: 41; 	 prediction: -8.1797, 	 target: -9.4300, 	 loss: 1.5632
# Epoch [3/20], Loss epoch: 19.6196, Loss validation: 16.3215, Time remaining: ~0.0h 0.0m 5s
# 	 Validation string, 	 i: 12; 	 prediction: -13.8233, 	 target: -14.9600, 	 loss: 1.2921
# 	 Validation string, 	 i: 123; 	 prediction: -12.5626, 	 target: -15.2800, 	 loss: 7.3844
# 	 Validation string, 	 i: 4; 	 prediction: -8.6297, 	 target: -5.8800, 	 loss: 7.5608
# Epoch [4/20], Loss epoch: 19.5249, Loss validation: 15.8340, Time remaining: ~0.0h 0.0m 5s
# 	 Validation string, 	 i: 21; 	 prediction: -8.0038, 	 target: -9.6300, 	 loss: 2.6445
# 	 Validation string, 	 i: 93; 	 prediction: -5.4732, 	 target: -10.0700, 	 loss: 21.1303
# 	 Validation string, 	 i: 14; 	 prediction: -15.4862, 	 target: -15.1200, 	 loss: 0.1341
# Epoch [5/20], Loss epoch: 19.4784, Loss validation: 15.4342, Time remaining: ~0.0h 0.0m 5s
# 	 Validation string, 	 i: 103; 	 prediction: -10.0088, 	 target: -14.4800, 	 loss: 19.9913
# 	 Validation string, 	 i: 92; 	 prediction: -10.0014, 	 target: -8.6600, 	 loss: 1.7995
# 	 Validation string, 	 i: 92; 	 prediction: -10.0014, 	 target: -8.6600, 	 loss: 1.7995
# Epoch [6/20], Loss epoch: 19.4592, Loss validation: 17.0304, Time remaining: ~0.0h 0.0m 4s
# 	 Validation string, 	 i: 39; 	 prediction: -12.7458, 	 target: -17.2400, 	 loss: 20.1979
# 	 Validation string, 	 i: 121; 	 prediction: -5.1747, 	 target: -11.3600, 	 loss: 38.2580
# 	 Validation string, 	 i: 56; 	 prediction: -9.5436, 	 target: -8.2800, 	 loss: 1.5968
# Epoch [7/20], Loss epoch: 19.4590, Loss validation: 16.4594, Time remaining: ~0.0h 0.0m 4s
# 	 Validation string, 	 i: 29; 	 prediction: -12.8650, 	 target: -13.7700, 	 loss: 0.8190
# 	 Validation string, 	 i: 55; 	 prediction: -10.1482, 	 target: -16.4600, 	 loss: 39.8387
# 	 Validation string, 	 i: 15; 	 prediction: -17.4804, 	 target: -13.4300, 	 loss: 16.4057
# Epoch [8/20], Loss epoch: 19.4616, Loss validation: 15.7293, Time remaining: ~0.0h 0.0m 4s
# 	 Validation string, 	 i: 86; 	 prediction: -6.7827, 	 target: -8.3800, 	 loss: 2.5515
# 	 Validation string, 	 i: 54; 	 prediction: -8.6770, 	 target: -12.9800, 	 loss: 18.5160
# 	 Validation string, 	 i: 38; 	 prediction: -12.1711, 	 target: -14.4300, 	 loss: 5.1026
# Epoch [9/20], Loss epoch: 19.4667, Loss validation: 15.9576, Time remaining: ~0.0h 0.0m 3s
# 	 Validation string, 	 i: 31; 	 prediction: -9.4751, 	 target: -4.1100, 	 loss: 28.7842
# 	 Validation string, 	 i: 56; 	 prediction: -9.7955, 	 target: -8.2800, 	 loss: 2.2966
# 	 Validation string, 	 i: 75; 	 prediction: -8.4187, 	 target: -8.5900, 	 loss: 0.0293
# Epoch [10/20], Loss epoch: 19.4652, Loss validation: 15.8986, Time remaining: ~0.0h 0.0m 3s
# The loss is not changing anymore, so we stop training.
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 18.716182556673058, std loss: 28.262615925763477
#
#
#  --- SWEEP POINT 4/5: (4,) ---
#  --- time reamining: 00:10:35.56
#
# Epoch [0/20], Loss epoch: 145.9984, Loss validation: 148.3643
# 	 Validation string, 	 i: 110; 	 prediction: -5.7289, 	 target: -11.1600, 	 loss: 29.4968
# 	 Validation string, 	 i: 108; 	 prediction: -6.0590, 	 target: 1.7300, 	 loss: 60.6681
# 	 Validation string, 	 i: 119; 	 prediction: -9.4708, 	 target: -11.7100, 	 loss: 5.0139
# Epoch [1/20], Loss epoch: 54.8780, Loss validation: 18.3770, Time remaining: ~0.0h 0.0m 7s
# 	 Validation string, 	 i: 8; 	 prediction: -5.6113, 	 target: -5.6800, 	 loss: 0.0047
# 	 Validation string, 	 i: 53; 	 prediction: -1.4196, 	 target: 1.1300, 	 loss: 6.5007
# 	 Validation string, 	 i: 39; 	 prediction: -12.3823, 	 target: -17.2400, 	 loss: 23.5968
# Epoch [2/20], Loss epoch: 21.5498, Loss validation: 15.4664, Time remaining: ~0.0h 0.0m 6s
# 	 Validation string, 	 i: 85; 	 prediction: -11.3132, 	 target: -10.3800, 	 loss: 0.8709
# 	 Validation string, 	 i: 115; 	 prediction: -7.1132, 	 target: -9.4300, 	 loss: 5.3674
# 	 Validation string, 	 i: 28; 	 prediction: -13.8791, 	 target: -20.0700, 	 loss: 38.3272
# Epoch [3/20], Loss epoch: 19.8104, Loss validation: 15.7609, Time remaining: ~0.0h 0.0m 5s
# 	 Validation string, 	 i: 25; 	 prediction: -11.6675, 	 target: -8.5900, 	 loss: 9.4710
# 	 Validation string, 	 i: 61; 	 prediction: -4.7985, 	 target: -7.3000, 	 loss: 6.2573
# 	 Validation string, 	 i: 37; 	 prediction: -3.6835, 	 target: -6.6100, 	 loss: 8.5646
# Epoch [4/20], Loss epoch: 19.5689, Loss validation: 16.3624, Time remaining: ~0.0h 0.0m 5s
# 	 Validation string, 	 i: 20; 	 prediction: -11.0861, 	 target: -12.8900, 	 loss: 3.2542
# 	 Validation string, 	 i: 21; 	 prediction: -7.6085, 	 target: -9.6300, 	 loss: 4.0866
# 	 Validation string, 	 i: 105; 	 prediction: -10.1301, 	 target: -16.3900, 	 loss: 39.1868
# Epoch [5/20], Loss epoch: 19.4996, Loss validation: 16.1285, Time remaining: ~0.0h 0.0m 4s
# 	 Validation string, 	 i: 124; 	 prediction: -4.5018, 	 target: -7.4900, 	 loss: 8.9291
# 	 Validation string, 	 i: 112; 	 prediction: -9.6602, 	 target: -16.0500, 	 loss: 40.8297
# 	 Validation string, 	 i: 102; 	 prediction: -12.8238, 	 target: -10.0700, 	 loss: 7.5833
# Epoch [6/20], Loss epoch: 19.4659, Loss validation: 16.2859, Time remaining: ~0.0h 0.0m 4s
# 	 Validation string, 	 i: 17; 	 prediction: -8.1877, 	 target: -11.0100, 	 loss: 7.9654
# 	 Validation string, 	 i: 43; 	 prediction: -7.7071, 	 target: -5.4900, 	 loss: 4.9156
# 	 Validation string, 	 i: 94; 	 prediction: -6.2708, 	 target: -5.8800, 	 loss: 0.1527
# Epoch [7/20], Loss epoch: 19.4483, Loss validation: 15.6083, Time remaining: ~0.0h 0.0m 4s
# 	 Validation string, 	 i: 1; 	 prediction: -8.6924, 	 target: -12.2800, 	 loss: 12.8711
# 	 Validation string, 	 i: 124; 	 prediction: -5.1263, 	 target: -7.4900, 	 loss: 5.5873
# 	 Validation string, 	 i: 96; 	 prediction: -13.3375, 	 target: -11.2600, 	 loss: 4.3162
# Epoch [8/20], Loss epoch: 19.4683, Loss validation: 15.9918, Time remaining: ~0.0h 0.0m 4s
# 	 Validation string, 	 i: 32; 	 prediction: -13.0757, 	 target: -15.5600, 	 loss: 6.1717
# 	 Validation string, 	 i: 77; 	 prediction: -5.7092, 	 target: -7.8300, 	 loss: 4.4978
# 	 Validation string, 	 i: 28; 	 prediction: -13.3539, 	 target: -20.0700, 	 loss: 45.1053
# Epoch [9/20], Loss epoch: 19.4781, Loss validation: 16.0144, Time remaining: ~0.0h 0.0m 3s
# 	 Validation string, 	 i: 63; 	 prediction: -4.0205, 	 target: -4.3500, 	 loss: 0.1086
# 	 Validation string, 	 i: 33; 	 prediction: -12.0577, 	 target: -15.8900, 	 loss: 14.6864
# 	 Validation string, 	 i: 75; 	 prediction: -8.4442, 	 target: -8.5900, 	 loss: 0.0213
# Epoch [10/20], Loss epoch: 19.4763, Loss validation: 15.7169, Time remaining: ~0.0h 0.0m 3s
# The loss is not changing anymore, so we stop training.
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 18.66605080152408, std loss: 28.667355722411344
#
#
#  --- SWEEP POINT 5/5: (5,) ---
#  --- time reamining: 00:03:59.26
#
# Epoch [0/20], Loss epoch: 138.6824, Loss validation: 139.2973
# 	 Validation string, 	 i: 14; 	 prediction: -14.9399, 	 target: -15.1200, 	 loss: 0.0324
# 	 Validation string, 	 i: 118; 	 prediction: -6.8522, 	 target: -3.7600, 	 loss: 9.5619
# 	 Validation string, 	 i: 73; 	 prediction: -5.0541, 	 target: -6.4000, 	 loss: 1.8115
# Epoch [1/20], Loss epoch: 47.9238, Loss validation: 17.6236, Time remaining: ~0.0h 0.0m 6s
# 	 Validation string, 	 i: 52; 	 prediction: -7.4575, 	 target: -6.7800, 	 loss: 0.4590
# 	 Validation string, 	 i: 28; 	 prediction: -13.8499, 	 target: -20.0700, 	 loss: 38.6892
# 	 Validation string, 	 i: 69; 	 prediction: -7.1811, 	 target: -5.5500, 	 loss: 2.6606
# Epoch [2/20], Loss epoch: 19.6984, Loss validation: 15.6608, Time remaining: ~0.0h 0.0m 6s
# 	 Validation string, 	 i: 33; 	 prediction: -11.7559, 	 target: -15.8900, 	 loss: 17.0905
# 	 Validation string, 	 i: 36; 	 prediction: -2.6925, 	 target: -7.5700, 	 loss: 23.7899
# 	 Validation string, 	 i: 98; 	 prediction: -10.8144, 	 target: -15.2100, 	 loss: 19.3209
# Epoch [3/20], Loss epoch: 19.4914, Loss validation: 15.9488, Time remaining: ~0.0h 0.0m 5s
# 	 Validation string, 	 i: 53; 	 prediction: 0.2353, 	 target: 1.1300, 	 loss: 0.8006
# 	 Validation string, 	 i: 77; 	 prediction: -5.7549, 	 target: -7.8300, 	 loss: 4.3062
# 	 Validation string, 	 i: 5; 	 prediction: -6.1259, 	 target: -14.3900, 	 loss: 68.2953
# Epoch [4/20], Loss epoch: 19.4733, Loss validation: 15.7941, Time remaining: ~0.0h 0.0m 5s
# 	 Validation string, 	 i: 9; 	 prediction: -13.7786, 	 target: -18.6800, 	 loss: 24.0233
# 	 Validation string, 	 i: 121; 	 prediction: -5.5870, 	 target: -11.3600, 	 loss: 33.3278
# 	 Validation string, 	 i: 32; 	 prediction: -12.4478, 	 target: -15.5600, 	 loss: 9.6861
# Epoch [5/20], Loss epoch: 19.4756, Loss validation: 17.1023, Time remaining: ~0.0h 0.0m 5s
# 	 Validation string, 	 i: 124; 	 prediction: -4.9350, 	 target: -7.4900, 	 loss: 6.5281
# 	 Validation string, 	 i: 56; 	 prediction: -9.3266, 	 target: -8.2800, 	 loss: 1.0953
# 	 Validation string, 	 i: 89; 	 prediction: -13.4896, 	 target: -8.3100, 	 loss: 26.8283
# Epoch [6/20], Loss epoch: 19.4799, Loss validation: 16.2924, Time remaining: ~0.0h 0.0m 4s
# 	 Validation string, 	 i: 80; 	 prediction: -17.0542, 	 target: -13.3100, 	 loss: 14.0188
# 	 Validation string, 	 i: 16; 	 prediction: -10.3668, 	 target: -16.3100, 	 loss: 35.3211
# 	 Validation string, 	 i: 121; 	 prediction: -5.5297, 	 target: -11.3600, 	 loss: 33.9923
# Epoch [7/20], Loss epoch: 19.4838, Loss validation: 15.7073, Time remaining: ~0.0h 0.0m 4s
# The loss is not changing anymore, so we stop training.
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 18.70596688475047, std loss: 28.104273412029528
