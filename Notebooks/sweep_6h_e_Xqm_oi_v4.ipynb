# %%
initial_path = 'peptide-QML'
# initial_path = '..'

# %%
import sys, random
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import helper_classes as c
from my_code import pytorch_model as m
from my_code import quantum_nodes as q

# %%
# name of the notebook
name_notebook = "sweep_6h_e_Xqm_oi_v4"

# %%
# sweep = c.Sweep(
#     name_notebook, 
#     initial_path=initial_path,
#     description="(6aa, 6q) (generate inputs) Try to find best number of q. layers, measurement, and type of Anzatz.",
#     repetitions=list(range(1, 4)),
#     ansatz=[q.parts.Ansatz_11, q.parts.Ansatz_full_conn, q.parts.Ansatz_11_2],
#     measurement = [1, 'all'],
#     block_n_layers=[4,9,14,19,24,29],
# )

# %%
# sweep.save()

# %%
sweep = c.Sweep.load(file_name=name_notebook+"-1", day='1004', initial_path=initial_path)

# %%
for sweep_point in sweep.points_left:

    # print the point of the sweep
    sweep.print_sweep_status(sweep_point['idx'])

    # -- QUANTUM BLOCK -- #
    n_qubits = 6
    quantum_layer = q.circuit(
        n_qubits = n_qubits, 
        device = "default.qubit.torch",
        device_options = {'shots': None},
        embedding = q.parts.AngleEmbedding,
        # embedding_ansatz = sweep_point['ansatz'],
        block_ansatz = sweep_point['ansatz'],
        final_ansatz = sweep_point['ansatz'], 
        measurement = q.parts.Measurement('Z', sweep_point['measurement']),
        # embedding_n_layers = sweep_point['embedding_n_layers'],
        # different_inputs_per_layer = False,
        block_n_layers = sweep_point['block_n_layers'],
        # wrapper_qlayer = pw.QLayerEmpty,
    )

    # -- MODEL -- #   

    class Tan(m.nn.Module):
        def __init__(self):
            super(Tan, self).__init__()

        def forward(self, x):
            return m.torch.tan(x * m.np.pi / 2)    
                
    class Model(m.Model):
        def __init__(self):
            super(Model, self).__init__()
            self.fc1 = m.nn.Embedding(num_embeddings=19, embedding_dim=1)
            self.fc2 = m.Reshape()
            self.fc3 = quantum_layer()   
            qubits_measured = n_qubits if sweep_point['measurement']=='all' else 1
            self.fc4 = m.nn.Linear(qubits_measured, qubits_measured)         
            self.fc5 = Tan()
            self.fc6 = m.nn.Linear(qubits_measured, 1)

        def forward(self, x):
            for i in [1,2,3,4,5,6]:
                x = getattr(self, 'fc{}'.format(i))(x)
            return x

    model = Model()

    # set seed
    seed_random = random.randint(0, 1000000)
    m.torch.manual_seed(seed_random)

    # set quantum layer
    model.set_quantum_layer(quantum_layer)

    # set the name and path of the model
    model.set_name_and_path(name_notebook, initial_path)

    #set sweep point
    model.set_sweep_point(
        sweep_uuid = sweep.uuid,
        sweep_point = sweep_point,
        day=sweep.day
    )

    # -- TRAIN -- #
    model.optimize_params(
        #save info
        save_model_info = True,
        description = 'sweep with 6 aa and 6 q -> Try to find best number of q. layers, measurement, and type of Anzatz.',    
        #data
        data=c.Data.load(initial_path=initial_path, file_name='PE_SCORES_6_Numbers'),
        # train options
        optimizer = m.optim.Adam,
        optimizer_options = {'lr': 0.01},
        num_epochs = 20,                
        batch_size = 32,
        # early stopping options
        stop_training_options = {
            'lookback_epochs': 5, 
            'threshold_slope': 0.001,
            'threshold_std_dev': 0.2
        },
        # metadata
        metadata = {
            'seed_random': seed_random,
            'Tan_layer': 'tan(x * pi/2)',
        }
    )

    # load best model
    model.load_state_dict_from_results(state_dict_name="parameters_epoch", rule="best")

    # -- VALIDATION and PLOTS -- #
    model.plot_losses(fig_size=(6,6))
    model.validate(
        pct=1,
        add_to_results=True,
        plot=True,
        print_items=False
    )

    # -- SAVE RESULTS -- #
    model.save_results()

    # -- GENERATE PEPTIDES and SAVE THEM -- #    
    oi_time = m.t.time()
    n_peptides = 20
    for i in range(n_peptides):
        model.get_input_with_low_score(
            layers_to_use = ['fc3', 'fc4', 'fc5', 'fc6'],
            n_iter = 1000,
            optimizer = m.torch.optim.Adam,
            optimizer_options = {'lr': 0.1},
            stop_criterion = 1e-3,
            initialization_seed = i,
        )
        print("{}/{} peptides generated. Score {}. \t Time remaining: {:.2f} min \t\t\t ".format(
            i+1, n_peptides, model.optimized_inputs[-1][1], (n_peptides-i)*(m.t.time() - oi_time)/(i+1)/60
        ), end='\r')
    oi_time = m.t.time() - oi_time
    model.save_input_optimization_results()
    best_oi, best_oi_score = model.best_optimized_input
    print("Best score: {} \t\t\t\t\t\t  ".format(best_oi_score))

    # -- ADD DATA GENERATED TO SWEEP -- #
    sweep.add_data(
        idx=sweep_point['idx'],
        model_uuid=model.uuid,
        best_loss_train=model.results.loss_epoch.best,
        best_loss_test=model.results.loss_validation_epoch.best,
        loss_validation=model.mean_loss_validation,
        loss_validation_r_squared=model.results.validation['r_squared'],
        n_parameters=model.n_parameters,
        time_train=model.results.time_epoch.last,
        best_oi=best_oi,
        best_oi_score=best_oi_score,
        oi_time=oi_time,
    )
    sweep.save(csv=False) #TODO: save csv=False automatically when sweep is already saved ion csv
# Out:
#  --- SWEEP POINT 1/108: (1, <class 'my_code.quantum_nodes.parts.Ansatz_11'>, 1, 4) ---
#  --- parameters sweeping: ['repetitions', 'ansatz', 'measurement', 'block_n_layers']
#
# Epoch [0/20], Loss epoch: 152.5549, Loss validation: 153.9552
# 	 Validation string, 	 i: 58; 	 prediction: -12.0655, 	 target: -12.8600, 	 loss: 0.6312
# 	 Validation string, 	 i: 6; 	 prediction: -9.2042, 	 target: -9.3000, 	 loss: 0.0092
# 	 Validation string, 	 i: 29; 	 prediction: -10.1340, 	 target: -13.7700, 	 loss: 13.2207
# Epoch [1/20], Loss epoch: 52.4725, Loss validation: 23.3976, Time remaining: ~0.0h 11.0m 11s
# 	 Validation string, 	 i: 27; 	 prediction: -13.4099, 	 target: -9.6500, 	 loss: 14.1367
# 	 Validation string, 	 i: 81; 	 prediction: -7.2390, 	 target: -1.5700, 	 loss: 32.1377
# 	 Validation string, 	 i: 99; 	 prediction: -7.3686, 	 target: -1.4300, 	 loss: 35.2668
# Epoch [2/20], Loss epoch: 28.8120, Loss validation: 19.8644, Time remaining: ~0.0h 10.0m 0s
# 	 Validation string, 	 i: 64; 	 prediction: -10.8117, 	 target: -14.8300, 	 loss: 16.1468
# 	 Validation string, 	 i: 9; 	 prediction: -13.9039, 	 target: -18.6800, 	 loss: 22.8112
# 	 Validation string, 	 i: 85; 	 prediction: -10.3010, 	 target: -10.3800, 	 loss: 0.0062
# Epoch [3/20], Loss epoch: 25.3778, Loss validation: 19.1148, Time remaining: ~0.0h 9.0m 12s
# 	 Validation string, 	 i: 92; 	 prediction: -10.3497, 	 target: -8.6600, 	 loss: 2.8551
# 	 Validation string, 	 i: 110; 	 prediction: -7.1871, 	 target: -11.1600, 	 loss: 15.7836
# 	 Validation string, 	 i: 36; 	 prediction: -6.0593, 	 target: -7.5700, 	 loss: 2.2822
# Epoch [4/20], Loss epoch: 25.2466, Loss validation: 22.1544, Time remaining: ~0.0h 8.0m 24s
# 	 Validation string, 	 i: 89; 	 prediction: -8.1691, 	 target: -8.3100, 	 loss: 0.0198
# 	 Validation string, 	 i: 48; 	 prediction: -11.7730, 	 target: -17.4400, 	 loss: 32.1149
# 	 Validation string, 	 i: 47; 	 prediction: -13.3310, 	 target: -6.6300, 	 loss: 44.9041
# Epoch [5/20], Loss epoch: 25.0524, Loss validation: 20.8709, Time remaining: ~0.0h 7.0m 43s
# 	 Validation string, 	 i: 94; 	 prediction: -6.9069, 	 target: -5.8800, 	 loss: 1.0545
# 	 Validation string, 	 i: 87; 	 prediction: -12.4726, 	 target: -12.8400, 	 loss: 0.1350
# 	 Validation string, 	 i: 66; 	 prediction: -6.5772, 	 target: -17.1800, 	 loss: 112.4191
# Epoch [6/20], Loss epoch: 24.7124, Loss validation: 23.4132, Time remaining: ~0.0h 7.0m 7s
# 	 Validation string, 	 i: 0; 	 prediction: -11.1909, 	 target: -22.1200, 	 loss: 119.4449
# 	 Validation string, 	 i: 98; 	 prediction: -9.1466, 	 target: -15.2100, 	 loss: 36.7643
# 	 Validation string, 	 i: 65; 	 prediction: -9.5114, 	 target: -20.1300, 	 loss: 112.7536
# Epoch [7/20], Loss epoch: 24.7138, Loss validation: 21.3287, Time remaining: ~0.0h 6.0m 32s
# 	 Validation string, 	 i: 46; 	 prediction: -12.2207, 	 target: -15.6400, 	 loss: 11.6914
# 	 Validation string, 	 i: 20; 	 prediction: -7.4614, 	 target: -12.8900, 	 loss: 29.4701
# 	 Validation string, 	 i: 25; 	 prediction: -13.3674, 	 target: -8.5900, 	 loss: 22.8233
# Epoch [8/20], Loss epoch: 24.0433, Loss validation: 18.6484, Time remaining: ~0.0h 5.0m 58s
# 	 Validation string, 	 i: 93; 	 prediction: -5.2273, 	 target: -10.0700, 	 loss: 23.4515
# 	 Validation string, 	 i: 68; 	 prediction: -14.3447, 	 target: -12.4700, 	 loss: 3.5144
# 	 Validation string, 	 i: 88; 	 prediction: -7.4215, 	 target: -5.4500, 	 loss: 3.8869
# Epoch [9/20], Loss epoch: 24.0647, Loss validation: 19.4746, Time remaining: ~0.0h 5.0m 30s
# 	 Validation string, 	 i: 108; 	 prediction: -6.2503, 	 target: 1.7300, 	 loss: 63.6851
# 	 Validation string, 	 i: 96; 	 prediction: -13.8117, 	 target: -11.2600, 	 loss: 6.5110
# 	 Validation string, 	 i: 54; 	 prediction: -8.5135, 	 target: -12.9800, 	 loss: 19.9497
# Epoch [10/20], Loss epoch: 23.9763, Loss validation: 18.3899, Time remaining: ~0.0h 5.0m 1s
# 	 Validation string, 	 i: 36; 	 prediction: -6.8148, 	 target: -7.5700, 	 loss: 0.5704
# 	 Validation string, 	 i: 2; 	 prediction: -10.8801, 	 target: -10.2300, 	 loss: 0.4227
# 	 Validation string, 	 i: 72; 	 prediction: -6.8606, 	 target: -2.7200, 	 loss: 17.1444
# Epoch [11/20], Loss epoch: 24.5296, Loss validation: 20.7922, Time remaining: ~0.0h 4.0m 32s
# 	 Validation string, 	 i: 115; 	 prediction: -7.3052, 	 target: -9.4300, 	 loss: 4.5149
# 	 Validation string, 	 i: 87; 	 prediction: -11.6988, 	 target: -12.8400, 	 loss: 1.3024
# 	 Validation string, 	 i: 90; 	 prediction: -6.0255, 	 target: 2.2600, 	 loss: 68.6490
# Epoch [12/20], Loss epoch: 23.6552, Loss validation: 16.6627, Time remaining: ~0.0h 4.0m 2s
# 	 Validation string, 	 i: 103; 	 prediction: -10.5539, 	 target: -14.4800, 	 loss: 15.4146
# 	 Validation string, 	 i: 96; 	 prediction: -10.6380, 	 target: -11.2600, 	 loss: 0.3869
# 	 Validation string, 	 i: 115; 	 prediction: -6.4855, 	 target: -9.4300, 	 loss: 8.6701
# Epoch [13/20], Loss epoch: 23.1593, Loss validation: 20.2400, Time remaining: ~0.0h 3.0m 33s
# 	 Validation string, 	 i: 87; 	 prediction: -13.5391, 	 target: -12.8400, 	 loss: 0.4888
# 	 Validation string, 	 i: 13; 	 prediction: -7.3423, 	 target: -6.9000, 	 loss: 0.1956
# 	 Validation string, 	 i: 23; 	 prediction: -11.1909, 	 target: -11.7600, 	 loss: 0.3238
# Epoch [14/20], Loss epoch: 22.8677, Loss validation: 21.9265, Time remaining: ~0.0h 3.0m 3s
# 	 Validation string, 	 i: 50; 	 prediction: -9.8255, 	 target: -14.2900, 	 loss: 19.9316
# 	 Validation string, 	 i: 22; 	 prediction: -14.4994, 	 target: -0.9300, 	 loss: 184.1283
# 	 Validation string, 	 i: 43; 	 prediction: -6.6567, 	 target: -5.4900, 	 loss: 1.3611
# Epoch [15/20], Loss epoch: 22.6454, Loss validation: 18.5759, Time remaining: ~0.0h 2.0m 33s
# 	 Validation string, 	 i: 119; 	 prediction: -11.0561, 	 target: -11.7100, 	 loss: 0.4276
# 	 Validation string, 	 i: 65; 	 prediction: -14.9627, 	 target: -20.1300, 	 loss: 26.7009
# 	 Validation string, 	 i: 53; 	 prediction: -5.1998, 	 target: 1.1300, 	 loss: 40.0661
# Epoch [16/20], Loss epoch: 22.2929, Loss validation: 18.1692, Time remaining: ~0.0h 2.0m 2s
# 	 Validation string, 	 i: 9; 	 prediction: -13.1066, 	 target: -18.6800, 	 loss: 31.0627
# 	 Validation string, 	 i: 64; 	 prediction: -9.6930, 	 target: -14.8300, 	 loss: 26.3892
# 	 Validation string, 	 i: 106; 	 prediction: -8.3030, 	 target: -5.8200, 	 loss: 6.1651
# Epoch [17/20], Loss epoch: 22.1704, Loss validation: 19.4372, Time remaining: ~0.0h 1.0m 32s
# 	 Validation string, 	 i: 82; 	 prediction: -6.8402, 	 target: -6.8800, 	 loss: 0.0016
# 	 Validation string, 	 i: 49; 	 prediction: -12.6476, 	 target: -18.0400, 	 loss: 29.0776
# 	 Validation string, 	 i: 63; 	 prediction: -5.5843, 	 target: -4.3500, 	 loss: 1.5235
# Epoch [18/20], Loss epoch: 22.1258, Loss validation: 17.9705, Time remaining: ~0.0h 1.0m 1s
# 	 Validation string, 	 i: 2; 	 prediction: -12.5845, 	 target: -10.2300, 	 loss: 5.5436
# 	 Validation string, 	 i: 78; 	 prediction: -9.8229, 	 target: -8.7800, 	 loss: 1.0877
# 	 Validation string, 	 i: 72; 	 prediction: -7.3431, 	 target: -2.7200, 	 loss: 21.3731
# Epoch [19/20], Loss epoch: 21.7990, Loss validation: 15.9187, Time remaining: ~0.0h 0.0m 31s
# 	 Validation string, 	 i: 107; 	 prediction: -8.7792, 	 target: -8.3800, 	 loss: 0.1594
# 	 Validation string, 	 i: 117; 	 prediction: -14.7013, 	 target: -18.1000, 	 loss: 11.5513
# 	 Validation string, 	 i: 8; 	 prediction: -8.0216, 	 target: -5.6800, 	 loss: 5.4833
# Epoch [20/20], Loss epoch: 21.7062, Loss validation: 16.3686, Time remaining: ~0.0h 0.0m 0s
# Loaded best state_dict from results.
# Progress: 100.00%. 			 Ending in 0.00 minutes
# Mean loss: 20.614057679376195, std loss: 31.439121731721347, r^2: 0.4586365190066405
# Best score: -32.583571139627374 						                    20/20 peptides generated. Score -12.19319693784537. 	 Time remaining: 0.11 min
#
#
#  --- SWEEP POINT 2/108: (1, <class 'my_code.quantum_nodes.parts.Ansatz_11'>, 1, 9) ---
#  --- time reamining: 23:38:00.27
#
# Epoch [0/20], Loss epoch: 147.7667, Loss validation: 148.8494
#  - Epoch [1/20], i: [3296/11284], Loss: 169.864820
