# %%
initial_path = 'peptide-QML'
# initial_path = '..'

# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import helper_classes as c

# %% [markdown]
# # 0927-sweep_12c_linear-1

# %%
sweep = c.Sweep.load(
    initial_path=initial_path,
    day='0927',
    file_name='sweep_12c_linear-1',
)
sweep.lists.keys()
# Out:
# dict_keys(['idx', 'repetitions', 'model_uuid', 'best_loss_train', 'best_loss_test', 'loss_validation', 'n_parameters', 'time_train'])

# %%
sweep.plot(
    x_key='n_parameters',
    y_key='loss_validation',
    legend_keys=[],
    fit_degree=2,
    replace=[],
    fix = [],
)
# Out:
# /home/raul/.local/lib/python3.8/site-packages/pennylane/numpy/wrapper.py:117: RankWarning: Polyfit may be poorly conditioned
#   res = obj(*args, **kwargs)
# No handles with labels found to put in legend.

# %% [markdown]
# # 0926-sweep_12h_er_Aqm-3

# %%
sweep = c.Sweep.load(
            initial_path=initial_path,
            day='0926',
            file_name='sweep_12h_er_Aqm-3',
        )
sweep.lists.keys()
# Out:
# dict_keys(['idx', 'repetitions', 'embedding_n_layers', 'block_n_layers', 'ansatz', 'model_uuid', 'best_loss_train', 'best_loss_test', 'loss_validation', 'n_parameters', 'time_train'])

# %%
# list(zip(sweep.lists['embedding_dim'], sweep.lists['quantum_n_layers'], sweep.lists['quantum_measurement'], sweep.lists['n_parameters']))

# %%
sweep.plot(
    x_key='n_parameters',
    y_key='loss_validation',
    legend_keys=['ansatz'],
    fit_degree=2,
    replace=[("<class 'my_code.quantum_nodes.parts.Ansatz_full_conn'>", 'full_conn'), ("<class 'my_code.quantum_nodes.parts.Ansatz_11'>", '11')],
    fix = [],
    to_string = ['ansatz'],
)

# %%
sweep.plot(
    x_key='block_n_layers',
    y_key='loss_validation',
    legend_keys=['ansatz'],
    fit_degree=2,
    replace=[("<class 'my_code.quantum_nodes.parts.Ansatz_full_conn'>", 'full_conn'), ("<class 'my_code.quantum_nodes.parts.Ansatz_11'>", '11')],
    fix = [],
    to_string = ['ansatz'],
)

# %%
sweep.plot(
    x_key='embedding_n_layers',
    y_key='loss_validation',
    legend_keys=['ansatz'],
    fit_degree=2,
    replace=[("<class 'my_code.quantum_nodes.parts.Ansatz_full_conn'>", 'full_conn'), ("<class 'my_code.quantum_nodes.parts.Ansatz_11'>", '11')],
    fix = [],
    to_string = ['ansatz'],
)
# Out:
# /home/raul/.local/lib/python3.8/site-packages/pennylane/numpy/wrapper.py:117: RankWarning: Polyfit may be poorly conditioned
#   res = obj(*args, **kwargs)
# /home/raul/.local/lib/python3.8/site-packages/pennylane/numpy/wrapper.py:117: RankWarning: Polyfit may be poorly conditioned
#   res = obj(*args, **kwargs)
