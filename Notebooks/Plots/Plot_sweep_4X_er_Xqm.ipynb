# %%
initial_path = 'peptide-QML'
# initial_path = '..'

# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import helper_classes as c
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # sweep_4h_er_Xqm-2

# %%
sweep = c.Sweep.load(
    initial_path=initial_path,
    day='0921',
    file_name='sweep_4h_er_Xqm-2',
)
sweep.lists.keys()
# Out:
# dict_keys(['idx', 'repetitions', 'quantum_n_layers', 'quantum_measurement', 'embedding_dim', 'model_uuid', 'best_loss_train', 'best_loss_test', 'loss_validation', 'n_parameters', 'time_train'])

# %%
print(sweep.lists['n_parameters'])
# Out:
# [153, 184, 215, 246, 277, 308, 153, 184, 215, 246, 277, 308, 156, 187, 218, 249, 280, 311, 153, 184, 215, 246, 277, 308, 153, 184, 215, 246, 277, 308, 156, 187, 218, 249, 280, 311, 153, 184, 215, 246, 277, 308, 153, 184]

# %%
sweep.plot(
    x_key='n_parameters',
    y_key='loss_validation',
    legend_keys=[],
    fit_degree=2,
    replace=[('embedding_dim', 'dim embedding'), ('loss_validation', 'loss validation')],
    fix = [],
)
# Out:
# No handles with labels found to put in legend.

# %%
sweep.plot(
    x_key='embedding_dim',
    y_key='loss_validation',
    legend_keys=['quantum_n_layers'],
    fit_degree=1,
    replace=[('embedding_dim', 'dim embedding'), ('loss_validation', 'loss validation')],
    fix = [('quantum_measurement', '0')],
)

# %%
sweep.plot(
    x_key='embedding_dim',
    y_key='loss_validation',
    legend_keys=['quantum_n_layers'],
    fit_degree=1,
    replace=[('embedding_dim', 'dim embedding'), ('loss_validation', 'loss validation')],
    fix = [('quantum_measurement', '1')],
)

# %%
sweep.plot(
    x_key='embedding_dim',
    y_key='loss_validation',
    legend_keys=['quantum_n_layers'],
    fit_degree=1,
    replace=[('embedding_dim', 'dim embedding'), ('loss_validation', 'loss validation')],
    fix = [('quantum_measurement', 'all')],
)
