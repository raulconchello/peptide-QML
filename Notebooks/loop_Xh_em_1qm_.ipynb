# %%
initial_path = 'peptide-QML/'
# initial_path = '../'

# %%
import numpy as np
import sys
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import functions as f
from my_code import pytorch_model as ptm
from my_code import quantum_nodes as qn
from my_code import pytorch_wrappers as pw
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.0.4) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
for num in [4, 6, 8, 10, 12]:
    print("## --- Num: ", num, " --- ##")
    print("")
    print("")

    for type_energy in ['', '_Single', '_Pair']:

        # -- DATA -- #

        # name of the notebook
        day = "0831"
        name_notebook = "{}-{}h_em_1qm{}.ipynb".format(day, num, type_energy)
        # save the name of the notebook
        with open('{}_notebooks_names.txt'.format(day), 'a') as file:
            file.write(name_notebook + '\n')

        # load data
        data_file_path = '{}data/Scores/PET/generated/bb14_Strings_Energies{}_10_000_{}_aa.txt'.format(initial_path, type_energy, num)  
        string_list, number_list = f.read_data_file(data_file_path)
        score_list = np.array(number_list)/1000
        vector_list = np.array([f.string_to_numbers(string) for string in string_list]) 
        X, Y, X_validation, Y_validation = f.create_validating_set(vector_list, score_list, percentage=0.1)

        # Define the dataset
        input_data = ptm.torch.tensor(X) 
        target_data = ptm.torch.tensor(Y).view(-1, 1)

        # Define the validation set
        input_validation = ptm.torch.tensor(X_validation)
        target_validation = ptm.torch.tensor(Y_validation).view(-1, 1)


        # -- TRAINING LOOP -- #
        for iii in range(5):

            for block_n_layers in range(1, 21, 2):
                print(iii, " # ------- block_n_layers: ", block_n_layers, " ------- #")
                print("")
                print("")

                # -- QUANTUM NODE -- #

                n_aminoacids = len(string_list[0])

                quantum_layer = qn.circuit(
                    n_qubits = n_aminoacids, 
                    device = "default.qubit.torch",
                    device_options = {'shots': None},
                    embedding = qn.parts.AngleEmbedding, 
                    # embedding_ansatz = qn.parts.Ansatz_11,
                    block_ansatz = qn.parts.Ansatz_11,
                    final_ansatz = qn.parts.Ansatz_final_11,
                    measurement = qn.parts.Measurement('Z', (n_aminoacids-1)//2),
                    # embedding_n_layers = 4,
                    # different_inputs_per_layer = True,
                    block_n_layers = block_n_layers,
                    # wrapper_qlayer = pw.QLayerEmpty,
                )

                # -- HYBRID MODEL -- #
                input_dim = input_data.size(1)

                n_pre_classical_layers = 4
                layers_dim = np.linspace(n_aminoacids, input_dim, 4).astype(int)

                import torch.nn as nn
                import torch
                    
                class Reshape(nn.Module):
                    def __init__(self):
                        super(Reshape, self).__init__()

                    def forward(self, x):
                        dims = len(x.shape)
                        return torch.transpose(x, dims-2, dims-1).reshape(x.shape[-3] if dims==3 else 1, x.shape[-2]*x.shape[-1]).squeeze()

                layers =  [ptm.nn.Embedding(num_embeddings=19, embedding_dim=quantum_layer.input_shape[0]//n_aminoacids), Reshape()]
                layers += [quantum_layer(), ptm.nn.Linear(1,1)]

                # Create model and set data:
                model = ptm.pytorch_model(
                    layers,    
                    save_options = {'initial_path': initial_path, 'name_notebook': name_notebook},
                )
                model.set_data(
                    data_X=input_data, 
                    data_Y=target_data, 
                    data_X_validation=input_validation,
                    data_Y_validation=target_validation
                )
                model.keep_track_params=False


                # -- TRAINING -- #
                import torch.optim as optim

                # train the model
                model.train(
                    optimizer= optim.Adam,
                    optimizer_options={'lr': 0.05},
                    num_epochs = 30,                
                    batch_size = 32,
                    stop_training_options = {
                        'lookback_epochs': 5, 
                        'threshold': 0.005
                    },
                )

                # save string of the model
                model.save_str(
                    metadata={
                        "data_file_path": data_file_path,
                        "Quantum_circuit": quantum_layer.__str__(),
                    }
                )

                # plot the losses of the trainig loop and save the figures
                model.plot_losses(save=True, save_txt=True)

                #save all the parameters of the model and the intermediate parameters of the model
                model.save_state_dict(intermediate=False)

                # plot the validation and save it
                model.plot_validation(save=True, fig_size=(9,9), percentatge=1)

                # print validation and save it
                model.str_validation(save=True, precision=4, percentatge=1, printing=False)
# Out:
# ## --- Num:  4  --- ##
#
#
# 0  # ------- block_n_layers:  1  ------- #
#
#
# Folder 'peptide-QML/checkpoints/0831' created successfully.
# Folder 'peptide-QML/checkpoints/0831/models' created successfully.
# Folder 'peptide-QML/checkpoints/0831/plots' created successfully.
# Folder 'peptide-QML/checkpoints/0831/pdfs' created successfully.
# Folder 'peptide-QML/checkpoints/0831/notebooks' created successfully.
# Folder 'peptide-QML/checkpoints/0831/txts' created successfully.
# Folder 'peptide-QML/checkpoints/0831/versions' created successfully.
# Epoch [0/30], Loss: 5.4774, Loss validation: 6.4478
# - Epoch [1/30], i: [224/9000], Loss: 3.1340
# /usr/lib/python3/dist-packages/torch/autograd/__init__.py:147: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:115.)
#   Variable._execution_engine.run_backward(
# 	 Validation string, 	 i: 0; 	 prediction: 0.1909, 	 target: 0.1892, 	 loss: 0.0090
# 	 Validation string, 	 i: 1; 	 prediction: -0.0628, 	 target: -0.0786, 	 loss: 0.2008
# 	 Validation string, 	 i: 2; 	 prediction: -0.0893, 	 target: -0.0655, 	 loss: 0.3640
# Epoch [1/30], Loss: 0.8050, Loss validation: 0.6378, Time remaining: ~0.0h 2.0m 37s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1879, 	 target: 0.1892, 	 loss: 0.0071
# 	 Validation string, 	 i: 1; 	 prediction: -0.0542, 	 target: -0.0786, 	 loss: 0.3097
# 	 Validation string, 	 i: 2; 	 prediction: -0.0857, 	 target: -0.0655, 	 loss: 0.3087
# Epoch [2/30], Loss: 0.4903, Loss validation: 0.5253, Time remaining: ~0.0h 2.0m 21s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1586, 	 target: 0.1892, 	 loss: 0.1615
# 	 Validation string, 	 i: 1; 	 prediction: -0.0796, 	 target: -0.0786, 	 loss: 0.0131
# 	 Validation string, 	 i: 2; 	 prediction: -0.0618, 	 target: -0.0655, 	 loss: 0.0561
# Epoch [3/30], Loss: 0.4130, Loss validation: 0.5414, Time remaining: ~0.0h 2.0m 13s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1703, 	 target: 0.1892, 	 loss: 0.0997
# 	 Validation string, 	 i: 1; 	 prediction: -0.0365, 	 target: -0.0786, 	 loss: 0.5355
# 	 Validation string, 	 i: 2; 	 prediction: -0.0508, 	 target: -0.0655, 	 loss: 0.2245
# Epoch [4/30], Loss: 0.4074, Loss validation: 0.5051, Time remaining: ~0.0h 2.0m 6s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1917, 	 target: 0.1892, 	 loss: 0.0130
# 	 Validation string, 	 i: 1; 	 prediction: -0.0550, 	 target: -0.0786, 	 loss: 0.2997
# 	 Validation string, 	 i: 2; 	 prediction: -0.0826, 	 target: -0.0655, 	 loss: 0.2603
# Epoch [5/30], Loss: 0.4001, Loss validation: 0.5011, Time remaining: ~0.0h 2.0m 0s
# 	 Validation string, 	 i: 0; 	 prediction: 0.2050, 	 target: 0.1892, 	 loss: 0.0834
# 	 Validation string, 	 i: 1; 	 prediction: -0.0437, 	 target: -0.0786, 	 loss: 0.4443
# 	 Validation string, 	 i: 2; 	 prediction: -0.0529, 	 target: -0.0655, 	 loss: 0.1923
# Epoch [6/30], Loss: 0.3983, Loss validation: 0.4943, Time remaining: ~0.0h 1.0m 55s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1623, 	 target: 0.1892, 	 loss: 0.1423
# 	 Validation string, 	 i: 1; 	 prediction: -0.0783, 	 target: -0.0786, 	 loss: 0.0032
# 	 Validation string, 	 i: 2; 	 prediction: -0.0876, 	 target: -0.0655, 	 loss: 0.3369
# Epoch [7/30], Loss: 0.4052, Loss validation: 0.5012, Time remaining: ~0.0h 1.0m 50s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_model_str_1.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_batches_1.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_1.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_validation_1.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_batches_1.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_1.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_validation_1.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_1.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_validation_1.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_validation_1.txt
# 0  # ------- block_n_layers:  3  ------- #
#
#
# Epoch [0/30], Loss: 3.9106, Loss validation: 5.0859
# 	 Validation string, 	 i: 0; 	 prediction: 0.2388, 	 target: 0.1892, 	 loss: 0.2619
# 	 Validation string, 	 i: 1; 	 prediction: -0.0535, 	 target: -0.0786, 	 loss: 0.3192
# 	 Validation string, 	 i: 2; 	 prediction: 0.0334, 	 target: -0.0655, 	 loss: 1.5091
# Epoch [1/30], Loss: 0.8385, Loss validation: 0.6198, Time remaining: ~0.0h 4.0m 31s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1759, 	 target: 0.1892, 	 loss: 0.0705
# 	 Validation string, 	 i: 1; 	 prediction: -0.0735, 	 target: -0.0786, 	 loss: 0.0644
# 	 Validation string, 	 i: 2; 	 prediction: -0.0691, 	 target: -0.0655, 	 loss: 0.0547
# Epoch [2/30], Loss: 0.4299, Loss validation: 0.4922, Time remaining: ~0.0h 4.0m 7s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1487, 	 target: 0.1892, 	 loss: 0.2140
# 	 Validation string, 	 i: 1; 	 prediction: -0.0461, 	 target: -0.0786, 	 loss: 0.4133
# 	 Validation string, 	 i: 2; 	 prediction: -0.0892, 	 target: -0.0655, 	 loss: 0.3615
# Epoch [3/30], Loss: 0.4051, Loss validation: 0.5296, Time remaining: ~0.0h 3.0m 52s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1641, 	 target: 0.1892, 	 loss: 0.1325
# 	 Validation string, 	 i: 1; 	 prediction: -0.0565, 	 target: -0.0786, 	 loss: 0.2814
# 	 Validation string, 	 i: 2; 	 prediction: -0.0607, 	 target: -0.0655, 	 loss: 0.0728
# Epoch [4/30], Loss: 0.4026, Loss validation: 0.5167, Time remaining: ~0.0h 3.0m 40s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1429, 	 target: 0.1892, 	 loss: 0.2447
# 	 Validation string, 	 i: 1; 	 prediction: -0.0515, 	 target: -0.0786, 	 loss: 0.3442
# 	 Validation string, 	 i: 2; 	 prediction: -0.0683, 	 target: -0.0655, 	 loss: 0.0434
# Epoch [5/30], Loss: 0.4089, Loss validation: 0.5190, Time remaining: ~0.0h 3.0m 30s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1702, 	 target: 0.1892, 	 loss: 0.1005
# 	 Validation string, 	 i: 1; 	 prediction: -0.0509, 	 target: -0.0786, 	 loss: 0.3524
# 	 Validation string, 	 i: 2; 	 prediction: -0.0480, 	 target: -0.0655, 	 loss: 0.2666
# Epoch [6/30], Loss: 0.4100, Loss validation: 0.4929, Time remaining: ~0.0h 3.0m 20s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_model_str_2.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_batches_2.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_2.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_validation_2.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_batches_2.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_2.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_validation_2.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_2.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_validation_2.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_validation_2.txt
# 0  # ------- block_n_layers:  5  ------- #
#
#
# Epoch [0/30], Loss: 1.5763, Loss validation: 1.8570
# 	 Validation string, 	 i: 0; 	 prediction: 0.2159, 	 target: 0.1892, 	 loss: 0.1409
# 	 Validation string, 	 i: 1; 	 prediction: -0.0433, 	 target: -0.0786, 	 loss: 0.4486
# 	 Validation string, 	 i: 2; 	 prediction: -0.0583, 	 target: -0.0655, 	 loss: 0.1102
# Epoch [1/30], Loss: 0.6000, Loss validation: 0.4765, Time remaining: ~0.0h 6.0m 28s
# 	 Validation string, 	 i: 0; 	 prediction: 0.2107, 	 target: 0.1892, 	 loss: 0.1139
# 	 Validation string, 	 i: 1; 	 prediction: -0.0273, 	 target: -0.0786, 	 loss: 0.6525
# 	 Validation string, 	 i: 2; 	 prediction: -0.0480, 	 target: -0.0655, 	 loss: 0.2677
# Epoch [2/30], Loss: 0.4152, Loss validation: 0.5186, Time remaining: ~0.0h 5.0m 54s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1638, 	 target: 0.1892, 	 loss: 0.1343
# 	 Validation string, 	 i: 1; 	 prediction: -0.0225, 	 target: -0.0786, 	 loss: 0.7142
# 	 Validation string, 	 i: 2; 	 prediction: -0.0694, 	 target: -0.0655, 	 loss: 0.0590
# Epoch [3/30], Loss: 0.4023, Loss validation: 0.4769, Time remaining: ~0.0h 5.0m 32s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1834, 	 target: 0.1892, 	 loss: 0.0308
# 	 Validation string, 	 i: 1; 	 prediction: -0.0537, 	 target: -0.0786, 	 loss: 0.3168
# 	 Validation string, 	 i: 2; 	 prediction: -0.0610, 	 target: -0.0655, 	 loss: 0.0688
# Epoch [4/30], Loss: 0.4044, Loss validation: 0.4998, Time remaining: ~0.0h 5.0m 15s
# 	 Validation string, 	 i: 0; 	 prediction: 0.2472, 	 target: 0.1892, 	 loss: 0.3067
# 	 Validation string, 	 i: 1; 	 prediction: -0.0336, 	 target: -0.0786, 	 loss: 0.5728
# 	 Validation string, 	 i: 2; 	 prediction: -0.0072, 	 target: -0.0655, 	 loss: 0.8908
# Epoch [5/30], Loss: 0.4039, Loss validation: 0.5325, Time remaining: ~0.0h 5.0m 1s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1918, 	 target: 0.1892, 	 loss: 0.0140
# 	 Validation string, 	 i: 1; 	 prediction: -0.0701, 	 target: -0.0786, 	 loss: 0.1084
# 	 Validation string, 	 i: 2; 	 prediction: -0.0479, 	 target: -0.0655, 	 loss: 0.2685
# Epoch [6/30], Loss: 0.4061, Loss validation: 0.5119, Time remaining: ~0.0h 4.0m 48s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_model_str_3.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_batches_3.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_3.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_validation_3.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_batches_3.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_3.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_validation_3.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_3.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_validation_3.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_validation_3.txt
# 0  # ------- block_n_layers:  7  ------- #
#
#
# Epoch [0/30], Loss: 1.3705, Loss validation: 1.6628
# 	 Validation string, 	 i: 0; 	 prediction: 0.1926, 	 target: 0.1892, 	 loss: 0.0180
# 	 Validation string, 	 i: 1; 	 prediction: -0.0475, 	 target: -0.0786, 	 loss: 0.3950
# 	 Validation string, 	 i: 2; 	 prediction: -0.0345, 	 target: -0.0655, 	 loss: 0.4733
# Epoch [1/30], Loss: 0.5789, Loss validation: 0.5050, Time remaining: ~0.0h 8.0m 30s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1635, 	 target: 0.1892, 	 loss: 0.1360
# 	 Validation string, 	 i: 1; 	 prediction: -0.0798, 	 target: -0.0786, 	 loss: 0.0159
# 	 Validation string, 	 i: 2; 	 prediction: -0.0633, 	 target: -0.0655, 	 loss: 0.0343
# Epoch [2/30], Loss: 0.4459, Loss validation: 0.4959, Time remaining: ~0.0h 7.0m 36s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1942, 	 target: 0.1892, 	 loss: 0.0266
# 	 Validation string, 	 i: 1; 	 prediction: -0.0300, 	 target: -0.0786, 	 loss: 0.6181
# 	 Validation string, 	 i: 2; 	 prediction: -0.0357, 	 target: -0.0655, 	 loss: 0.4554
# Epoch [3/30], Loss: 0.4081, Loss validation: 0.4829, Time remaining: ~0.0h 7.0m 15s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1798, 	 target: 0.1892, 	 loss: 0.0498
# 	 Validation string, 	 i: 1; 	 prediction: -0.0486, 	 target: -0.0786, 	 loss: 0.3818
# 	 Validation string, 	 i: 2; 	 prediction: -0.0393, 	 target: -0.0655, 	 loss: 0.3999
# Epoch [4/30], Loss: 0.4102, Loss validation: 0.4848, Time remaining: ~0.0h 6.0m 51s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1542, 	 target: 0.1892, 	 loss: 0.1847
# 	 Validation string, 	 i: 1; 	 prediction: -0.0544, 	 target: -0.0786, 	 loss: 0.3071
# 	 Validation string, 	 i: 2; 	 prediction: -0.0292, 	 target: -0.0655, 	 loss: 0.5549
# Epoch [5/30], Loss: 0.4210, Loss validation: 0.4822, Time remaining: ~0.0h 6.0m 32s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1312, 	 target: 0.1892, 	 loss: 0.3066
# 	 Validation string, 	 i: 1; 	 prediction: -0.0488, 	 target: -0.0786, 	 loss: 0.3789
# 	 Validation string, 	 i: 2; 	 prediction: -0.0638, 	 target: -0.0655, 	 loss: 0.0257
# Epoch [6/30], Loss: 0.4070, Loss validation: 0.4612, Time remaining: ~0.0h 6.0m 12s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1124, 	 target: 0.1892, 	 loss: 0.4061
# 	 Validation string, 	 i: 1; 	 prediction: -0.0707, 	 target: -0.0786, 	 loss: 0.1009
# 	 Validation string, 	 i: 2; 	 prediction: -0.0643, 	 target: -0.0655, 	 loss: 0.0185
# Epoch [7/30], Loss: 0.4084, Loss validation: 0.6034, Time remaining: ~0.0h 5.0m 55s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_model_str_4.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_batches_4.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_4.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_validation_4.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_batches_4.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_4.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_validation_4.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_4.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_validation_4.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_validation_4.txt
# 0  # ------- block_n_layers:  9  ------- #
#
#
# Epoch [0/30], Loss: 1.8073, Loss validation: 2.1572
# 	 Validation string, 	 i: 0; 	 prediction: 0.1854, 	 target: 0.1892, 	 loss: 0.0199
# 	 Validation string, 	 i: 1; 	 prediction: -0.0583, 	 target: -0.0786, 	 loss: 0.2579
# 	 Validation string, 	 i: 2; 	 prediction: -0.0470, 	 target: -0.0655, 	 loss: 0.2826
# Epoch [1/30], Loss: 0.6829, Loss validation: 0.5512, Time remaining: ~0.0h 10.0m 13s
# 	 Validation string, 	 i: 0; 	 prediction: 0.2069, 	 target: 0.1892, 	 loss: 0.0934
# 	 Validation string, 	 i: 1; 	 prediction: -0.0875, 	 target: -0.0786, 	 loss: 0.1141
# 	 Validation string, 	 i: 2; 	 prediction: -0.0824, 	 target: -0.0655, 	 loss: 0.2586
# Epoch [2/30], Loss: 0.4536, Loss validation: 0.5483, Time remaining: ~0.0h 9.0m 14s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1681, 	 target: 0.1892, 	 loss: 0.1115
# 	 Validation string, 	 i: 1; 	 prediction: 0.0168, 	 target: -0.0786, 	 loss: 1.2138
# 	 Validation string, 	 i: 2; 	 prediction: 0.0050, 	 target: -0.0655, 	 loss: 1.0761
# Epoch [3/30], Loss: 0.4397, Loss validation: 0.5988, Time remaining: ~0.0h 8.0m 41s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1775, 	 target: 0.1892, 	 loss: 0.0616
# 	 Validation string, 	 i: 1; 	 prediction: -0.0350, 	 target: -0.0786, 	 loss: 0.5544
# 	 Validation string, 	 i: 2; 	 prediction: -0.0271, 	 target: -0.0655, 	 loss: 0.5860
# Epoch [4/30], Loss: 0.4288, Loss validation: 0.5036, Time remaining: ~0.0h 8.0m 18s
# 	 Validation string, 	 i: 0; 	 prediction: 0.0866, 	 target: 0.1892, 	 loss: 0.5422
# 	 Validation string, 	 i: 1; 	 prediction: -0.0841, 	 target: -0.0786, 	 loss: 0.0703
# 	 Validation string, 	 i: 2; 	 prediction: -0.0721, 	 target: -0.0655, 	 loss: 0.1004
# Epoch [5/30], Loss: 0.4204, Loss validation: 0.5210, Time remaining: ~0.0h 7.0m 57s
# 	 Validation string, 	 i: 0; 	 prediction: 0.2259, 	 target: 0.1892, 	 loss: 0.1941
# 	 Validation string, 	 i: 1; 	 prediction: -0.0142, 	 target: -0.0786, 	 loss: 0.8193
# 	 Validation string, 	 i: 2; 	 prediction: -0.0132, 	 target: -0.0655, 	 loss: 0.7988
# Epoch [6/30], Loss: 0.4466, Loss validation: 0.6114, Time remaining: ~0.0h 7.0m 36s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1477, 	 target: 0.1892, 	 loss: 0.2196
# 	 Validation string, 	 i: 1; 	 prediction: -0.0453, 	 target: -0.0786, 	 loss: 0.4237
# 	 Validation string, 	 i: 2; 	 prediction: -0.0140, 	 target: -0.0655, 	 loss: 0.7867
# Epoch [7/30], Loss: 0.4330, Loss validation: 0.5467, Time remaining: ~0.0h 7.0m 15s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_model_str_5.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_batches_5.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_5.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_validation_5.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_batches_5.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_5.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_validation_5.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_5.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_validation_5.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_validation_5.txt
# 0  # ------- block_n_layers:  11  ------- #
#
#
# Epoch [0/30], Loss: 4.2804, Loss validation: 4.7253
# 	 Validation string, 	 i: 0; 	 prediction: 0.1459, 	 target: 0.1892, 	 loss: 0.2289
# 	 Validation string, 	 i: 1; 	 prediction: -0.0752, 	 target: -0.0786, 	 loss: 0.0429
# 	 Validation string, 	 i: 2; 	 prediction: -0.0305, 	 target: -0.0655, 	 loss: 0.5341
# Epoch [1/30], Loss: 0.7652, Loss validation: 0.6992, Time remaining: ~0.0h 12.0m 23s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1633, 	 target: 0.1892, 	 loss: 0.1369
# 	 Validation string, 	 i: 1; 	 prediction: -0.0727, 	 target: -0.0786, 	 loss: 0.0749
# 	 Validation string, 	 i: 2; 	 prediction: -0.0451, 	 target: -0.0655, 	 loss: 0.3111
# Epoch [2/30], Loss: 0.6337, Loss validation: 0.6227, Time remaining: ~0.0h 11.0m 9s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1625, 	 target: 0.1892, 	 loss: 0.1409
# 	 Validation string, 	 i: 1; 	 prediction: -0.0685, 	 target: -0.0786, 	 loss: 0.1280
# 	 Validation string, 	 i: 2; 	 prediction: -0.0281, 	 target: -0.0655, 	 loss: 0.5711
# Epoch [3/30], Loss: 0.5820, Loss validation: 0.5697, Time remaining: ~0.0h 10.0m 32s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1745, 	 target: 0.1892, 	 loss: 0.0779
# 	 Validation string, 	 i: 1; 	 prediction: -0.0730, 	 target: -0.0786, 	 loss: 0.0705
# 	 Validation string, 	 i: 2; 	 prediction: -0.0782, 	 target: -0.0655, 	 loss: 0.1933
# Epoch [4/30], Loss: 0.4348, Loss validation: 0.5556, Time remaining: ~0.0h 10.0m 2s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1381, 	 target: 0.1892, 	 loss: 0.2703
# 	 Validation string, 	 i: 1; 	 prediction: -0.0624, 	 target: -0.0786, 	 loss: 0.2062
# 	 Validation string, 	 i: 2; 	 prediction: -0.0670, 	 target: -0.0655, 	 loss: 0.0227
# Epoch [5/30], Loss: 0.4385, Loss validation: 0.5209, Time remaining: ~0.0h 9.0m 34s
# 	 Validation string, 	 i: 0; 	 prediction: 0.2090, 	 target: 0.1892, 	 loss: 0.1049
# 	 Validation string, 	 i: 1; 	 prediction: -0.0198, 	 target: -0.0786, 	 loss: 0.7475
# 	 Validation string, 	 i: 2; 	 prediction: -0.0206, 	 target: -0.0655, 	 loss: 0.6855
# Epoch [6/30], Loss: 0.4222, Loss validation: 0.4967, Time remaining: ~0.0h 9.0m 9s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1755, 	 target: 0.1892, 	 loss: 0.0724
# 	 Validation string, 	 i: 1; 	 prediction: -0.0564, 	 target: -0.0786, 	 loss: 0.2825
# 	 Validation string, 	 i: 2; 	 prediction: -0.0531, 	 target: -0.0655, 	 loss: 0.1890
# Epoch [7/30], Loss: 0.4153, Loss validation: 0.4948, Time remaining: ~0.0h 8.0m 44s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1992, 	 target: 0.1892, 	 loss: 0.0528
# 	 Validation string, 	 i: 1; 	 prediction: -0.0369, 	 target: -0.0786, 	 loss: 0.5299
# 	 Validation string, 	 i: 2; 	 prediction: 0.0022, 	 target: -0.0655, 	 loss: 1.0340
# Epoch [8/30], Loss: 0.4282, Loss validation: 0.4899, Time remaining: ~0.0h 8.0m 19s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_model_str_6.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_batches_6.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_6.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_validation_6.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_batches_6.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_6.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_validation_6.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_6.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_validation_6.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_validation_6.txt
# 0  # ------- block_n_layers:  13  ------- #
#
#
# Epoch [0/30], Loss: 7.5962, Loss validation: 8.7234
# 	 Validation string, 	 i: 0; 	 prediction: 0.1840, 	 target: 0.1892, 	 loss: 0.0273
# 	 Validation string, 	 i: 1; 	 prediction: -0.0143, 	 target: -0.0786, 	 loss: 0.8174
# 	 Validation string, 	 i: 2; 	 prediction: -0.0337, 	 target: -0.0655, 	 loss: 0.4849
# Epoch [1/30], Loss: 0.7562, Loss validation: 0.5038, Time remaining: ~0.0h 14.0m 28s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1678, 	 target: 0.1892, 	 loss: 0.1133
# 	 Validation string, 	 i: 1; 	 prediction: -0.0424, 	 target: -0.0786, 	 loss: 0.4606
# 	 Validation string, 	 i: 2; 	 prediction: 0.0302, 	 target: -0.0655, 	 loss: 1.4603
# Epoch [2/30], Loss: 0.4665, Loss validation: 0.5418, Time remaining: ~0.0h 12.0m 57s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1468, 	 target: 0.1892, 	 loss: 0.2242
# 	 Validation string, 	 i: 1; 	 prediction: -0.0745, 	 target: -0.0786, 	 loss: 0.0518
# 	 Validation string, 	 i: 2; 	 prediction: -0.0229, 	 target: -0.0655, 	 loss: 0.6499
# Epoch [3/30], Loss: 0.4588, Loss validation: 0.4685, Time remaining: ~0.0h 12.0m 15s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1696, 	 target: 0.1892, 	 loss: 0.1036
# 	 Validation string, 	 i: 1; 	 prediction: -0.0261, 	 target: -0.0786, 	 loss: 0.6672
# 	 Validation string, 	 i: 2; 	 prediction: -0.0550, 	 target: -0.0655, 	 loss: 0.1596
# Epoch [4/30], Loss: 0.4644, Loss validation: 0.5001, Time remaining: ~0.0h 11.0m 38s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1096, 	 target: 0.1892, 	 loss: 0.4206
# 	 Validation string, 	 i: 1; 	 prediction: -0.0216, 	 target: -0.0786, 	 loss: 0.7249
# 	 Validation string, 	 i: 2; 	 prediction: -0.0827, 	 target: -0.0655, 	 loss: 0.2620
# Epoch [5/30], Loss: 0.4715, Loss validation: 0.6122, Time remaining: ~0.0h 11.0m 7s
# 	 Validation string, 	 i: 0; 	 prediction: 0.2017, 	 target: 0.1892, 	 loss: 0.0663
# 	 Validation string, 	 i: 1; 	 prediction: -0.0094, 	 target: -0.0786, 	 loss: 0.8808
# 	 Validation string, 	 i: 2; 	 prediction: -0.0829, 	 target: -0.0655, 	 loss: 0.2651
# Epoch [6/30], Loss: 0.4702, Loss validation: 0.4808, Time remaining: ~0.0h 10.0m 38s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_model_str_7.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_batches_7.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_7.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_validation_7.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_batches_7.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_7.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_validation_7.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_7.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_validation_7.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_validation_7.txt
# 0  # ------- block_n_layers:  15  ------- #
#
#
# Epoch [0/30], Loss: 5.2313, Loss validation: 6.2895
# 	 Validation string, 	 i: 0; 	 prediction: 0.2241, 	 target: 0.1892, 	 loss: 0.1843
# 	 Validation string, 	 i: 1; 	 prediction: -0.0559, 	 target: -0.0786, 	 loss: 0.2889
# 	 Validation string, 	 i: 2; 	 prediction: 0.0022, 	 target: -0.0655, 	 loss: 1.0340
# Epoch [1/30], Loss: 0.7398, Loss validation: 0.6374, Time remaining: ~0.0h 16.0m 30s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1835, 	 target: 0.1892, 	 loss: 0.0302
# 	 Validation string, 	 i: 1; 	 prediction: -0.0399, 	 target: -0.0786, 	 loss: 0.4924
# 	 Validation string, 	 i: 2; 	 prediction: -0.1044, 	 target: -0.0655, 	 loss: 0.5946
# Epoch [2/30], Loss: 0.4978, Loss validation: 0.6024, Time remaining: ~0.0h 14.0m 52s
# 	 Validation string, 	 i: 0; 	 prediction: 0.1272, 	 target: 0.1892, 	 loss: 0.3278
# 	 Validation string, 	 i: 1; 	 prediction: -0.0264, 	 target: -0.0786, 	 loss: 0.6639
# 	 Validation string, 	 i: 2; 	 prediction: -0.0619, 	 target: -0.0655, 	 loss: 0.0553
# Epoch [3/30], Loss: 0.4977, Loss validation: 0.5857, Time remaining: ~0.0h 14.0m 2s
# - Epoch [4/30], i: [3072/9000], Loss: 0.5890
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-2abb2a4e2d8a> in <module>
#      96
#      97                 # train the model
# ---> 98                 model.train(
#      99                     optimizer= optim.Adam,
#     100                     optimizer_options={'lr': 0.05},
#
# ~/peptide-QML/my_code/pytorch_model.py in train(self, loss_function, optimizer, optimizer_options, initialization_options, num_epochs, batch_size, print_batch, validation, n_validation, n_print_validation, time, stop_training_options)
#     158
#     159                 # Forward pass
# --> 160                 outputs = self.model(inputs)
#     161
#     162                 # Compute the loss
#
# /usr/lib/python3/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/lib/python3/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# /usr/lib/python3/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.8/site-packages/pennylane/qnn/torch.py in forward(self, inputs)
#     406         else:
#     407             # calculate the forward pass as usual
# --> 408             results = self._evaluate_qnode(inputs)
#     409
#     410         # reshape to the correct number of batch dims
#
# ~/.local/lib/python3.8/site-packages/pennylane/qnn/torch.py in _evaluate_qnode(self, x)
#     427             **{arg: weight.to(x) for arg, weight in self.qnode_weights.items()},
#     428         }
# --> 429         res = self.qnode(**kwargs)
#     430
#     431         if isinstance(res, torch.Tensor):
#
# ~/.local/lib/python3.8/site-packages/pennylane/qnode.py in __call__(self, *args, **kwargs)
#     948                 self.execute_kwargs.pop("mode")
#     949             # pylint: disable=unexpected-keyword-arg
# --> 950             res = qml.execute(
#     951                 [self.tape],
#     952                 device=self.device,
#
# ~/.local/lib/python3.8/site-packages/pennylane/interfaces/execution.py in execute(tapes, device, gradient_fn, interface, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion, device_batch_transform)
#     509             pass_kwargs=new_device_interface,
#     510         )
# --> 511         results = cached_execute_fn(tapes, execution_config=config)
#     512         return batch_fn(results)
#     513
#
# ~/.local/lib/python3.8/site-packages/pennylane/interfaces/execution.py in wrapper(tapes, **kwargs)
#     285             # execute all unique tapes that do not exist in the cache
#     286             # convert to list as new device interface returns a tuple
# --> 287             res = list(fn(execution_tapes.values(), **kwargs))
#     288
#     289         final_res = []
#
# ~/.local/lib/python3.8/site-packages/pennylane/interfaces/execution.py in fn(tapes, **kwargs)
#     208         def fn(tapes: Sequence[QuantumTape], **kwargs):  # pylint: disable=function-redefined
#     209             tapes = [expand_fn(tape) for tape in tapes]
# --> 210             return original_fn(tapes, **kwargs)
#     211
#     212     @wraps(fn)
#
# /usr/lib/python3.8/contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# ~/.local/lib/python3.8/site-packages/pennylane/_qubit_device.py in batch_execute(self, circuits)
#     601             self.reset()
#     602
# --> 603             res = self.execute(circuit)
#     604             results.append(res)
#     605
#
# ~/.local/lib/python3.8/site-packages/pennylane/devices/default_qubit_torch.py in execute(self, circuit, **kwargs)
#     230                     )
#     231
# --> 232         return super().execute(circuit, **kwargs)
#     233
#     234     def _asarray(self, a, dtype=None):
#
# ~/.local/lib/python3.8/site-packages/pennylane/_qubit_device.py in execute(self, circuit, **kwargs)
#     318
#     319         # apply all circuit operations
# --> 320         self.apply(circuit.operations, rotations=self._get_diagonalizing_gates(circuit), **kwargs)
#     321
#     322         # generate computational basis samples
#
# ~/.local/lib/python3.8/site-packages/pennylane/devices/default_qubit.py in apply(self, operations, rotations, **kwargs)
#     291                 self._state = self._apply_parametrized_evolution(self._state, operation)
#     292             else:
# --> 293                 self._state = self._apply_operation(self._state, operation)
#     294
#     295         # store the pre-rotated state
#
# ~/.local/lib/python3.8/site-packages/pennylane/devices/default_qubit.py in _apply_operation(self, state, operation)
#     331             return self._apply_ops[operation.name](state, axes)
#     332
# --> 333         matrix = self._asarray(self._get_unitary_matrix(operation), dtype=self.C_DTYPE)
#     334
#     335         if operation in diagonal_in_z_basis:
#
# ~/.local/lib/python3.8/site-packages/pennylane/devices/default_qubit_torch.py in _get_unitary_matrix(self, unitary)
#     302         if unitary in diagonal_in_z_basis:
#     303             return self._asarray(unitary.eigvals(), dtype=self.C_DTYPE)
# --> 304         return self._asarray(unitary.matrix(), dtype=self.C_DTYPE)
#     305
#     306     def sample_basis_states(self, number_of_states, state_probability):
#
# ~/.local/lib/python3.8/site-packages/pennylane/operation.py in matrix(self, wire_order)
#     746             tensor_like: matrix representation
#     747         """
# --> 748         canonical_matrix = self.compute_matrix(*self.parameters, **self.hyperparameters)
#     749
#     750         if wire_order is None or self.wires == Wires(wire_order):
#
# ~/.local/lib/python3.8/site-packages/pennylane/ops/qubit/parametric_ops_single_qubit.py in compute_matrix(theta)
#     202
#     203         c = qml.math.cos(theta / 2)
# --> 204         s = qml.math.sin(theta / 2)
#     205         if qml.math.get_interface(theta) == "tensorflow":
#     206             c = qml.math.cast_like(c, 1j)
#
# ~/.local/lib/python3.8/site-packages/autoray/autoray.py in do(fn, like, *args, **kwargs)
#      78     """
#      79     backend = choose_backend(fn, *args, like=like, **kwargs)
# ---> 80     return get_lib_fn(backend, fn)(*args, **kwargs)
#      81
#      82
#
# KeyboardInterrupt:

# %%
# push changes to git
if initial_path != '../':
    # !cd peptide-QML && git add . && git commit -m "data trained model" && git push
