# %%
initial_path = 'peptide-QML/'
# initial_path = '../'

# %%
import numpy as np
import sys
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import functions as f
from my_code import pytorch_model as ptm
from my_code import quantum_nodes as qn
from my_code import pytorch_wrappers as pw
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.0.4) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
for num in [4, 6, 8, 10, 12]:
    print("## --- Num: ", num, " --- ##")
    print("")
    print("")

    for type_energy in ['', '_Single', '_Pair']:

        # -- DATA -- #

        # name of the notebook
        day = "0831"
        name_notebook = "{}-{}h_em_1qm{}.ipynb".format(day, num, type_energy)
        # save the name of the notebook
        with open('{}_notebooks_names.txt'.format(day), 'a') as file:
            file.write(name_notebook + '\n')

        # load data
        data_file_path = '{}data/Scores/PET/generated/bb14_Strings_Energies{}_10_000_{}_aa.txt'.format(initial_path, type_energy, num)  
        string_list, number_list = f.read_data_file(data_file_path)
        score_list = np.array(number_list)/1000
        vector_list = np.array([f.string_to_numbers(string) for string in string_list]) 
        X, Y, X_validation, Y_validation = f.create_validating_set(vector_list, score_list, percentage=0.1)

        # Define the dataset
        input_data = ptm.torch.tensor(X) 
        target_data = ptm.torch.tensor(Y).view(-1, 1)

        # Define the validation set
        input_validation = ptm.torch.tensor(X_validation)
        target_validation = ptm.torch.tensor(Y_validation).view(-1, 1)


        # -- TRAINING LOOP -- #
        for iii in range(5):

            for block_n_layers in range(1, 21, 2):
                print(iii, " # ------- block_n_layers: ", block_n_layers, " ------- #")
                print("")
                print("")

                # -- QUANTUM NODE -- #

                n_aminoacids = len(string_list[0])

                quantum_layer = qn.circuit(
                    n_qubits = n_aminoacids, 
                    device = "default.qubit.torch",
                    device_options = {'shots': None},
                    embedding = qn.parts.AngleEmbedding, 
                    # embedding_ansatz = qn.parts.Ansatz_11,
                    block_ansatz = qn.parts.Ansatz_11,
                    final_ansatz = qn.parts.Ansatz_final_11,
                    measurement = qn.parts.Measurement('Z', (n_aminoacids-1)//2),
                    # embedding_n_layers = 4,
                    # different_inputs_per_layer = True,
                    block_n_layers = block_n_layers,
                    # wrapper_qlayer = pw.QLayerEmpty,
                )

                # -- HYBRID MODEL -- #
                input_dim = input_data.size(1)

                n_pre_classical_layers = 4
                layers_dim = np.linspace(n_aminoacids, input_dim, 4).astype(int)

                import torch.nn as nn
                import torch
                    
                class Reshape(nn.Module):
                    def __init__(self):
                        super(Reshape, self).__init__()

                    def forward(self, x):
                        dims = len(x.shape)
                        return torch.transpose(x, dims-2, dims-1).reshape(x.shape[-3] if dims==3 else 1, x.shape[-2]*x.shape[-1]).squeeze()

                layers =  [ptm.nn.Embedding(num_embeddings=19, embedding_dim=quantum_layer.input_shape[0]//n_aminoacids), Reshape()]
                layers += [quantum_layer(), ptm.nn.Linear(1,1)]

                # Create model and set data:
                model = ptm.pytorch_model(
                    layers,    
                    save_options = {'initial_path': initial_path, 'name_notebook': name_notebook},
                )
                model.set_data(
                    data_X=input_data, 
                    data_Y=target_data, 
                    data_X_validation=input_validation,
                    data_Y_validation=target_validation
                )
                model.keep_track_params=False


                # -- TRAINING -- #
                import torch.optim as optim

                # train the model
                model.train(
                    optimizer= optim.Adam,
                    optimizer_options={'lr': 0.05},
                    num_epochs = 30,                
                    batch_size = 32,
                    stop_training_options = {
                        'lookback_epochs': 5, 
                        'threshold': 0.005
                    },
                )

                # -- SAVE -- #

                # dump the object
                model.dump()

                # save string of the model
                model.save_str(
                    metadata={
                        "data_file_path": data_file_path,
                        "Quantum_circuit": quantum_layer.__str__(),
                    }
                )

                # plot the losses of the trainig loop and save the figures
                model.plot_losses(save=True, save_txt=True)

                #save all the parameters of the model and the intermediate parameters of the model
                model.save_state_dict(intermediate=False)

                # plot the validation and save it
                model.plot_validation(save=True, fig_size=(9,9), percentatge=1)

                # print validation and save it
                model.str_validation(save=True, precision=4, percentatge=1, printing=False)
# Out:
# ## --- Num:  4  --- ##
#
#
# 0  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 3.5015, Loss validation: 3.7363
# - Epoch [1/1], i: [256/9000], Loss: 1.1202
# /usr/lib/python3/dist-packages/torch/autograd/__init__.py:147: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:115.)
#   Variable._execution_engine.run_backward(
# 	 Validation string, 	 i: 0; 	 prediction: 0.0656, 	 target: 0.0233, 	 loss: 1.8179
# 	 Validation string, 	 i: 1; 	 prediction: -0.0498, 	 target: 0.0175, 	 loss: 3.8538
# 	 Validation string, 	 i: 2; 	 prediction: -0.0589, 	 target: -0.0747, 	 loss: 0.2106
# Epoch [1/1], Loss: 0.7710, Loss validation: 0.4738, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_model_str_4.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_batches_4.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_4.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_validation_4.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_batches_4.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_4.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_validation_4.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_4.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_validation_4.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_validation_4.txt
# 1  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 2.6535, Loss validation: 2.7145
# 	 Validation string, 	 i: 0; 	 prediction: 0.0374, 	 target: 0.0233, 	 loss: 0.6087
# 	 Validation string, 	 i: 1; 	 prediction: -0.0543, 	 target: 0.0175, 	 loss: 4.1091
# 	 Validation string, 	 i: 2; 	 prediction: -0.0949, 	 target: -0.0747, 	 loss: 0.2712
# Epoch [1/1], Loss: 0.7503, Loss validation: 0.7073, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_model_str_5.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_batches_5.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_5.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_validation_5.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_batches_5.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_5.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_validation_5.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_5.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_validation_5.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_validation_5.txt
# 2  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 1.4849, Loss validation: 1.5874
# 	 Validation string, 	 i: 0; 	 prediction: 0.0647, 	 target: 0.0233, 	 loss: 1.7816
# 	 Validation string, 	 i: 1; 	 prediction: -0.0767, 	 target: 0.0175, 	 loss: 5.3920
# 	 Validation string, 	 i: 2; 	 prediction: -0.0641, 	 target: -0.0747, 	 loss: 0.1419
# Epoch [1/1], Loss: 0.4807, Loss validation: 0.5524, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_model_str_6.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_batches_6.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_6.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_validation_6.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_batches_6.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_6.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_validation_6.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_6.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_validation_6.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_validation_6.txt
# 3  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 6.9792, Loss validation: 7.2364
# 	 Validation string, 	 i: 0; 	 prediction: 0.0227, 	 target: 0.0233, 	 loss: 0.0230
# 	 Validation string, 	 i: 1; 	 prediction: -0.1036, 	 target: 0.0175, 	 loss: 6.9302
# 	 Validation string, 	 i: 2; 	 prediction: -0.0659, 	 target: -0.0747, 	 loss: 0.1169
# Epoch [1/1], Loss: 0.9284, Loss validation: 0.5897, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_model_str_7.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_batches_7.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_7.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_validation_7.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_batches_7.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_7.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_validation_7.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_7.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_validation_7.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_validation_7.txt
# 4  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 8.1252, Loss validation: 8.5016
# 	 Validation string, 	 i: 0; 	 prediction: 0.0239, 	 target: 0.0233, 	 loss: 0.0286
# 	 Validation string, 	 i: 1; 	 prediction: -0.0634, 	 target: 0.0175, 	 loss: 4.6310
# 	 Validation string, 	 i: 2; 	 prediction: -0.0412, 	 target: -0.0747, 	 loss: 0.4483
# Epoch [1/1], Loss: 0.9356, Loss validation: 0.5058, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_model_str_8.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_batches_8.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_8.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_losses_epochs_validation_8.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_batches_8.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_8.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_losses_epochs_validation_8.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_8.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_validation_8.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_validation_8.txt
# 0  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 9.3262, Loss validation: 9.5159
# 	 Validation string, 	 i: 0; 	 prediction: -0.0160, 	 target: -0.0110, 	 loss: 0.4602
# 	 Validation string, 	 i: 1; 	 prediction: -0.0130, 	 target: -0.0075, 	 loss: 0.7284
# 	 Validation string, 	 i: 2; 	 prediction: -0.0130, 	 target: -0.0065, 	 loss: 1.0072
# Epoch [1/1], Loss: 0.7455, Loss validation: 0.5512, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_model_str_1.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_losses_batches_1.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_losses_epochs_1.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_losses_epochs_validation_1.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_losses_batches_1.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_losses_epochs_1.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_losses_epochs_validation_1.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_Single_1.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_validation_1.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_validation_1.txt
# 1  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 24.8592, Loss validation: 22.4465
# 	 Validation string, 	 i: 0; 	 prediction: -0.0154, 	 target: -0.0110, 	 loss: 0.4087
# 	 Validation string, 	 i: 1; 	 prediction: -0.0248, 	 target: -0.0075, 	 loss: 2.2865
# 	 Validation string, 	 i: 2; 	 prediction: -0.0146, 	 target: -0.0065, 	 loss: 1.2479
# Epoch [1/1], Loss: 1.1161, Loss validation: 0.7139, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_model_str_2.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_losses_batches_2.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_losses_epochs_2.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_losses_epochs_validation_2.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_losses_batches_2.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_losses_epochs_2.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_losses_epochs_validation_2.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_Single_2.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_validation_2.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_validation_2.txt
# 2  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 40.8051, Loss validation: 40.1904
# 	 Validation string, 	 i: 0; 	 prediction: -0.0155, 	 target: -0.0110, 	 loss: 0.4186
# 	 Validation string, 	 i: 1; 	 prediction: -0.0075, 	 target: -0.0075, 	 loss: 0.0103
# 	 Validation string, 	 i: 2; 	 prediction: -0.0132, 	 target: -0.0065, 	 loss: 1.0293
# Epoch [1/1], Loss: 1.5293, Loss validation: 0.5173, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_model_str_3.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_losses_batches_3.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_losses_epochs_3.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_losses_epochs_validation_3.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_losses_batches_3.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_losses_epochs_3.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_losses_epochs_validation_3.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_Single_3.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_validation_3.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_validation_3.txt
# 3  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 14.4793, Loss validation: 14.3609
# 	 Validation string, 	 i: 0; 	 prediction: -0.0013, 	 target: -0.0110, 	 loss: 0.8788
# 	 Validation string, 	 i: 1; 	 prediction: -0.0019, 	 target: -0.0075, 	 loss: 0.7515
# 	 Validation string, 	 i: 2; 	 prediction: -0.0023, 	 target: -0.0065, 	 loss: 0.6529
# Epoch [1/1], Loss: 0.9886, Loss validation: 0.8783, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_model_str_4.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_losses_batches_4.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_losses_epochs_4.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_losses_epochs_validation_4.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_losses_batches_4.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_losses_epochs_4.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_losses_epochs_validation_4.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_Single_4.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_validation_4.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_validation_4.txt
# 4  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 82.4771, Loss validation: 80.2676
# 	 Validation string, 	 i: 0; 	 prediction: -0.0125, 	 target: -0.0110, 	 loss: 0.1392
# 	 Validation string, 	 i: 1; 	 prediction: -0.0085, 	 target: -0.0075, 	 loss: 0.1237
# 	 Validation string, 	 i: 2; 	 prediction: -0.0124, 	 target: -0.0065, 	 loss: 0.9185
# Epoch [1/1], Loss: 3.4357, Loss validation: 0.6928, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_model_str_5.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_losses_batches_5.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_losses_epochs_5.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_losses_epochs_validation_5.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_losses_batches_5.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_losses_epochs_5.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_losses_epochs_validation_5.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_Single_5.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Single_validation_5.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Single_validation_5.txt
# 0  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 5.8748, Loss validation: 5.3867
# 	 Validation string, 	 i: 0; 	 prediction: -0.0275, 	 target: 0.1173, 	 loss: 1.2344
# 	 Validation string, 	 i: 1; 	 prediction: 0.1646, 	 target: 0.2171, 	 loss: 0.2422
# 	 Validation string, 	 i: 2; 	 prediction: -0.0135, 	 target: 0.3155, 	 loss: 1.0426
# Epoch [1/1], Loss: 1.0590, Loss validation: 0.9099, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_model_str_1.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_losses_batches_1.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_losses_epochs_1.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_losses_epochs_validation_1.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_losses_batches_1.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_losses_epochs_1.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_losses_epochs_validation_1.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_Pair_1.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_validation_1.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_validation_1.txt
# 1  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 4.8905, Loss validation: 4.4727
# 	 Validation string, 	 i: 0; 	 prediction: 0.0991, 	 target: 0.1173, 	 loss: 0.1552
# 	 Validation string, 	 i: 1; 	 prediction: 0.1577, 	 target: 0.2171, 	 loss: 0.2739
# 	 Validation string, 	 i: 2; 	 prediction: 0.1400, 	 target: 0.3155, 	 loss: 0.5561
# Epoch [1/1], Loss: 0.7870, Loss validation: 0.5568, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_model_str_2.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_losses_batches_2.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_losses_epochs_2.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_losses_epochs_validation_2.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_losses_batches_2.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_losses_epochs_2.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_losses_epochs_validation_2.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_Pair_2.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_validation_2.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_validation_2.txt
# 2  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 2.1129, Loss validation: 1.9261
# 	 Validation string, 	 i: 0; 	 prediction: 0.1360, 	 target: 0.1173, 	 loss: 0.1594
# 	 Validation string, 	 i: 1; 	 prediction: -0.0086, 	 target: 0.2171, 	 loss: 1.0395
# 	 Validation string, 	 i: 2; 	 prediction: 0.1474, 	 target: 0.3155, 	 loss: 0.5329
# Epoch [1/1], Loss: 0.6550, Loss validation: 0.6235, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_model_str_3.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_losses_batches_3.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_losses_epochs_3.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_losses_epochs_validation_3.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_losses_batches_3.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_losses_epochs_3.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_losses_epochs_validation_3.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_Pair_3.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_validation_3.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_validation_3.txt
# 3  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 4.9689, Loss validation: 4.5380
# 	 Validation string, 	 i: 0; 	 prediction: 0.1592, 	 target: 0.1173, 	 loss: 0.3574
# 	 Validation string, 	 i: 1; 	 prediction: 0.0005, 	 target: 0.2171, 	 loss: 0.9978
# 	 Validation string, 	 i: 2; 	 prediction: 0.1730, 	 target: 0.3155, 	 loss: 0.4517
# Epoch [1/1], Loss: 1.0026, Loss validation: 0.6018, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_model_str_4.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_losses_batches_4.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_losses_epochs_4.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_losses_epochs_validation_4.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_losses_batches_4.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_losses_epochs_4.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_losses_epochs_validation_4.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_Pair_4.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_validation_4.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_validation_4.txt
# 4  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 1.4501, Loss validation: 1.3162
# 	 Validation string, 	 i: 0; 	 prediction: 0.1946, 	 target: 0.1173, 	 loss: 0.6590
# 	 Validation string, 	 i: 1; 	 prediction: 0.0852, 	 target: 0.2171, 	 loss: 0.6077
# 	 Validation string, 	 i: 2; 	 prediction: 0.1772, 	 target: 0.3155, 	 loss: 0.4384
# Epoch [1/1], Loss: 0.7565, Loss validation: 0.5529, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_model_str_5.txt
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_losses_batches_5.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_losses_epochs_5.png
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_losses_epochs_validation_5.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_losses_batches_5.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_losses_epochs_5.txt
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_losses_epochs_validation_5.txt
# Model saved as peptide-QML/checkpoints/0831/models/0831-4h_em_1qm_Pair_5.pth
# Saved in:  peptide-QML/checkpoints/0831/plots/0831-4h_em_1qm_Pair_validation_5.png
# Saved in:  peptide-QML/checkpoints/0831/txts/0831-4h_em_1qm_Pair_validation_5.txt
# ## --- Num:  6  --- ##
#
#
# 0  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/1], Loss: 2.6413, Loss validation: 2.6258
# - Epoch [1/1], i: [7008/9000], Loss: 0.5194
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-bea0154c5ff7> in <module>
#      97
#      98                 # train the model
# ---> 99                 model.train(
#     100                     optimizer= optim.Adam,
#     101                     optimizer_options={'lr': 0.05},
#
# ~/peptide-QML/my_code/pytorch_model.py in train(self, loss_function, optimizer, optimizer_options, initialization_options, num_epochs, batch_size, print_batch, validation, n_validation, n_print_validation, time, stop_training_options)
#     158
#     159                 # Forward pass
# --> 160                 outputs = self.model(inputs)
#     161
#     162                 # Compute the loss
#
# /usr/lib/python3/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/lib/python3/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# /usr/lib/python3/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.local/lib/python3.8/site-packages/pennylane/qnn/torch.py in forward(self, inputs)
#     406         else:
#     407             # calculate the forward pass as usual
# --> 408             results = self._evaluate_qnode(inputs)
#     409
#     410         # reshape to the correct number of batch dims
#
# ~/.local/lib/python3.8/site-packages/pennylane/qnn/torch.py in _evaluate_qnode(self, x)
#     427             **{arg: weight.to(x) for arg, weight in self.qnode_weights.items()},
#     428         }
# --> 429         res = self.qnode(**kwargs)
#     430
#     431         if isinstance(res, torch.Tensor):
#
# ~/.local/lib/python3.8/site-packages/pennylane/qnode.py in __call__(self, *args, **kwargs)
#     948                 self.execute_kwargs.pop("mode")
#     949             # pylint: disable=unexpected-keyword-arg
# --> 950             res = qml.execute(
#     951                 [self.tape],
#     952                 device=self.device,
#
# ~/.local/lib/python3.8/site-packages/pennylane/interfaces/execution.py in execute(tapes, device, gradient_fn, interface, grad_on_execution, gradient_kwargs, cache, cachesize, max_diff, override_shots, expand_fn, max_expansion, device_batch_transform)
#     509             pass_kwargs=new_device_interface,
#     510         )
# --> 511         results = cached_execute_fn(tapes, execution_config=config)
#     512         return batch_fn(results)
#     513
#
# ~/.local/lib/python3.8/site-packages/pennylane/interfaces/execution.py in wrapper(tapes, **kwargs)
#     285             # execute all unique tapes that do not exist in the cache
#     286             # convert to list as new device interface returns a tuple
# --> 287             res = list(fn(execution_tapes.values(), **kwargs))
#     288
#     289         final_res = []
#
# ~/.local/lib/python3.8/site-packages/pennylane/interfaces/execution.py in fn(tapes, **kwargs)
#     208         def fn(tapes: Sequence[QuantumTape], **kwargs):  # pylint: disable=function-redefined
#     209             tapes = [expand_fn(tape) for tape in tapes]
# --> 210             return original_fn(tapes, **kwargs)
#     211
#     212     @wraps(fn)
#
# /usr/lib/python3.8/contextlib.py in inner(*args, **kwds)
#      73         def inner(*args, **kwds):
#      74             with self._recreate_cm():
# ---> 75                 return func(*args, **kwds)
#      76         return inner
#      77
#
# ~/.local/lib/python3.8/site-packages/pennylane/_qubit_device.py in batch_execute(self, circuits)
#     601             self.reset()
#     602
# --> 603             res = self.execute(circuit)
#     604             results.append(res)
#     605
#
# ~/.local/lib/python3.8/site-packages/pennylane/devices/default_qubit_torch.py in execute(self, circuit, **kwargs)
#     230                     )
#     231
# --> 232         return super().execute(circuit, **kwargs)
#     233
#     234     def _asarray(self, a, dtype=None):
#
# ~/.local/lib/python3.8/site-packages/pennylane/_qubit_device.py in execute(self, circuit, **kwargs)
#     329
#     330         else:
# --> 331             results = self.statistics(circuit)
#     332             single_measurement = len(circuit.measurements) == 1
#     333
#
# ~/.local/lib/python3.8/site-packages/pennylane/_qubit_device.py in statistics(self, circuit, shot_range, bin_size)
#     971             # Pass instances directly
#     972             elif isinstance(m, ExpectationMP):
# --> 973                 result = self.expval(obs, shot_range=shot_range, bin_size=bin_size)
#     974
#     975             elif isinstance(m, VarianceMP):
#
# ~/.local/lib/python3.8/site-packages/pennylane/devices/default_qubit.py in expval(self, observable, shot_range, bin_size)
#     584         # to a component that can be re-used by devices as needed.
#     585         if observable.name not in ("Hamiltonian", "SparseHamiltonian"):
# --> 586             return super().expval(observable, shot_range=shot_range, bin_size=bin_size)
#     587
#     588         assert self.shots is None, f"{observable.name} must be used with shots=None"
#
# ~/.local/lib/python3.8/site-packages/pennylane/_qubit_device.py in expval(self, observable, shot_range, bin_size)
#    1663         if self.shots is None:
#    1664             try:
# -> 1665                 eigvals = self._asarray(observable.eigvals(), dtype=self.R_DTYPE)
#    1666             except qml.operation.EigvalsUndefinedError as e:
#    1667                 raise qml.operation.EigvalsUndefinedError(
#
# KeyboardInterrupt:

# %%
# push changes to git
if initial_path != '../':
    # !cd peptide-QML && git add . && git commit -m "data trained model" && git push
