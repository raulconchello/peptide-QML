# %%
initial_path = 'peptide-QML/'
# initial_path = '../'

# %%
import numpy as np
import sys
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import functions as f
from my_code import pytorch_model as ptm
from my_code import quantum_nodes as qn
from my_code import pytorch_wrappers as pw
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.0.4) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
for num in [4, 6, 8, 10, 12]:
    print("## --- Num: ", num, " --- ##")
    print("")
    print("")

    # -- NAME NOTEBOOK -- #
    day = "0831"
    name_notebook = day + "-{}h_em_1qm_loop.ipynb".format(num)

    # -- DATA -- #
    data_file_path_1 = initial_path + 'data/Scores/PET/generated/bb14_Strings_Energies_10_000_{}_aa.txt'.format(num)  
    data_file_path_2 = initial_path + 'data/Scores/PET/generated/bb14_Strings_Energies_Single_10_000_{}_aa.txt'.format(num)

    for data_file_path in [data_file_path_1, data_file_path_2]:

        string_list, number_list = f.read_data_file(data_file_path)
        score_list = np.array(number_list)/1000
        vector_list = np.array([f.string_to_numbers(string) for string in string_list]) 

        X, Y, X_validation, Y_validation = f.create_validating_set(vector_list, score_list, percentage=0.1)

        # Define the dataset
        input_data = ptm.torch.tensor(X) 
        target_data = ptm.torch.tensor(Y).view(-1, 1)

        # Define the validation set
        input_validation = ptm.torch.tensor(X_validation)
        target_validation = ptm.torch.tensor(Y_validation).view(-1, 1)


        # -- TRAINING LOOP -- #
        for iii in range(5):

            for block_n_layers in range(1, 21, 2):
                print(iii, " # ------- block_n_layers: ", block_n_layers, " ------- #")
                print("")
                print("")

                # -- QUANTUM NODE -- #

                n_aminoacids = len(string_list[0])

                quantum_layer = qn.circuit(
                    n_qubits = n_aminoacids, 
                    device = "default.qubit.torch",
                    device_options = {'shots': None},
                    embedding = qn.parts.AngleEmbedding, 
                    # embedding_ansatz = qn.parts.Ansatz_11,
                    block_ansatz = qn.parts.Ansatz_11,
                    final_ansatz = qn.parts.Ansatz_final_11,
                    measurement = qn.parts.Measurement('Z', (n_aminoacids-1)//2),
                    # embedding_n_layers = 4,
                    # different_inputs_per_layer = True,
                    block_n_layers = block_n_layers,
                    # wrapper_qlayer = pw.QLayerEmpty,
                )

                # -- HYBRID MODEL -- #
                input_dim = input_data.size(1)

                n_pre_classical_layers = 4
                layers_dim = np.linspace(n_aminoacids, input_dim, 4).astype(int)

                import torch.nn as nn
                import torch
                    
                class Reshape(nn.Module):
                    def __init__(self):
                        super(Reshape, self).__init__()

                    def forward(self, x):
                        dims = len(x.shape)
                        return torch.transpose(x, dims-2, dims-1).reshape(x.shape[-3] if dims==3 else 1, x.shape[-2]*x.shape[-1]).squeeze()

                layers =  [ptm.nn.Embedding(num_embeddings=19, embedding_dim=quantum_layer.input_shape[0]//n_aminoacids), Reshape()]
                layers += [quantum_layer(), ptm.nn.Linear(1,1)]

                # Create model and set data:
                model = ptm.pytorch_model(
                    layers,    
                    save_options = {'initial_path': initial_path, 'name_notebook': name_notebook},
                )
                model.set_data(
                    data_X=input_data, 
                    data_Y=target_data, 
                    data_X_validation=input_validation,
                    data_Y_validation=target_validation
                )
                model.keep_track_params=False


                # -- TRAINING -- #
                import torch.optim as optim

                # train the model
                model.train(
                    optimizer= optim.Adam,
                    optimizer_options={'lr': 0.05},
                    num_epochs = 30,                
                    batch_size = 32,
                    stop_training_options = {
                        'lookback_epochs': 5, 
                        'threshold': 0.005
                    },
                )

                # save string of the model
                model.save_str(
                    metadata={
                        "data_file_path": data_file_path,
                        "Quantum_circuit": quantum_layer.__str__(),
                    }
                )

                # plot the losses of the trainig loop and save the figures
                model.plot_losses(save=True, save_txt=True)

                #save all the parameters of the model and the intermediate parameters of the model
                model.save_state_dict(intermediate=False)

                # plot the validation and save it
                model.plot_validation(save=True, fig_size=(9,9), percentatge=1)

                # print validation and save it
                model.str_validation(save=True, precision=4, percentatge=1, printing=False)
# Out:
# 0  # ------- block_n_layers:  1  ------- #
# Epoch [0/30], Loss: 0.8134, Loss validation: 0.8769
# - Epoch [1/30], i: [0/9000], Loss: 1.1630
# /usr/lib/python3/dist-packages/torch/autograd/__init__.py:147: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:115.)
#   Variable._execution_engine.run_backward(
# 	 Validation string, 	 i: 0; 	 prediction: 0.5215, 	 target: 0.0692, 	 loss: 6.5309
# 	 Validation string, 	 i: 1; 	 prediction: 0.3484, 	 target: 0.2339, 	 loss: 0.4898
# 	 Validation string, 	 i: 2; 	 prediction: 0.2265, 	 target: 0.1523, 	 loss: 0.4876
# Epoch [1/30], Loss: 0.4718, Loss validation: 0.3953, Time remaining: ~0.0h 13.0m 30s
# 	 Validation string, 	 i: 0; 	 prediction: 0.4093, 	 target: 0.0692, 	 loss: 4.9103
# 	 Validation string, 	 i: 1; 	 prediction: 0.3085, 	 target: 0.2339, 	 loss: 0.3191
# 	 Validation string, 	 i: 2; 	 prediction: 0.2137, 	 target: 0.1523, 	 loss: 0.4032
# Epoch [2/30], Loss: 0.3839, Loss validation: 0.3789, Time remaining: ~0.0h 12.0m 7s
# 	 Validation string, 	 i: 0; 	 prediction: 0.4322, 	 target: 0.0692, 	 loss: 5.2408
# 	 Validation string, 	 i: 1; 	 prediction: 0.2816, 	 target: 0.2339, 	 loss: 0.2040
# 	 Validation string, 	 i: 2; 	 prediction: 0.2247, 	 target: 0.1523, 	 loss: 0.4754
# Epoch [3/30], Loss: 0.3602, Loss validation: 0.3281, Time remaining: ~0.0h 11.0m 22s
# 	 Validation string, 	 i: 0; 	 prediction: 0.3694, 	 target: 0.0692, 	 loss: 4.3350
# 	 Validation string, 	 i: 1; 	 prediction: 0.3946, 	 target: 0.2339, 	 loss: 0.6876
# 	 Validation string, 	 i: 2; 	 prediction: 0.2944, 	 target: 0.1523, 	 loss: 0.9333
# Epoch [4/30], Loss: 0.3497, Loss validation: 0.3356, Time remaining: ~0.0h 10.0m 50s
# 	 Validation string, 	 i: 0; 	 prediction: 0.4266, 	 target: 0.0692, 	 loss: 5.1605
# 	 Validation string, 	 i: 1; 	 prediction: 0.3516, 	 target: 0.2339, 	 loss: 0.5037
# 	 Validation string, 	 i: 2; 	 prediction: 0.1572, 	 target: 0.1523, 	 loss: 0.0321
# Epoch [5/30], Loss: 0.3534, Loss validation: 0.3347, Time remaining: ~0.0h 10.0m 21s
# 	 Validation string, 	 i: 0; 	 prediction: 0.4630, 	 target: 0.0692, 	 loss: 5.6855
# 	 Validation string, 	 i: 1; 	 prediction: 0.3035, 	 target: 0.2339, 	 loss: 0.2980
# 	 Validation string, 	 i: 2; 	 prediction: 0.1804, 	 target: 0.1523, 	 loss: 0.1845
# Epoch [6/30], Loss: 0.3517, Loss validation: 0.3144, Time remaining: ~0.0h 9.0m 50s
# 	 Validation string, 	 i: 0; 	 prediction: 0.5002, 	 target: 0.0692, 	 loss: 6.2236
# 	 Validation string, 	 i: 1; 	 prediction: 0.6068, 	 target: 0.2339, 	 loss: 1.5950
# 	 Validation string, 	 i: 2; 	 prediction: 0.3227, 	 target: 0.1523, 	 loss: 1.1189
# Epoch [7/30], Loss: 0.3468, Loss validation: 0.4317, Time remaining: ~0.0h 9.0m 23s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_model_str_32.txt
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_batches_32.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_32.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_validation_32.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_batches_32.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_32.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_validation_32.txt
# Model saved as peptide-QML/checkpoints/0830/models/0830-mh_em_1qm_loop_32.pth
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_validation_32.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_validation_32.txt
# 0  # ------- block_n_layers:  2  ------- #
#
#
# Epoch [0/30], Loss: 0.7179, Loss validation: 0.6812
# 	 Validation string, 	 i: 0; 	 prediction: 0.4488, 	 target: 0.0692, 	 loss: 5.4817
# 	 Validation string, 	 i: 1; 	 prediction: 0.3454, 	 target: 0.2339, 	 loss: 0.4771
# 	 Validation string, 	 i: 2; 	 prediction: 0.2510, 	 target: 0.1523, 	 loss: 0.6485
# Epoch [1/30], Loss: 0.4676, Loss validation: 0.3433, Time remaining: ~0.0h 17.0m 55s
# 	 Validation string, 	 i: 0; 	 prediction: 0.5915, 	 target: 0.0692, 	 loss: 7.5423
# 	 Validation string, 	 i: 1; 	 prediction: 0.2755, 	 target: 0.2339, 	 loss: 0.1783
# 	 Validation string, 	 i: 2; 	 prediction: 0.2398, 	 target: 0.1523, 	 loss: 0.5745
# Epoch [2/30], Loss: 0.3454, Loss validation: 0.3311, Time remaining: ~0.0h 16.0m 11s
# 	 Validation string, 	 i: 0; 	 prediction: 0.4973, 	 target: 0.0692, 	 loss: 6.1817
# 	 Validation string, 	 i: 1; 	 prediction: 0.3646, 	 target: 0.2339, 	 loss: 0.5591
# 	 Validation string, 	 i: 2; 	 prediction: 0.2762, 	 target: 0.1523, 	 loss: 0.8139
# Epoch [3/30], Loss: 0.3394, Loss validation: 0.3313, Time remaining: ~0.0h 15.0m 8s
# 	 Validation string, 	 i: 0; 	 prediction: 0.2292, 	 target: 0.0692, 	 loss: 2.3095
# 	 Validation string, 	 i: 1; 	 prediction: 0.1368, 	 target: 0.2339, 	 loss: 0.4149
# 	 Validation string, 	 i: 2; 	 prediction: 0.0178, 	 target: 0.1523, 	 loss: 0.8834
# Epoch [4/30], Loss: 0.3371, Loss validation: 0.3388, Time remaining: ~0.0h 14.0m 23s
# 	 Validation string, 	 i: 0; 	 prediction: 0.4259, 	 target: 0.0692, 	 loss: 5.1504
# 	 Validation string, 	 i: 1; 	 prediction: 0.3312, 	 target: 0.2339, 	 loss: 0.4164
# 	 Validation string, 	 i: 2; 	 prediction: 0.2081, 	 target: 0.1523, 	 loss: 0.3667
# Epoch [5/30], Loss: 0.3359, Loss validation: 0.3406, Time remaining: ~0.0h 13.0m 49s
# 	 Validation string, 	 i: 0; 	 prediction: 0.4352, 	 target: 0.0692, 	 loss: 5.2842
# 	 Validation string, 	 i: 1; 	 prediction: 0.2331, 	 target: 0.2339, 	 loss: 0.0032
# 	 Validation string, 	 i: 2; 	 prediction: 0.1371, 	 target: 0.1523, 	 loss: 0.0995
# Epoch [6/30], Loss: 0.3344, Loss validation: 0.3280, Time remaining: ~0.0h 13.0m 10s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_model_str_33.txt
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_batches_33.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_33.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_validation_33.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_batches_33.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_33.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_validation_33.txt
# Model saved as peptide-QML/checkpoints/0830/models/0830-mh_em_1qm_loop_33.pth
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_validation_33.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_validation_33.txt
# 0  # ------- block_n_layers:  3  ------- #
#
#
# Epoch [0/30], Loss: 0.7202, Loss validation: 0.7118
# 	 Validation string, 	 i: 0; 	 prediction: 0.5537, 	 target: 0.0692, 	 loss: 6.9956
# 	 Validation string, 	 i: 1; 	 prediction: 0.3098, 	 target: 0.2339, 	 loss: 0.3248
# 	 Validation string, 	 i: 2; 	 prediction: 0.2170, 	 target: 0.1523, 	 loss: 0.4247
# Epoch [1/30], Loss: 0.4003, Loss validation: 0.3362, Time remaining: ~0.0h 23.0m 9s
# 	 Validation string, 	 i: 0; 	 prediction: 0.2823, 	 target: 0.0692, 	 loss: 3.0766
# 	 Validation string, 	 i: 1; 	 prediction: 0.2198, 	 target: 0.2339, 	 loss: 0.0602
# 	 Validation string, 	 i: 2; 	 prediction: 0.1630, 	 target: 0.1523, 	 loss: 0.0706
# Epoch [2/30], Loss: 0.3507, Loss validation: 0.3296, Time remaining: ~0.0h 20.0m 53s
# 	 Validation string, 	 i: 0; 	 prediction: 0.5487, 	 target: 0.0692, 	 loss: 6.9236
# 	 Validation string, 	 i: 1; 	 prediction: 0.3341, 	 target: 0.2339, 	 loss: 0.4287
# 	 Validation string, 	 i: 2; 	 prediction: 0.1118, 	 target: 0.1523, 	 loss: 0.2661
# Epoch [3/30], Loss: 0.3520, Loss validation: 0.3613, Time remaining: ~0.0h 19.0m 37s
# 	 Validation string, 	 i: 0; 	 prediction: 0.3978, 	 target: 0.0692, 	 loss: 4.7443
# 	 Validation string, 	 i: 1; 	 prediction: 0.1714, 	 target: 0.2339, 	 loss: 0.2669
# 	 Validation string, 	 i: 2; 	 prediction: 0.0578, 	 target: 0.1523, 	 loss: 0.6203
# Epoch [4/30], Loss: 0.3456, Loss validation: 0.3494, Time remaining: ~0.0h 18.0m 37s
# 	 Validation string, 	 i: 0; 	 prediction: 0.5309, 	 target: 0.0692, 	 loss: 6.6665
# 	 Validation string, 	 i: 1; 	 prediction: 0.2352, 	 target: 0.2339, 	 loss: 0.0060
# 	 Validation string, 	 i: 2; 	 prediction: 0.2483, 	 target: 0.1523, 	 loss: 0.6304
# Epoch [5/30], Loss: 0.3486, Loss validation: 0.3284, Time remaining: ~0.0h 17.0m 48s
# 	 Validation string, 	 i: 0; 	 prediction: 0.3651, 	 target: 0.0692, 	 loss: 4.2724
# 	 Validation string, 	 i: 1; 	 prediction: 0.1530, 	 target: 0.2339, 	 loss: 0.3455
# 	 Validation string, 	 i: 2; 	 prediction: 0.1726, 	 target: 0.1523, 	 loss: 0.1332
# Epoch [6/30], Loss: 0.3461, Loss validation: 0.3295, Time remaining: ~0.0h 16.0m 57s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_model_str_34.txt
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_batches_34.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_34.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_validation_34.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_batches_34.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_34.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_validation_34.txt
# Model saved as peptide-QML/checkpoints/0830/models/0830-mh_em_1qm_loop_34.pth
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_validation_34.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_validation_34.txt
# 0  # ------- block_n_layers:  4  ------- #
#
#
# Epoch [0/30], Loss: 0.9740, Loss validation: 0.9645
# 	 Validation string, 	 i: 0; 	 prediction: 0.5995, 	 target: 0.0692, 	 loss: 7.6566
# 	 Validation string, 	 i: 1; 	 prediction: 0.4284, 	 target: 0.2339, 	 loss: 0.8321
# 	 Validation string, 	 i: 2; 	 prediction: 0.4287, 	 target: 0.1523, 	 loss: 1.8149
# Epoch [1/30], Loss: 0.3769, Loss validation: 0.3635, Time remaining: ~0.0h 28.0m 4s
# 	 Validation string, 	 i: 0; 	 prediction: 0.5532, 	 target: 0.0692, 	 loss: 6.9892
# 	 Validation string, 	 i: 1; 	 prediction: 0.4097, 	 target: 0.2339, 	 loss: 0.7519
# 	 Validation string, 	 i: 2; 	 prediction: 0.3642, 	 target: 0.1523, 	 loss: 1.3916
# Epoch [2/30], Loss: 0.3330, Loss validation: 0.3417, Time remaining: ~0.0h 25.0m 16s
# 	 Validation string, 	 i: 0; 	 prediction: 0.5090, 	 target: 0.0692, 	 loss: 6.3497
# 	 Validation string, 	 i: 1; 	 prediction: 0.2910, 	 target: 0.2339, 	 loss: 0.2444
# 	 Validation string, 	 i: 2; 	 prediction: 0.3316, 	 target: 0.1523, 	 loss: 1.1776
# Epoch [3/30], Loss: 0.3312, Loss validation: 0.3070, Time remaining: ~0.0h 23.0m 54s
# 	 Validation string, 	 i: 0; 	 prediction: 0.5779, 	 target: 0.0692, 	 loss: 7.3446
# 	 Validation string, 	 i: 1; 	 prediction: 0.3981, 	 target: 0.2339, 	 loss: 0.7025
# 	 Validation string, 	 i: 2; 	 prediction: 0.3959, 	 target: 0.1523, 	 loss: 1.5994
# Epoch [4/30], Loss: 0.3337, Loss validation: 0.3664, Time remaining: ~0.0h 22.0m 46s
# 	 Validation string, 	 i: 0; 	 prediction: 0.5202, 	 target: 0.0692, 	 loss: 6.5115
# 	 Validation string, 	 i: 1; 	 prediction: 0.2449, 	 target: 0.2339, 	 loss: 0.0470
# 	 Validation string, 	 i: 2; 	 prediction: 0.2465, 	 target: 0.1523, 	 loss: 0.6185
# Epoch [5/30], Loss: 0.3309, Loss validation: 0.3107, Time remaining: ~0.0h 21.0m 42s
# 	 Validation string, 	 i: 0; 	 prediction: 0.5572, 	 target: 0.0692, 	 loss: 7.0459
# 	 Validation string, 	 i: 1; 	 prediction: 0.2474, 	 target: 0.2339, 	 loss: 0.0579
# 	 Validation string, 	 i: 2; 	 prediction: 0.1525, 	 target: 0.1523, 	 loss: 0.0013
# Epoch [6/30], Loss: 0.3315, Loss validation: 0.3149, Time remaining: ~0.0h 20.0m 44s
# The loss is not changing anymore, so we stop training.
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_model_str_35.txt
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_batches_35.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_35.png
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_losses_epochs_validation_35.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_batches_35.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_35.txt
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_losses_epochs_validation_35.txt
# Model saved as peptide-QML/checkpoints/0830/models/0830-mh_em_1qm_loop_35.pth
# Saved in:  peptide-QML/checkpoints/0830/plots/0830-mh_em_1qm_loop_validation_35.png
# Saved in:  peptide-QML/checkpoints/0830/txts/0830-mh_em_1qm_loop_validation_35.txt
# 0  # ------- block_n_layers:  5  ------- #
#
#
# Epoch [0/30], Loss: 1.4770, Loss validation: 1.4988
# 	 Validation string, 	 i: 0; 	 prediction: 0.4999, 	 target: 0.0692, 	 loss: 6.2187
# 	 Validation string, 	 i: 1; 	 prediction: 0.3182, 	 target: 0.2339, 	 loss: 0.3606
# 	 Validation string, 	 i: 2; 	 prediction: 0.2348, 	 target: 0.1523, 	 loss: 0.5415
# Epoch [1/30], Loss: 0.4387, Loss validation: 0.3207, Time remaining: ~0.0h 33.0m 5s
# - Epoch [2/30], i: [8224/9000], Loss: 0.2675
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-8c98966d68df> in <module>
#      63
#      64         # train the model
# ---> 65         model.train(
#      66             optimizer= optim.Adam,
#      67             optimizer_options={'lr': 0.05},
#
# ~/peptide-QML/my_code/pytorch_model.py in train(self, loss_function, optimizer, optimizer_options, initialization_options, num_epochs, batch_size, print_batch, validation, n_validation, n_print_validation, time, stop_training_options)
#     165                 # Backward pass and optimization
#     166                 optimizer.zero_grad()
# --> 167                 loss.backward()
#     168                 optimizer.step()
#     169
#
# /usr/lib/python3/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     253                 create_graph=create_graph,
#     254                 inputs=inputs)
# --> 255         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     256
#     257     def register_hook(self, hook):
#
# /usr/lib/python3/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     145         retain_graph = create_graph
#     146
# --> 147     Variable._execution_engine.run_backward(
#     148         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     149         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
# push changes to git
if initial_path != '../':
    # !cd peptide-QML && git add . && git commit -m "data trained model" && git push
