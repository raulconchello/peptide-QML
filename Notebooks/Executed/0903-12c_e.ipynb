# %%
initial_path = 'peptide-QML/'
# initial_path = '../'

# %%
import numpy as np
import sys
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import functions as f
from my_code import pytorch_model as ptm
from my_code import quantum_nodes as qn
from my_code import pytorch_wrappers as pw
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.0.4) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
dim = 12
day = "0903"


# -- DATA -- #

# name of the notebook
name_notebook = "{}-{}c_e.ipynb".format(day, dim)

# load data
data_file_path = '{}data/Scores/PET/PET_SCORES.csv'.format(initial_path)
string_list, number_list = f.read_data_file(
    data_file_path,
    skip_first_line=True, 
    delimiter=', ', 
    columns_to_return=[1, 2],
    which_columns_are_numbers=[2]
    )
score_list = np.array(number_list)/100
vector_list = np.array([f.string_to_numbers(string) for string in string_list]) 
X, Y, X_validation, Y_validation = f.create_validating_set(vector_list, score_list, percentage=0.1)

# Define the dataset
input_data = ptm.torch.tensor(X) 
target_data = ptm.torch.tensor(Y).view(-1, 1)

# Define the validation set
input_validation = ptm.torch.tensor(X_validation)
target_validation = ptm.torch.tensor(Y_validation).view(-1, 1)


# -- TRAINING LOOP -- #
for iii in range(5):

    for block_n_layers in range(2, 5):
        print(iii, " # ------- block_n_layers: ", block_n_layers, " ------- #")
        print("")
        print("")

        # -- CLASSICAL MODEL -- #
        n_aminoacids = len(string_list[0])
        input_dim = input_data.shape[1]

        class Reshape(ptm.nn.Module):
            def __init__(self):
                super(Reshape, self).__init__()

            def forward(self, x):
                dims = len(x.shape)
                return ptm.torch.transpose(x, dims-2, dims-1).reshape(x.shape[-3] if dims==3 else 1, x.shape[-2]*x.shape[-1]).squeeze()

        n_neurons = []
        layers_dim = np.linspace(input_dim, input_dim**2, block_n_layers).astype(int)
        for n in zip(layers_dim[:-1], layers_dim[1:]): n_neurons.append(n)
        layers_dim = np.linspace(input_dim**2, 1, block_n_layers).astype(int)
        for n in zip(layers_dim[:-1], layers_dim[1:]): n_neurons.append(n)

        layers =  [ptm.nn.Embedding(num_embeddings=19, embedding_dim=1), Reshape()]
        for i, o in n_neurons: 
            layers += [ptm.nn.Linear(i, o), ptm.nn.Sigmoid()]    # activation function RELU didn't work well  
        layers += [ptm.nn.Linear(1,1)]

        # Create model and set data:
        model = ptm.pytorch_model(
            layers,    
            save_options = {'initial_path': initial_path, 'name_notebook': name_notebook},
        )
        model.set_data(
            data_X=input_data, 
            data_Y=target_data, 
            data_X_validation=input_validation,
            data_Y_validation=target_validation
        )
        model.keep_track_params=False


        # -- TRAINING -- #
        import torch.optim as optim

        # train the model
        model.train(
            optimizer= optim.Adam,
            optimizer_options={'lr': 0.02},
            num_epochs = 3,                
            batch_size = 32,
            stop_training_options = {
                'lookback_epochs': 5, 
                'threshold_slope': 0.001,
                'threshold_std_dev': 0.2
            },
        )

        # -- SAVE -- #

        # dump the object
        model.dump()

        # save string of the model
        model.save_str(
            metadata={
                "data_file_path": data_file_path,
                "n_aminoacids": n_aminoacids,
                "block_n_layers": block_n_layers,
            }
        )

        # plot the losses of the trainig loop and save the figures
        model.plot_losses(save=True, save_txt=True)

        #save all the parameters of the model and the intermediate parameters of the model
        model.save_state_dict(intermediate=False)

        # plot the validation and save it
        model.plot_validation(save=True, fig_size=(9,9), percentatge=1)

        # print validation and save it
        model.str_validation(save=True, precision=4, percentatge=1, printing=False)
# Out:
# 0  # ------- block_n_layers:  2  ------- #
#
#
# Epoch [0/3], Loss: 70.3552, Loss validation: 70.0762
# /usr/lib/python3/dist-packages/torch/autograd/__init__.py:147: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:115.)
#   Variable._execution_engine.run_backward(
# 	 Validation string, 	 i: 0; 	 prediction: -0.1505, 	 target: -0.1376, 	 loss: 0.1671
# 	 Validation string, 	 i: 1; 	 prediction: -0.2228, 	 target: -0.3264, 	 loss: 10.8559
# 	 Validation string, 	 i: 2; 	 prediction: -0.1303, 	 target: -0.3203, 	 loss: 36.4964
# Epoch [1/3], Loss: 7.0802, Loss validation: 5.8192, Time remaining: ~0.0h 0.0m 45s
# 	 Validation string, 	 i: 0; 	 prediction: -0.1532, 	 target: -0.1376, 	 loss: 0.2462
# 	 Validation string, 	 i: 1; 	 prediction: -0.2292, 	 target: -0.3264, 	 loss: 9.5488
# 	 Validation string, 	 i: 2; 	 prediction: -0.1499, 	 target: -0.3203, 	 loss: 29.3438
# Epoch [2/3], Loss: 5.5360, Loss validation: 5.4007, Time remaining: ~0.0h 0.0m 22s
# 	 Validation string, 	 i: 0; 	 prediction: -0.1636, 	 target: -0.1376, 	 loss: 0.6840
# 	 Validation string, 	 i: 1; 	 prediction: -0.2085, 	 target: -0.3264, 	 loss: 14.0429
# 	 Validation string, 	 i: 2; 	 prediction: -0.1352, 	 target: -0.3203, 	 loss: 34.6258
# Epoch [3/3], Loss: 5.3809, Loss validation: 5.4144, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_model_str_4.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_losses_batches_4.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_losses_epochs_4.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_losses_epochs_validation_4.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_losses_batches_4.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_losses_epochs_4.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_losses_epochs_validation_4.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_e_4.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_validation_4.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_validation_4.txt
# 0  # ------- block_n_layers:  3  ------- #
#
#
# Epoch [0/3], Loss: 86.9523, Loss validation: 87.1338
# 	 Validation string, 	 i: 0; 	 prediction: -0.3025, 	 target: -0.1376, 	 loss: 27.4843
# 	 Validation string, 	 i: 1; 	 prediction: -0.3025, 	 target: -0.3264, 	 loss: 0.5776
# 	 Validation string, 	 i: 2; 	 prediction: -0.3025, 	 target: -0.3203, 	 loss: 0.3205
# Epoch [1/3], Loss: 21.0941, Loss validation: 21.3915, Time remaining: ~1.0h 4.0m 44s
# 	 Validation string, 	 i: 0; 	 prediction: -0.2803, 	 target: -0.1376, 	 loss: 20.5754
# 	 Validation string, 	 i: 1; 	 prediction: -0.2803, 	 target: -0.3264, 	 loss: 2.1508
# 	 Validation string, 	 i: 2; 	 prediction: -0.2803, 	 target: -0.3203, 	 loss: 1.6196
# Epoch [2/3], Loss: 21.0738, Loss validation: 20.8555, Time remaining: ~0.0h 34.0m 40s
# 	 Validation string, 	 i: 0; 	 prediction: -0.2944, 	 target: -0.1376, 	 loss: 24.8386
# 	 Validation string, 	 i: 1; 	 prediction: -0.2944, 	 target: -0.3264, 	 loss: 1.0378
# 	 Validation string, 	 i: 2; 	 prediction: -0.2944, 	 target: -0.3203, 	 loss: 0.6803
# Epoch [3/3], Loss: 21.0838, Loss validation: 21.0794, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_model_str_5.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_losses_batches_5.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_losses_epochs_5.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_losses_epochs_validation_5.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_losses_batches_5.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_losses_epochs_5.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_losses_epochs_validation_5.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_e_5.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_validation_5.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_validation_5.txt
# 0  # ------- block_n_layers:  4  ------- #
#
#
# Epoch [0/3], Loss: 1715.0792, Loss validation: 1714.1372
# 	 Validation string, 	 i: 0; 	 prediction: -0.2913, 	 target: -0.1376, 	 loss: 23.8880
# 	 Validation string, 	 i: 1; 	 prediction: -0.2913, 	 target: -0.3264, 	 loss: 1.2433
# 	 Validation string, 	 i: 2; 	 prediction: -0.2913, 	 target: -0.3203, 	 loss: 0.8484
# Epoch [1/3], Loss: 22.4061, Loss validation: 20.9974, Time remaining: ~1.0h 31.0m 34s
# 	 Validation string, 	 i: 0; 	 prediction: -0.2615, 	 target: -0.1376, 	 loss: 15.5251
# 	 Validation string, 	 i: 1; 	 prediction: -0.2615, 	 target: -0.3264, 	 loss: 4.2534
# 	 Validation string, 	 i: 2; 	 prediction: -0.2615, 	 target: -0.3203, 	 loss: 3.4911
# Epoch [2/3], Loss: 21.0850, Loss validation: 21.1795, Time remaining: ~0.0h 42.0m 11s
# 	 Validation string, 	 i: 0; 	 prediction: -0.2757, 	 target: -0.1376, 	 loss: 19.2870
# 	 Validation string, 	 i: 1; 	 prediction: -0.2757, 	 target: -0.3264, 	 loss: 2.5949
# 	 Validation string, 	 i: 2; 	 prediction: -0.2757, 	 target: -0.3203, 	 loss: 2.0077
# Epoch [3/3], Loss: 21.0866, Loss validation: 20.8688, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_model_str_6.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_losses_batches_6.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_losses_epochs_6.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_losses_epochs_validation_6.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_losses_batches_6.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_losses_epochs_6.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_losses_epochs_validation_6.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_e_6.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_validation_6.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_validation_6.txt
# 1  # ------- block_n_layers:  2  ------- #
#
#
# Epoch [0/3], Loss: 143.3923, Loss validation: 143.1558
# 	 Validation string, 	 i: 0; 	 prediction: -0.1522, 	 target: -0.1376, 	 loss: 0.2157
# 	 Validation string, 	 i: 1; 	 prediction: -0.2347, 	 target: -0.3264, 	 loss: 8.5013
# 	 Validation string, 	 i: 2; 	 prediction: -0.1461, 	 target: -0.3203, 	 loss: 30.6774
# Epoch [1/3], Loss: 6.9577, Loss validation: 5.6950, Time remaining: ~0.0h 0.0m 43s
# 	 Validation string, 	 i: 0; 	 prediction: -0.1621, 	 target: -0.1376, 	 loss: 0.6084
# 	 Validation string, 	 i: 1; 	 prediction: -0.2267, 	 target: -0.3264, 	 loss: 10.0453
# 	 Validation string, 	 i: 2; 	 prediction: -0.1548, 	 target: -0.3203, 	 loss: 27.6859
# Epoch [2/3], Loss: 5.6055, Loss validation: 5.4793, Time remaining: ~0.0h 0.0m 21s
# 	 Validation string, 	 i: 0; 	 prediction: -0.1102, 	 target: -0.1376, 	 loss: 0.7591
# 	 Validation string, 	 i: 1; 	 prediction: -0.1736, 	 target: -0.3264, 	 loss: 23.6109
# 	 Validation string, 	 i: 2; 	 prediction: -0.1048, 	 target: -0.3203, 	 loss: 46.9299
# Epoch [3/3], Loss: 5.4821, Loss validation: 6.9023, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_model_str_7.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_losses_batches_7.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_losses_epochs_7.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_losses_epochs_validation_7.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_losses_batches_7.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_losses_epochs_7.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_losses_epochs_validation_7.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_e_7.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_e_validation_7.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_e_validation_7.txt
# 1  # ------- block_n_layers:  3  ------- #
#
#
# Epoch [0/3], Loss: 1995.3526, Loss validation: 1994.3356
# 	 Validation string, 	 i: 0; 	 prediction: -0.2713, 	 target: -0.1376, 	 loss: 18.0595
# 	 Validation string, 	 i: 1; 	 prediction: -0.2713, 	 target: -0.3264, 	 loss: 3.0728
# 	 Validation string, 	 i: 2; 	 prediction: -0.2713, 	 target: -0.3203, 	 loss: 2.4305
# Epoch [1/3], Loss: 23.7119, Loss validation: 20.9226, Time remaining: ~1.0h 1.0m 55s
# 	 Validation string, 	 i: 0; 	 prediction: -0.2991, 	 target: -0.1376, 	 loss: 26.3772
# 	 Validation string, 	 i: 1; 	 prediction: -0.2991, 	 target: -0.3264, 	 loss: 0.7512
# 	 Validation string, 	 i: 2; 	 prediction: -0.2991, 	 target: -0.3203, 	 loss: 0.4526
# Epoch [2/3], Loss: 21.0802, Loss validation: 21.2466, Time remaining: ~0.0h 31.0m 50s
# - Epoch [3/3], i: [249856/397781], Loss: 16.4892
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
