# %%
initial_path = 'peptide-QML/'
# initial_path = '../'

# %%
import numpy as np
import sys
sys.path.append(initial_path)

# %load_ext autoreload
# %autoreload 2
from my_code import functions as f
from my_code import pytorch_model as ptm
from my_code import quantum_nodes as qn
from my_code import pytorch_wrappers as pw
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (2.0.4) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
dim = 12
day = "0903"


# -- DATA -- #

# name of the notebook
name_notebook = "{}-{}c_em.ipynb".format(day, dim)

# load data
data_file_path = '{}data/Scores/PET/PET_SCORES.csv'.format(initial_path)
string_list, number_list = f.read_data_file(
    data_file_path,
    skip_first_line=True, 
    delimiter=', ', 
    columns_to_return=[1, 2],
    which_columns_are_numbers=[2]
    )
score_list = np.array(number_list)/100
vector_list = np.array([f.string_to_numbers(string) for string in string_list]) 
X, Y, X_validation, Y_validation = f.create_validating_set(vector_list, score_list, percentage=0.1)

# Define the dataset
input_data = ptm.torch.tensor(X) 
target_data = ptm.torch.tensor(Y).view(-1, 1)

# Define the validation set
input_validation = ptm.torch.tensor(X_validation)
target_validation = ptm.torch.tensor(Y_validation).view(-1, 1)


# -- TRAINING LOOP -- #
for iii in range(5):

    for block_n_layers in range(1, 5):
        print(iii, " # ------- block_n_layers: ", block_n_layers, " ------- #")
        print("")
        print("")

        # -- CLASSICAL MODEL -- #
        n_aminoacids = len(string_list[0])
        input_dim = input_data.shape[1]

        class Reshape(ptm.nn.Module):
            def __init__(self):
                super(Reshape, self).__init__()

            def forward(self, x):
                dims = len(x.shape)
                return ptm.torch.transpose(x, dims-2, dims-1).reshape(x.shape[-3] if dims==3 else 1, x.shape[-2]*x.shape[-1]).squeeze()
            
        embedding_dim = 4
        layers =  [ptm.nn.Embedding(num_embeddings=19, embedding_dim=embedding_dim), Reshape()]

        layers_dim = np.linspace(input_dim*embedding_dim, 1, block_n_layers+1).astype(int)
        for i, o in zip(layers_dim[:-1], layers_dim[1:]):
            layers += [ptm.nn.Linear(i, o), ptm.nn.Sigmoid()]    # activation function RELU didn't work well  
        layers += [ptm.nn.Linear(1,1)]

        


        # Create model and set data:
        model = ptm.pytorch_model(
            layers,    
            save_options = {'initial_path': initial_path, 'name_notebook': name_notebook},
        )
        model.set_data(
            data_X=input_data, 
            data_Y=target_data, 
            data_X_validation=input_validation,
            data_Y_validation=target_validation
        )
        model.keep_track_params=False


        # -- TRAINING -- #
        import torch.optim as optim

        # train the model
        model.train(
            optimizer= optim.Adam,
            optimizer_options={'lr': 0.02},
            num_epochs = 3,                
            batch_size = 32,
            stop_training_options = {
                'lookback_epochs': 5, 
                'threshold_slope': 0.001,
                'threshold_std_dev': 0.2
            },
        )

        # -- SAVE -- #

        # dump the object
        model.dump()

        # save string of the model
        model.save_str(
            metadata={
                "data_file_path": data_file_path,
                "n_aminoacids": n_aminoacids,
                "block_n_layers": block_n_layers,
            }
        )

        # plot the losses of the trainig loop and save the figures
        model.plot_losses(save=True, save_txt=True)

        #save all the parameters of the model and the intermediate parameters of the model
        model.save_state_dict(intermediate=False)

        # plot the validation and save it
        model.plot_validation(save=True, fig_size=(9,9), percentatge=1)

        # print validation and save it
        model.str_validation(save=True, precision=4, percentatge=1, printing=False)
# Out:
# 0  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/3], Loss: 62.5027, Loss validation: 63.4970
# - Epoch [1/3], i: [2208/397781], Loss: 9.81150
# /usr/lib/python3/dist-packages/torch/autograd/__init__.py:147: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at  ../c10/cuda/CUDAFunctions.cpp:115.)
#   Variable._execution_engine.run_backward(
# 	 Validation string, 	 i: 0; 	 prediction: -0.4397, 	 target: -0.4187, 	 loss: 0.4440
# 	 Validation string, 	 i: 1; 	 prediction: -0.1613, 	 target: -0.0715, 	 loss: 8.1466
# 	 Validation string, 	 i: 2; 	 prediction: -0.4599, 	 target: -0.4843, 	 loss: 0.6020
# Epoch [1/3], Loss: 8.5702, Loss validation: 8.2940, Time remaining: ~0.0h 0.0m 32s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4371, 	 target: -0.4187, 	 loss: 0.3433
# 	 Validation string, 	 i: 1; 	 prediction: -0.1736, 	 target: -0.0715, 	 loss: 10.5336
# 	 Validation string, 	 i: 2; 	 prediction: -0.4642, 	 target: -0.4843, 	 loss: 0.4095
# Epoch [2/3], Loss: 8.5341, Loss validation: 8.2771, Time remaining: ~0.0h 0.0m 16s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4553, 	 target: -0.4187, 	 loss: 1.3543
# 	 Validation string, 	 i: 1; 	 prediction: -0.2124, 	 target: -0.0715, 	 loss: 20.0546
# 	 Validation string, 	 i: 2; 	 prediction: -0.4854, 	 target: -0.4843, 	 loss: 0.0012
# Epoch [3/3], Loss: 8.5191, Loss validation: 9.1128, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_1.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_1.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_1.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_1.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_1.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_1.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_1.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_1.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_1.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_1.txt
# 0  # ------- block_n_layers:  2  ------- #
#
#
# Epoch [0/3], Loss: 264.3333, Loss validation: 263.1191
# 	 Validation string, 	 i: 0; 	 prediction: -0.4423, 	 target: -0.4187, 	 loss: 0.5621
# 	 Validation string, 	 i: 1; 	 prediction: -0.1976, 	 target: -0.0715, 	 loss: 16.0638
# 	 Validation string, 	 i: 2; 	 prediction: -0.5181, 	 target: -0.4843, 	 loss: 1.1546
# Epoch [1/3], Loss: 6.2559, Loss validation: 6.1112, Time remaining: ~0.0h 0.0m 39s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4407, 	 target: -0.4187, 	 loss: 0.4889
# 	 Validation string, 	 i: 1; 	 prediction: -0.1825, 	 target: -0.0715, 	 loss: 12.4423
# 	 Validation string, 	 i: 2; 	 prediction: -0.5134, 	 target: -0.4843, 	 loss: 0.8581
# Epoch [2/3], Loss: 5.7365, Loss validation: 6.2206, Time remaining: ~0.0h 0.0m 19s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4230, 	 target: -0.4187, 	 loss: 0.0183
# 	 Validation string, 	 i: 1; 	 prediction: -0.1922, 	 target: -0.0715, 	 loss: 14.7067
# 	 Validation string, 	 i: 2; 	 prediction: -0.5092, 	 target: -0.4843, 	 loss: 0.6279
# Epoch [3/3], Loss: 5.7715, Loss validation: 5.7961, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_2.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_2.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_2.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_2.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_2.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_2.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_2.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_2.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_2.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_2.txt
# 0  # ------- block_n_layers:  3  ------- #
#
#
# Epoch [0/3], Loss: 151.3696, Loss validation: 151.9806
# 	 Validation string, 	 i: 0; 	 prediction: -0.4064, 	 target: -0.4187, 	 loss: 0.1540
# 	 Validation string, 	 i: 1; 	 prediction: -0.2062, 	 target: -0.0715, 	 loss: 18.3214
# 	 Validation string, 	 i: 2; 	 prediction: -0.5032, 	 target: -0.4843, 	 loss: 0.3612
# Epoch [1/3], Loss: 5.5335, Loss validation: 5.0786, Time remaining: ~0.0h 0.0m 44s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3918, 	 target: -0.4187, 	 loss: 0.7297
# 	 Validation string, 	 i: 1; 	 prediction: -0.1945, 	 target: -0.0715, 	 loss: 15.2841
# 	 Validation string, 	 i: 2; 	 prediction: -0.4997, 	 target: -0.4843, 	 loss: 0.2398
# Epoch [2/3], Loss: 4.9924, Loss validation: 4.8901, Time remaining: ~0.0h 0.0m 22s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3435, 	 target: -0.4187, 	 loss: 5.7197
# 	 Validation string, 	 i: 1; 	 prediction: -0.1824, 	 target: -0.0715, 	 loss: 12.4310
# 	 Validation string, 	 i: 2; 	 prediction: -0.4431, 	 target: -0.4843, 	 loss: 1.7165
# Epoch [3/3], Loss: 4.9958, Loss validation: 5.2745, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_3.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_3.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_3.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_3.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_3.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_3.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_3.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_3.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_3.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_3.txt
# 0  # ------- block_n_layers:  4  ------- #
#
#
# Epoch [0/3], Loss: 467.6743, Loss validation: 466.2365
# 	 Validation string, 	 i: 0; 	 prediction: -0.3861, 	 target: -0.4187, 	 loss: 1.0767
# 	 Validation string, 	 i: 1; 	 prediction: -0.1973, 	 target: -0.0715, 	 loss: 15.9876
# 	 Validation string, 	 i: 2; 	 prediction: -0.4577, 	 target: -0.4843, 	 loss: 0.7136
# Epoch [1/3], Loss: 10.4863, Loss validation: 5.3232, Time remaining: ~0.0h 0.0m 51s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3846, 	 target: -0.4187, 	 loss: 1.1738
# 	 Validation string, 	 i: 1; 	 prediction: -0.2220, 	 target: -0.0715, 	 loss: 22.8754
# 	 Validation string, 	 i: 2; 	 prediction: -0.4649, 	 target: -0.4843, 	 loss: 0.3789
# Epoch [2/3], Loss: 5.2486, Loss validation: 4.9507, Time remaining: ~0.0h 0.0m 24s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3893, 	 target: -0.4187, 	 loss: 0.8750
# 	 Validation string, 	 i: 1; 	 prediction: -0.3142, 	 target: -0.0715, 	 loss: 59.5105
# 	 Validation string, 	 i: 2; 	 prediction: -0.5243, 	 target: -0.4843, 	 loss: 1.6173
# Epoch [3/3], Loss: 5.1408, Loss validation: 5.1855, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_4.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_4.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_4.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_4.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_4.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_4.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_4.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_4.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_4.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_4.txt
# 1  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/3], Loss: 23.1018, Loss validation: 22.8673
# 	 Validation string, 	 i: 0; 	 prediction: -0.4250, 	 target: -0.4187, 	 loss: 0.0400
# 	 Validation string, 	 i: 1; 	 prediction: -0.1744, 	 target: -0.0715, 	 loss: 10.6990
# 	 Validation string, 	 i: 2; 	 prediction: -0.4508, 	 target: -0.4843, 	 loss: 1.1344
# Epoch [1/3], Loss: 8.5890, Loss validation: 8.2536, Time remaining: ~0.0h 0.0m 33s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4106, 	 target: -0.4187, 	 loss: 0.0669
# 	 Validation string, 	 i: 1; 	 prediction: -0.1688, 	 target: -0.0715, 	 loss: 9.5569
# 	 Validation string, 	 i: 2; 	 prediction: -0.4317, 	 target: -0.4843, 	 loss: 2.7966
# Epoch [2/3], Loss: 8.5346, Loss validation: 8.4722, Time remaining: ~0.0h 0.0m 16s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4025, 	 target: -0.4187, 	 loss: 0.2665
# 	 Validation string, 	 i: 1; 	 prediction: -0.1840, 	 target: -0.0715, 	 loss: 12.7763
# 	 Validation string, 	 i: 2; 	 prediction: -0.4465, 	 target: -0.4843, 	 loss: 1.4397
# Epoch [3/3], Loss: 8.5264, Loss validation: 8.4330, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_5.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_5.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_5.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_5.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_5.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_5.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_5.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_5.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_5.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_5.txt
# 1  # ------- block_n_layers:  2  ------- #
#
#
# Epoch [0/3], Loss: 2630.1519, Loss validation: 2632.6552
# 	 Validation string, 	 i: 0; 	 prediction: -0.3503, 	 target: -0.4187, 	 loss: 4.7243
# 	 Validation string, 	 i: 1; 	 prediction: -0.2411, 	 target: -0.0715, 	 loss: 29.0680
# 	 Validation string, 	 i: 2; 	 prediction: -0.5160, 	 target: -0.4843, 	 loss: 1.0155
# Epoch [1/3], Loss: 9.8571, Loss validation: 5.3960, Time remaining: ~0.0h 0.0m 39s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3907, 	 target: -0.4187, 	 loss: 0.7902
# 	 Validation string, 	 i: 1; 	 prediction: -0.2486, 	 target: -0.0715, 	 loss: 31.6854
# 	 Validation string, 	 i: 2; 	 prediction: -0.4936, 	 target: -0.4843, 	 loss: 0.0875
# Epoch [2/3], Loss: 5.3261, Loss validation: 5.2011, Time remaining: ~0.0h 0.0m 19s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3411, 	 target: -0.4187, 	 loss: 6.0830
# 	 Validation string, 	 i: 1; 	 prediction: -0.2104, 	 target: -0.0715, 	 loss: 19.4792
# 	 Validation string, 	 i: 2; 	 prediction: -0.4848, 	 target: -0.4843, 	 loss: 0.0002
# Epoch [3/3], Loss: 5.3477, Loss validation: 5.4885, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_6.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_6.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_6.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_6.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_6.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_6.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_6.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_6.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_6.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_6.txt
# 1  # ------- block_n_layers:  3  ------- #
#
#
# Epoch [0/3], Loss: 535.6541, Loss validation: 537.0519
# 	 Validation string, 	 i: 0; 	 prediction: -0.4105, 	 target: -0.4187, 	 loss: 0.0676
# 	 Validation string, 	 i: 1; 	 prediction: -0.1749, 	 target: -0.0715, 	 loss: 10.7904
# 	 Validation string, 	 i: 2; 	 prediction: -0.4647, 	 target: -0.4843, 	 loss: 0.3873
# Epoch [1/3], Loss: 6.2549, Loss validation: 5.5143, Time remaining: ~0.0h 0.0m 46s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4166, 	 target: -0.4187, 	 loss: 0.0044
# 	 Validation string, 	 i: 1; 	 prediction: -0.1940, 	 target: -0.0715, 	 loss: 15.1513
# 	 Validation string, 	 i: 2; 	 prediction: -0.4632, 	 target: -0.4843, 	 loss: 0.4484
# Epoch [2/3], Loss: 5.0553, Loss validation: 4.9517, Time remaining: ~0.0h 0.0m 22s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4294, 	 target: -0.4187, 	 loss: 0.1152
# 	 Validation string, 	 i: 1; 	 prediction: -0.2412, 	 target: -0.0715, 	 loss: 29.0970
# 	 Validation string, 	 i: 2; 	 prediction: -0.3708, 	 target: -0.4843, 	 loss: 13.0162
# Epoch [3/3], Loss: 5.0156, Loss validation: 4.7878, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_7.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_7.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_7.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_7.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_7.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_7.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_7.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_7.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_7.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_7.txt
# 1  # ------- block_n_layers:  4  ------- #
#
#
# Epoch [0/3], Loss: 391.7439, Loss validation: 392.9098
# 	 Validation string, 	 i: 0; 	 prediction: -0.4040, 	 target: -0.4187, 	 loss: 0.2194
# 	 Validation string, 	 i: 1; 	 prediction: -0.1379, 	 target: -0.0715, 	 loss: 4.4487
# 	 Validation string, 	 i: 2; 	 prediction: -0.4788, 	 target: -0.4843, 	 loss: 0.0311
# Epoch [1/3], Loss: 6.6595, Loss validation: 5.3950, Time remaining: ~0.0h 0.0m 51s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3853, 	 target: -0.4187, 	 loss: 1.1264
# 	 Validation string, 	 i: 1; 	 prediction: -0.1756, 	 target: -0.0715, 	 loss: 10.9386
# 	 Validation string, 	 i: 2; 	 prediction: -0.4996, 	 target: -0.4843, 	 loss: 0.2356
# Epoch [2/3], Loss: 5.3423, Loss validation: 5.3555, Time remaining: ~0.0h 0.0m 25s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4106, 	 target: -0.4187, 	 loss: 0.0668
# 	 Validation string, 	 i: 1; 	 prediction: -0.2383, 	 target: -0.0715, 	 loss: 28.1048
# 	 Validation string, 	 i: 2; 	 prediction: -0.5174, 	 target: -0.4843, 	 loss: 1.1076
# Epoch [3/3], Loss: 5.3080, Loss validation: 5.6785, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_8.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_8.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_8.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_8.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_8.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_8.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_8.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_8.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_8.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_8.txt
# 2  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/3], Loss: 30.1447, Loss validation: 29.5989
# 	 Validation string, 	 i: 0; 	 prediction: -0.4276, 	 target: -0.4187, 	 loss: 0.0794
# 	 Validation string, 	 i: 1; 	 prediction: -0.1732, 	 target: -0.0715, 	 loss: 10.4576
# 	 Validation string, 	 i: 2; 	 prediction: -0.4402, 	 target: -0.4843, 	 loss: 1.9636
# Epoch [1/3], Loss: 8.6588, Loss validation: 8.4611, Time remaining: ~0.0h 0.0m 33s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4462, 	 target: -0.4187, 	 loss: 0.7666
# 	 Validation string, 	 i: 1; 	 prediction: -0.1850, 	 target: -0.0715, 	 loss: 13.0023
# 	 Validation string, 	 i: 2; 	 prediction: -0.4460, 	 target: -0.4843, 	 loss: 1.4788
# Epoch [2/3], Loss: 8.5562, Loss validation: 8.3936, Time remaining: ~0.0h 0.0m 16s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4161, 	 target: -0.4187, 	 loss: 0.0068
# 	 Validation string, 	 i: 1; 	 prediction: -0.1783, 	 target: -0.0715, 	 loss: 11.5214
# 	 Validation string, 	 i: 2; 	 prediction: -0.4518, 	 target: -0.4843, 	 loss: 1.0673
# Epoch [3/3], Loss: 8.5266, Loss validation: 8.3933, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_9.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_9.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_9.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_9.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_9.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_9.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_9.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_9.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_9.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_9.txt
# 2  # ------- block_n_layers:  2  ------- #
#
#
# Epoch [0/3], Loss: 148.9871, Loss validation: 148.1901
# 	 Validation string, 	 i: 0; 	 prediction: -0.4258, 	 target: -0.4187, 	 loss: 0.0508
# 	 Validation string, 	 i: 1; 	 prediction: -0.2476, 	 target: -0.0715, 	 loss: 31.3308
# 	 Validation string, 	 i: 2; 	 prediction: -0.4861, 	 target: -0.4843, 	 loss: 0.0032
# Epoch [1/3], Loss: 6.0057, Loss validation: 5.6158, Time remaining: ~0.0h 0.0m 40s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4381, 	 target: -0.4187, 	 loss: 0.3815
# 	 Validation string, 	 i: 1; 	 prediction: -0.1484, 	 target: -0.0715, 	 loss: 5.9661
# 	 Validation string, 	 i: 2; 	 prediction: -0.4774, 	 target: -0.4843, 	 loss: 0.0480
# Epoch [2/3], Loss: 5.6193, Loss validation: 5.4202, Time remaining: ~0.0h 0.0m 19s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3910, 	 target: -0.4187, 	 loss: 0.7749
# 	 Validation string, 	 i: 1; 	 prediction: -0.1847, 	 target: -0.0715, 	 loss: 12.9521
# 	 Validation string, 	 i: 2; 	 prediction: -0.4936, 	 target: -0.4843, 	 loss: 0.0872
# Epoch [3/3], Loss: 5.6083, Loss validation: 5.3993, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_10.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_10.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_10.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_10.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_10.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_10.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_10.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_10.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_10.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_10.txt
# 2  # ------- block_n_layers:  3  ------- #
#
#
# Epoch [0/3], Loss: 20.9191, Loss validation: 20.8240
# 	 Validation string, 	 i: 0; 	 prediction: -0.3775, 	 target: -0.4187, 	 loss: 1.7128
# 	 Validation string, 	 i: 1; 	 prediction: -0.2285, 	 target: -0.0715, 	 loss: 24.8908
# 	 Validation string, 	 i: 2; 	 prediction: -0.4417, 	 target: -0.4843, 	 loss: 1.8356
# Epoch [1/3], Loss: 5.4028, Loss validation: 4.9828, Time remaining: ~0.0h 0.0m 44s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4162, 	 target: -0.4187, 	 loss: 0.0064
# 	 Validation string, 	 i: 1; 	 prediction: -0.2025, 	 target: -0.0715, 	 loss: 17.3480
# 	 Validation string, 	 i: 2; 	 prediction: -0.4064, 	 target: -0.4843, 	 loss: 6.1301
# Epoch [2/3], Loss: 5.0046, Loss validation: 4.9270, Time remaining: ~0.0h 0.0m 21s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3969, 	 target: -0.4187, 	 loss: 0.4782
# 	 Validation string, 	 i: 1; 	 prediction: -0.1978, 	 target: -0.0715, 	 loss: 16.1074
# 	 Validation string, 	 i: 2; 	 prediction: -0.4863, 	 target: -0.4843, 	 loss: 0.0039
# Epoch [3/3], Loss: 5.0266, Loss validation: 4.8518, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_11.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_11.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_11.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_11.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_11.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_11.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_11.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_11.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_11.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_11.txt
# 2  # ------- block_n_layers:  4  ------- #
#
#
# Epoch [0/3], Loss: 1507.1192, Loss validation: 1509.5265
# 	 Validation string, 	 i: 0; 	 prediction: -0.3442, 	 target: -0.4187, 	 loss: 5.6112
# 	 Validation string, 	 i: 1; 	 prediction: -0.1785, 	 target: -0.0715, 	 loss: 11.5745
# 	 Validation string, 	 i: 2; 	 prediction: -0.4670, 	 target: -0.4843, 	 loss: 0.3028
# Epoch [1/3], Loss: 20.6887, Loss validation: 7.0261, Time remaining: ~0.0h 0.0m 51s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4164, 	 target: -0.4187, 	 loss: 0.0054
# 	 Validation string, 	 i: 1; 	 prediction: -0.1946, 	 target: -0.0715, 	 loss: 15.3028
# 	 Validation string, 	 i: 2; 	 prediction: -0.4371, 	 target: -0.4843, 	 loss: 2.2462
# Epoch [2/3], Loss: 5.9378, Loss validation: 5.6261, Time remaining: ~0.0h 0.0m 24s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3809, 	 target: -0.4187, 	 loss: 1.4469
# 	 Validation string, 	 i: 1; 	 prediction: -0.1843, 	 target: -0.0715, 	 loss: 12.8516
# 	 Validation string, 	 i: 2; 	 prediction: -0.4603, 	 target: -0.4843, 	 loss: 0.5798
# Epoch [3/3], Loss: 5.4677, Loss validation: 5.2319, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_12.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_12.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_12.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_12.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_12.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_12.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_12.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_12.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_12.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_12.txt
# 3  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/3], Loss: 630.9773, Loss validation: 630.4328
# 	 Validation string, 	 i: 0; 	 prediction: -0.4101, 	 target: -0.4187, 	 loss: 0.0747
# 	 Validation string, 	 i: 1; 	 prediction: -0.1716, 	 target: -0.0715, 	 loss: 10.1175
# 	 Validation string, 	 i: 2; 	 prediction: -0.4360, 	 target: -0.4843, 	 loss: 2.3591
# Epoch [1/3], Loss: 9.7267, Loss validation: 8.7404, Time remaining: ~0.0h 0.0m 33s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3878, 	 target: -0.4187, 	 loss: 0.9627
# 	 Validation string, 	 i: 1; 	 prediction: -0.1594, 	 target: -0.0715, 	 loss: 7.8054
# 	 Validation string, 	 i: 2; 	 prediction: -0.4453, 	 target: -0.4843, 	 loss: 1.5336
# Epoch [2/3], Loss: 8.5057, Loss validation: 8.8061, Time remaining: ~0.0h 0.0m 16s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4618, 	 target: -0.4187, 	 loss: 1.8774
# 	 Validation string, 	 i: 1; 	 prediction: -0.1908, 	 target: -0.0715, 	 loss: 14.3882
# 	 Validation string, 	 i: 2; 	 prediction: -0.5025, 	 target: -0.4843, 	 loss: 0.3337
# Epoch [3/3], Loss: 8.5391, Loss validation: 8.9526, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_13.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_13.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_13.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_13.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_13.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_13.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_13.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_13.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_13.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_13.txt
# 3  # ------- block_n_layers:  2  ------- #
#
#
# Epoch [0/3], Loss: 22.9636, Loss validation: 22.9846
# 	 Validation string, 	 i: 0; 	 prediction: -0.4193, 	 target: -0.4187, 	 loss: 0.0004
# 	 Validation string, 	 i: 1; 	 prediction: -0.1859, 	 target: -0.0715, 	 loss: 13.2210
# 	 Validation string, 	 i: 2; 	 prediction: -0.4575, 	 target: -0.4843, 	 loss: 0.7231
# Epoch [1/3], Loss: 5.8552, Loss validation: 5.3331, Time remaining: ~0.0h 0.0m 40s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4009, 	 target: -0.4187, 	 loss: 0.3206
# 	 Validation string, 	 i: 1; 	 prediction: -0.2384, 	 target: -0.0715, 	 loss: 28.1348
# 	 Validation string, 	 i: 2; 	 prediction: -0.4542, 	 target: -0.4843, 	 loss: 0.9131
# Epoch [2/3], Loss: 5.4111, Loss validation: 5.2332, Time remaining: ~0.0h 0.0m 19s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3835, 	 target: -0.4187, 	 loss: 1.2537
# 	 Validation string, 	 i: 1; 	 prediction: -0.1792, 	 target: -0.0715, 	 loss: 11.7151
# 	 Validation string, 	 i: 2; 	 prediction: -0.4561, 	 target: -0.4843, 	 loss: 0.8061
# Epoch [3/3], Loss: 5.4237, Loss validation: 5.4311, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_14.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_14.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_14.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_14.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_14.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_14.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_14.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_14.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_14.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_14.txt
# 3  # ------- block_n_layers:  3  ------- #
#
#
# Epoch [0/3], Loss: 176.7192, Loss validation: 177.4818
# 	 Validation string, 	 i: 0; 	 prediction: -0.4061, 	 target: -0.4187, 	 loss: 0.1595
# 	 Validation string, 	 i: 1; 	 prediction: -0.2267, 	 target: -0.0715, 	 loss: 24.3341
# 	 Validation string, 	 i: 2; 	 prediction: -0.4650, 	 target: -0.4843, 	 loss: 0.3757
# Epoch [1/3], Loss: 6.4398, Loss validation: 5.9795, Time remaining: ~0.0h 0.0m 47s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4021, 	 target: -0.4187, 	 loss: 0.2768
# 	 Validation string, 	 i: 1; 	 prediction: -0.1795, 	 target: -0.0715, 	 loss: 11.7922
# 	 Validation string, 	 i: 2; 	 prediction: -0.4561, 	 target: -0.4843, 	 loss: 0.8045
# Epoch [2/3], Loss: 5.2280, Loss validation: 5.3723, Time remaining: ~0.0h 0.0m 22s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3861, 	 target: -0.4187, 	 loss: 1.0748
# 	 Validation string, 	 i: 1; 	 prediction: -0.1801, 	 target: -0.0715, 	 loss: 11.9034
# 	 Validation string, 	 i: 2; 	 prediction: -0.4612, 	 target: -0.4843, 	 loss: 0.5399
# Epoch [3/3], Loss: 5.1775, Loss validation: 5.2905, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_15.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_15.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_15.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_15.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_15.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_15.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_15.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_15.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_15.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_15.txt
# 3  # ------- block_n_layers:  4  ------- #
#
#
# Epoch [0/3], Loss: 21.5654, Loss validation: 21.5430
# 	 Validation string, 	 i: 0; 	 prediction: -0.3994, 	 target: -0.4187, 	 loss: 0.3752
# 	 Validation string, 	 i: 1; 	 prediction: -0.1887, 	 target: -0.0715, 	 loss: 13.8668
# 	 Validation string, 	 i: 2; 	 prediction: -0.4375, 	 target: -0.4843, 	 loss: 2.2158
# Epoch [1/3], Loss: 5.4228, Loss validation: 5.1709, Time remaining: ~0.0h 0.0m 51s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3737, 	 target: -0.4187, 	 loss: 2.0499
# 	 Validation string, 	 i: 1; 	 prediction: -0.1939, 	 target: -0.0715, 	 loss: 15.1398
# 	 Validation string, 	 i: 2; 	 prediction: -0.3897, 	 target: -0.4843, 	 loss: 9.0370
# Epoch [2/3], Loss: 5.0626, Loss validation: 4.9855, Time remaining: ~0.0h 0.0m 25s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3725, 	 target: -0.4187, 	 loss: 2.1516
# 	 Validation string, 	 i: 1; 	 prediction: -0.1943, 	 target: -0.0715, 	 loss: 15.2432
# 	 Validation string, 	 i: 2; 	 prediction: -0.4460, 	 target: -0.4843, 	 loss: 1.4785
# Epoch [3/3], Loss: 5.0529, Loss validation: 5.2560, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_16.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_16.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_16.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_16.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_16.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_16.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_16.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_16.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_16.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_16.txt
# 4  # ------- block_n_layers:  1  ------- #
#
#
# Epoch [0/3], Loss: 112.7885, Loss validation: 113.5760
# 	 Validation string, 	 i: 0; 	 prediction: -0.4119, 	 target: -0.4187, 	 loss: 0.0464
# 	 Validation string, 	 i: 1; 	 prediction: -0.1459, 	 target: -0.0715, 	 loss: 5.5843
# 	 Validation string, 	 i: 2; 	 prediction: -0.4513, 	 target: -0.4843, 	 loss: 1.1033
# Epoch [1/3], Loss: 8.6617, Loss validation: 8.5283, Time remaining: ~0.0h 0.0m 33s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3850, 	 target: -0.4187, 	 loss: 1.1489
# 	 Validation string, 	 i: 1; 	 prediction: -0.1683, 	 target: -0.0715, 	 loss: 9.4649
# 	 Validation string, 	 i: 2; 	 prediction: -0.4146, 	 target: -0.4843, 	 loss: 4.9011
# Epoch [2/3], Loss: 8.5227, Loss validation: 8.8167, Time remaining: ~0.0h 0.0m 16s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4004, 	 target: -0.4187, 	 loss: 0.3393
# 	 Validation string, 	 i: 1; 	 prediction: -0.1446, 	 target: -0.0715, 	 loss: 5.3973
# 	 Validation string, 	 i: 2; 	 prediction: -0.4377, 	 target: -0.4843, 	 loss: 2.1952
# Epoch [3/3], Loss: 8.5282, Loss validation: 8.9671, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_17.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_17.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_17.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_17.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_17.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_17.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_17.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_17.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_17.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_17.txt
# 4  # ------- block_n_layers:  2  ------- #
#
#
# Epoch [0/3], Loss: 135.7865, Loss validation: 135.1928
# 	 Validation string, 	 i: 0; 	 prediction: -0.4140, 	 target: -0.4187, 	 loss: 0.0226
# 	 Validation string, 	 i: 1; 	 prediction: -0.1813, 	 target: -0.0715, 	 loss: 12.1888
# 	 Validation string, 	 i: 2; 	 prediction: -0.4567, 	 target: -0.4843, 	 loss: 0.7682
# Epoch [1/3], Loss: 5.8336, Loss validation: 5.9647, Time remaining: ~0.0h 0.0m 40s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3629, 	 target: -0.4187, 	 loss: 3.1460
# 	 Validation string, 	 i: 1; 	 prediction: -0.1784, 	 target: -0.0715, 	 loss: 11.5385
# 	 Validation string, 	 i: 2; 	 prediction: -0.5063, 	 target: -0.4843, 	 loss: 0.4902
# Epoch [2/3], Loss: 5.3868, Loss validation: 5.3202, Time remaining: ~0.0h 0.0m 20s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3987, 	 target: -0.4187, 	 loss: 0.4022
# 	 Validation string, 	 i: 1; 	 prediction: -0.1992, 	 target: -0.0715, 	 loss: 16.4599
# 	 Validation string, 	 i: 2; 	 prediction: -0.4776, 	 target: -0.4843, 	 loss: 0.0452
# Epoch [3/3], Loss: 5.4082, Loss validation: 5.2126, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_18.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_18.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_18.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_18.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_18.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_18.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_18.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_18.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_18.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_18.txt
# 4  # ------- block_n_layers:  3  ------- #
#
#
# Epoch [0/3], Loss: 131.9089, Loss validation: 131.1453
# 	 Validation string, 	 i: 0; 	 prediction: -0.4328, 	 target: -0.4187, 	 loss: 0.2010
# 	 Validation string, 	 i: 1; 	 prediction: -0.1712, 	 target: -0.0715, 	 loss: 10.0442
# 	 Validation string, 	 i: 2; 	 prediction: -0.4362, 	 target: -0.4843, 	 loss: 2.3358
# Epoch [1/3], Loss: 6.2474, Loss validation: 5.3450, Time remaining: ~0.0h 0.0m 46s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3571, 	 target: -0.4187, 	 loss: 3.8283
# 	 Validation string, 	 i: 1; 	 prediction: -0.1574, 	 target: -0.0715, 	 loss: 7.4505
# 	 Validation string, 	 i: 2; 	 prediction: -0.4425, 	 target: -0.4843, 	 loss: 1.7640
# Epoch [2/3], Loss: 5.3220, Loss validation: 5.3541, Time remaining: ~0.0h 0.0m 22s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4276, 	 target: -0.4187, 	 loss: 0.0800
# 	 Validation string, 	 i: 1; 	 prediction: -0.1780, 	 target: -0.0715, 	 loss: 11.4616
# 	 Validation string, 	 i: 2; 	 prediction: -0.5092, 	 target: -0.4843, 	 loss: 0.6271
# Epoch [3/3], Loss: 5.3305, Loss validation: 5.2293, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_19.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_19.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_19.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_19.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_19.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_19.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_19.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_19.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_19.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_19.txt
# 4  # ------- block_n_layers:  4  ------- #
#
#
# Epoch [0/3], Loss: 137.4292, Loss validation: 136.6504
# 	 Validation string, 	 i: 0; 	 prediction: -0.4038, 	 target: -0.4187, 	 loss: 0.2245
# 	 Validation string, 	 i: 1; 	 prediction: -0.1715, 	 target: -0.0715, 	 loss: 10.1066
# 	 Validation string, 	 i: 2; 	 prediction: -0.4805, 	 target: -0.4843, 	 loss: 0.0149
# Epoch [1/3], Loss: 5.8436, Loss validation: 5.3093, Time remaining: ~0.0h 0.0m 51s
# 	 Validation string, 	 i: 0; 	 prediction: -0.4158, 	 target: -0.4187, 	 loss: 0.0085
# 	 Validation string, 	 i: 1; 	 prediction: -0.1593, 	 target: -0.0715, 	 loss: 7.7882
# 	 Validation string, 	 i: 2; 	 prediction: -0.4836, 	 target: -0.4843, 	 loss: 0.0005
# Epoch [2/3], Loss: 5.1981, Loss validation: 5.3231, Time remaining: ~0.0h 0.0m 24s
# 	 Validation string, 	 i: 0; 	 prediction: -0.3973, 	 target: -0.4187, 	 loss: 0.4619
# 	 Validation string, 	 i: 1; 	 prediction: -0.1827, 	 target: -0.0715, 	 loss: 12.4920
# 	 Validation string, 	 i: 2; 	 prediction: -0.3996, 	 target: -0.4843, 	 loss: 7.2508
# Epoch [3/3], Loss: 5.1599, Loss validation: 5.1206, Time remaining: ~0.0h 0.0m 0s
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_model_str_20.txt
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_batches_20.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_20.png
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_losses_epochs_validation_20.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_batches_20.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_20.txt
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_losses_epochs_validation_20.txt
# Model saved as peptide-QML/checkpoints/0903/models/0903-12c_em_20.pth
# Saved in:  peptide-QML/checkpoints/0903/plots/0903-12c_em_validation_20.png
# Saved in:  peptide-QML/checkpoints/0903/txts/0903-12c_em_validation_20.txt
